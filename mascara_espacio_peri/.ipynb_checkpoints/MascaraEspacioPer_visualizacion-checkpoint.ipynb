# %%
import glob
import re
import os
import SimpleITK as sitk
import matplotlib.pyplot as plt

# %%
image_viewer = sitk.ImageViewer()
slicer = '/home/maryskal/Slicer/Slicer'
image_viewer.SetApplication(slicer)

# %%
folder = '/home/maryskal/Documents/SITK/Vessel_stencils/10047G_INSP_STD_BWH_COPD'
files = [re.split(f'{folder}/', file)[1] for file in glob.glob(f"{folder}/*.nrrd")]

# %%
files.sort()
files
# Out:
# ['mask__lt5_2.nrrd',
#  'mask__lt5_3.nrrd',
#  'mask__lt5_5.nrrd',
#  'mask__lt5_artery_2.nrrd',
#  'mask__lt5_artery_3.nrrd',
#  'mask__lt5_artery_5.nrrd',
#  'mask__lt5_vein_2.nrrd',
#  'mask__lt5_vein_3.nrrd',
#  'mask__lt5_vein_5.nrrd',
#  'mask_full_2.nrrd',
#  'mask_full_3.nrrd',
#  'mask_full_5.nrrd',
#  'mask_full_artery_2.nrrd',
#  'mask_full_artery_3.nrrd',
#  'mask_full_artery_5.nrrd',
#  'mask_full_vein_2.nrrd',
#  'mask_full_vein_3.nrrd',
#  'mask_full_vein_5.nrrd',
#  'mask_gt20_2.nrrd',
#  'mask_gt20_3.nrrd',
#  'mask_gt20_5.nrrd',
#  'mask_gt20_artery_2.nrrd',
#  'mask_gt20_artery_3.nrrd',
#  'mask_gt20_artery_5.nrrd',
#  'mask_gt20_vein_2.nrrd',
#  'mask_gt20_vein_3.nrrd',
#  'mask_gt20_vein_5.nrrd']

# %%
masks = {}
for mask in files:
    masks[mask] = sitk.ReadImage(os.path.join(folder, mask))

# %%
masks
# Out:
# {'mask__lt5_2.nrrd': <SimpleITK.SimpleITK.Image; proxy of <Swig Object of type 'std::vector< itk::simple::Image >::value_type *' at 0x7f39e81ac9c0> >,
#  'mask__lt5_3.nrrd': <SimpleITK.SimpleITK.Image; proxy of <Swig Object of type 'std::vector< itk::simple::Image >::value_type *' at 0x7f3a03e27360> >,
#  'mask__lt5_5.nrrd': <SimpleITK.SimpleITK.Image; proxy of <Swig Object of type 'std::vector< itk::simple::Image >::value_type *' at 0x7f3a03e273f0> >,
#  'mask__lt5_artery_2.nrrd': <SimpleITK.SimpleITK.Image; proxy of <Swig Object of type 'std::vector< itk::simple::Image >::value_type *' at 0x7f3a03e27a50> >,
#  'mask__lt5_artery_3.nrrd': <SimpleITK.SimpleITK.Image; proxy of <Swig Object of type 'std::vector< itk::simple::Image >::value_type *' at 0x7f3a03e27b40> >,
#  'mask__lt5_artery_5.nrrd': <SimpleITK.SimpleITK.Image; proxy of <Swig Object of type 'std::vector< itk::simple::Image >::value_type *' at 0x7f3a03e27240> >,
#  'mask__lt5_vein_2.nrrd': <SimpleITK.SimpleITK.Image; proxy of <Swig Object of type 'std::vector< itk::simple::Image >::value_type *' at 0x7f39bc4529d0> >,
#  'mask__lt5_vein_3.nrrd': <SimpleITK.SimpleITK.Image; proxy of <Swig Object of type 'std::vector< itk::simple::Image >::value_type *' at 0x7f39bc452bb0> >,
#  'mask__lt5_vein_5.nrrd': <SimpleITK.SimpleITK.Image; proxy of <Swig Object of type 'std::vector< itk::simple::Image >::value_type *' at 0x7f39bc452d60> >,
#  'mask_full_2.nrrd': <SimpleITK.SimpleITK.Image; proxy of <Swig Object of type 'std::vector< itk::simple::Image >::value_type *' at 0x7f39bc452f10> >,
#  'mask_full_3.nrrd': <SimpleITK.SimpleITK.Image; proxy of <Swig Object of type 'std::vector< itk::simple::Image >::value_type *' at 0x7f39bc452e80> >,
#  'mask_full_5.nrrd': <SimpleITK.SimpleITK.Image; proxy of <Swig Object of type 'std::vector< itk::simple::Image >::value_type *' at 0x7f39bc452df0> >,
#  'mask_full_artery_2.nrrd': <SimpleITK.SimpleITK.Image; proxy of <Swig Object of type 'std::vector< itk::simple::Image >::value_type *' at 0x7f39bc452340> >,
#  'mask_full_artery_3.nrrd': <SimpleITK.SimpleITK.Image; proxy of <Swig Object of type 'std::vector< itk::simple::Image >::value_type *' at 0x7f39bc4528e0> >,
#  'mask_full_artery_5.nrrd': <SimpleITK.SimpleITK.Image; proxy of <Swig Object of type 'std::vector< itk::simple::Image >::value_type *' at 0x7f39bc452a00> >,
#  'mask_full_vein_2.nrrd': <SimpleITK.SimpleITK.Image; proxy of <Swig Object of type 'std::vector< itk::simple::Image >::value_type *' at 0x7f39bc452820> >,
#  'mask_full_vein_3.nrrd': <SimpleITK.SimpleITK.Image; proxy of <Swig Object of type 'std::vector< itk::simple::Image >::value_type *' at 0x7f39bc4523d0> >,
#  'mask_full_vein_5.nrrd': <SimpleITK.SimpleITK.Image; proxy of <Swig Object of type 'std::vector< itk::simple::Image >::value_type *' at 0x7f39bc4526d0> >,
#  'mask_gt20_2.nrrd': <SimpleITK.SimpleITK.Image; proxy of <Swig Object of type 'std::vector< itk::simple::Image >::value_type *' at 0x7f39bc452a30> >,
#  'mask_gt20_3.nrrd': <SimpleITK.SimpleITK.Image; proxy of <Swig Object of type 'std::vector< itk::simple::Image >::value_type *' at 0x7f39bc453150> >,
#  'mask_gt20_5.nrrd': <SimpleITK.SimpleITK.Image; proxy of <Swig Object of type 'std::vector< itk::simple::Image >::value_type *' at 0x7f39bc452cd0> >,
#  'mask_gt20_artery_2.nrrd': <SimpleITK.SimpleITK.Image; proxy of <Swig Object of type 'std::vector< itk::simple::Image >::value_type *' at 0x7f39bc453060> >,
#  'mask_gt20_artery_3.nrrd': <SimpleITK.SimpleITK.Image; proxy of <Swig Object of type 'std::vector< itk::simple::Image >::value_type *' at 0x7f39bc451e00> >,
#  'mask_gt20_artery_5.nrrd': <SimpleITK.SimpleITK.Image; proxy of <Swig Object of type 'std::vector< itk::simple::Image >::value_type *' at 0x7f39bc453330> >,
#  'mask_gt20_vein_2.nrrd': <SimpleITK.SimpleITK.Image; proxy of <Swig Object of type 'std::vector< itk::simple::Image >::value_type *' at 0x7f39bc4533c0> >,
#  'mask_gt20_vein_3.nrrd': <SimpleITK.SimpleITK.Image; proxy of <Swig Object of type 'std::vector< itk::simple::Image >::value_type *' at 0x7f39bc453450> >,
#  'mask_gt20_vein_5.nrrd': <SimpleITK.SimpleITK.Image; proxy of <Swig Object of type 'std::vector< itk::simple::Image >::value_type *' at 0x7f39bc4534e0> >}

# %%
fig, ax = plt.subplots(len(masks), figsize = (10,200))
for i, mask in enumerate(masks.values()):
    arr = sitk.GetArrayFromImage(mask)
    ax[i].set_title(files[i])
    ax[i].imshow(arr[300,:,:], cmap = 'gray')
