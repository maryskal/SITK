# %%
import os
import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import SimpleITK as sitk
from radiomics import featureextractor, getTestCase

# %%
image_viewer = sitk.ImageViewer()

# %%
#slicer = 'D:/Users/maryskal/Slicer 5.0.2/Slicer.exe'
slicer = '/home/maryskal/Slicer/Slicer'
image_viewer.SetApplication(slicer)

# %%
ctFolder = 'Vessel_stencils'
ctPath = os.path.join(ctFolder,'10047G_INSP_STD_BWH_COPD.nrrd')
maskPaths = ['mask__lt5_artery_2.nrrd', 'mask__lt5_artery_5.nrrd', 'mask_full_artery_3.nrrd']
maskPaths = [os.path.join(ctFolder, '10047G_INSP_STD_BWH_COPD', mask) for mask in maskPaths]

# %%
ct = sitk.ReadImage(ctPath)
masks = {}
for maskPath in maskPaths:
    masks[maskPath[-17:-5]] = sitk.ReadImage(maskPath)

# %%
extractor = featureextractor.RadiomicsFeatureExtractor()
extractor.disableAllFeatures()
extractor.enableFeatureClassByName('firstorder')
extractor.enableFeatureClassByName('glrlm')
extractor.enableFeatureClassByName('ngtdm')
extractor.enabledFeatures
# Out:
# {'firstorder': [], 'glrlm': [], 'ngtdm': []}

# %% [markdown]
# # Extracción

# %%
features_dict = {}
for k, mask in masks.items():
    result = extractor.execute(ct, mask)
    feature_names = list(sorted(filter(lambda k: k.startswith("original_"), result)))
    features_dict[k] = {}
    for feature in feature_names:
        features_dict[k][feature] = float(result[feature])

# %%
features_dict
# Out:
# {'_lt5_artery_2': {'original_firstorder_10Percentile': -931.0,
#   'original_firstorder_90Percentile': -739.0,
#   'original_firstorder_Energy': 3182050922227.0,
#   'original_firstorder_Entropy': 3.5844123458266486,
#   'original_firstorder_InterquartileRange': 91.0,
#   'original_firstorder_Kurtosis': 15.78732610572031,
#   'original_firstorder_Maximum': 339.0,
#   'original_firstorder_Mean': -846.918642324047,
#   'original_firstorder_MeanAbsoluteDeviation': 65.7187542754502,
#   'original_firstorder_Median': -871.0,
#   'original_firstorder_Minimum': -1024.0,
#   'original_firstorder_Range': 1363.0,
#   'original_firstorder_RobustMeanAbsoluteDeviation': 39.1982589590297,
#   'original_firstorder_RootMeanSquared': 852.365820598492,
#   'original_firstorder_Skewness': 2.6551252464011386,
#   'original_firstorder_TotalEnergy': 613750412948.1064,
#   'original_firstorder_Uniformity': 0.11086712861397556,
#   'original_firstorder_Variance': 9256.30540853344,
#   'original_glrlm_GrayLevelNonUniformity': 385051.5720438382,
#   'original_glrlm_GrayLevelNonUniformityNormalized': 0.10430612602024886,
#   'original_glrlm_GrayLevelVariance': 16.182375945981587,
#   'original_glrlm_HighGrayLevelRunEmphasis': 78.06589922586447,
#   'original_glrlm_LongRunEmphasis': 1.6646351109175777,
#   'original_glrlm_LongRunHighGrayLevelEmphasis': 109.25928319550438,
#   'original_glrlm_LongRunLowGrayLevelEmphasis': 0.053779611269160796,
#   'original_glrlm_LowGrayLevelRunEmphasis': 0.029776839405542526,
#   'original_glrlm_RunEntropy': 4.379243185143931,
#   'original_glrlm_RunLengthNonUniformity': 2725250.8697283613,
#   'original_glrlm_RunLengthNonUniformityNormalized': 0.7367904506095058,
#   'original_glrlm_RunPercentage': 0.8424845423501528,
#   'original_glrlm_RunVariance': 0.24894003888310814,
#   'original_glrlm_ShortRunEmphasis': 0.881998937523708,
#   'original_glrlm_ShortRunHighGrayLevelEmphasis': 72.19638204958886,
#   'original_glrlm_ShortRunLowGrayLevelEmphasis': 0.025600415805997333,
#   'original_ngtdm_Busyness': 715.3009198557982,
#   'original_ngtdm_Coarseness': 2.4025497754892256e-06,
#   'original_ngtdm_Complexity': 1992.0536564792512,
#   'original_ngtdm_Contrast': 0.014277363148193204,
#   'original_ngtdm_Strength': 0.010709899625273269},
#  '_lt5_artery_5': {'original_firstorder_10Percentile': -940.0,
#   'original_firstorder_90Percentile': -786.0,
#   'original_firstorder_Energy': 14657754884212.0,
#   'original_firstorder_Entropy': 3.3295254860024883,
#   'original_firstorder_InterquartileRange': 64.0,
#   'original_firstorder_Kurtosis': 32.849505693336546,
#   'original_firstorder_Maximum': 1294.0,
#   'original_firstorder_Mean': -863.4967885548252,
#   'original_firstorder_MeanAbsoluteDeviation': 65.93983933865572,
#   'original_firstorder_Median': -893.0,
#   'original_firstorder_Minimum': -1024.0,
#   'original_firstorder_Range': 2318.0,
#   'original_firstorder_RobustMeanAbsoluteDeviation': 28.664404763105438,
#   'original_firstorder_RootMeanSquared': 872.6721144277517,
#   'original_firstorder_Skewness': 4.7525155371339585,
#   'original_firstorder_TotalEnergy': 2827171322192.7725,
#   'original_firstorder_Uniformity': 0.1448328413205421,
#   'original_firstorder_Variance': 15929.915455306393,
#   'original_glrlm_GrayLevelNonUniformity': 1785924.2317811672,
#   'original_glrlm_GrayLevelNonUniformityNormalized': 0.1276745056663608,
#   'original_glrlm_GrayLevelVariance': 31.07228971065334,
#   'original_glrlm_HighGrayLevelRunEmphasis': 86.41979269680323,
#   'original_glrlm_LongRunEmphasis': 2.5438138546362308,
#   'original_glrlm_LongRunHighGrayLevelEmphasis': 148.59491868149217,
#   'original_glrlm_LongRunLowGrayLevelEmphasis': 0.10340966688380508,
#   'original_glrlm_LowGrayLevelRunEmphasis': 0.0358736859424601,
#   'original_glrlm_RunEntropy': 4.627501337888246,
#   'original_glrlm_RunLengthNonUniformity': 8284609.713080835,
#   'original_glrlm_RunLengthNonUniformityNormalized': 0.590574904129496,
#   'original_glrlm_RunPercentage': 0.7262722251587068,
#   'original_glrlm_RunVariance': 0.6321980324724983,
#   'original_glrlm_ShortRunEmphasis': 0.7963791227654851,
#   'original_glrlm_ShortRunHighGrayLevelEmphasis': 77.20384683802693,
#   'original_glrlm_ShortRunLowGrayLevelEmphasis': 0.027335339966977158,
#   'original_ngtdm_Busyness': 1553.8040313792158,
#   'original_ngtdm_Coarseness': 5.869805904241584e-07,
#   'original_ngtdm_Complexity': 6054.958269960442,
#   'original_ngtdm_Contrast': 0.005181158065557733,
#   'original_ngtdm_Strength': 0.026172192664258197},
#  'full_artery_3': {'original_firstorder_10Percentile': -938.0,
#   'original_firstorder_90Percentile': -771.0,
#   'original_firstorder_Energy': 6774483351391.0,
#   'original_firstorder_Entropy': 3.4011103330703096,
#   'original_firstorder_InterquartileRange': 72.0,
#   'original_firstorder_Kurtosis': 28.5995401266992,
#   'original_firstorder_Maximum': 803.0,
#   'original_firstorder_Mean': -862.6471760179198,
#   'original_firstorder_MeanAbsoluteDeviation': 61.28510801510226,
#   'original_firstorder_Median': -887.0,
#   'original_firstorder_Minimum': -1024.0,
#   'original_firstorder_Range': 1827.0,
#   'original_firstorder_RobustMeanAbsoluteDeviation': 32.08949299219851,
#   'original_firstorder_RootMeanSquared': 868.77620508413,
#   'original_firstorder_Skewness': 4.07091875797922,
#   'original_firstorder_TotalEnergy': 1306654750677.71,
#   'original_firstorder_Uniformity': 0.13210362743138873,
#   'original_firstorder_Variance': 10611.944228690412,
#   'original_glrlm_GrayLevelNonUniformity': 830466.9055762575,
#   'original_glrlm_GrayLevelNonUniformityNormalized': 0.11982205638749185,
#   'original_glrlm_GrayLevelVariance': 19.450692123279683,
#   'original_glrlm_HighGrayLevelRunEmphasis': 73.3825656157694,
#   'original_glrlm_LongRunEmphasis': 2.1318836348855355,
#   'original_glrlm_LongRunHighGrayLevelEmphasis': 119.7749068808032,
#   'original_glrlm_LongRunLowGrayLevelEmphasis': 0.08565754801183585,
#   'original_glrlm_LowGrayLevelRunEmphasis': 0.03483939844977375,
#   'original_glrlm_RunEntropy': 4.49223393842587,
#   'original_glrlm_RunLengthNonUniformity': 4455134.829220257,
#   'original_glrlm_RunLengthNonUniformityNormalized': 0.6411172121887354,
#   'original_glrlm_RunPercentage': 0.7716863674421638,
#   'original_glrlm_RunVariance': 0.44020005496924175,
#   'original_glrlm_ShortRunEmphasis': 0.8279921667695044,
#   'original_glrlm_ShortRunHighGrayLevelEmphasis': 65.75687223548461,
#   'original_glrlm_ShortRunLowGrayLevelEmphasis': 0.027564852397263452,
#   'original_ngtdm_Busyness': 929.5792489657994,
#   'original_ngtdm_Coarseness': 1.2573761209199627e-06,
#   'original_ngtdm_Complexity': 3865.726988977672,
#   'original_ngtdm_Contrast': 0.006079580868158411,
#   'original_ngtdm_Strength': 0.023652297175941136}}

# %% [markdown]
# Union de los dos resultados

# %%
# lista de cada uno de los diccionarios
dict_list = [features for features in features_dict.values()]
# unifico los diccionarios (mismas claves, lista de valores)
features = {}
for k, v in dict_list[0].items():
    features[k] = [dic[k] for dic in dict_list]

# %%
df = pd.DataFrame(features)

# %% [markdown]
# ### Normalizo

# %%
for column in df.columns:
    df[column] = abs(df[column] /df[column].abs().max())
# Añado la mascara
df['type_mask'] = masks.keys()

# %%
df
# Out:
#               original_firstorder_10Percentile  \
# lt5_artery_2                          0.990426
# lt5_artery_5                          1.000000
# ull_artery_3                          0.997872
#
#               original_firstorder_90Percentile  original_firstorder_Energy  \
# lt5_artery_2                          0.940204                    0.217090
# lt5_artery_5                          1.000000                    1.000000
# ull_artery_3                          0.980916                    0.462177
#
#               original_firstorder_Entropy  \
# lt5_artery_2                     1.000000
# lt5_artery_5                     0.928890
# ull_artery_3                     0.948861
#
#               original_firstorder_InterquartileRange  \
# lt5_artery_2                                1.000000
# lt5_artery_5                                0.703297
# ull_artery_3                                0.791209
#
#               original_firstorder_Kurtosis  original_firstorder_Maximum  \
# lt5_artery_2                      0.480596                     0.261978
# lt5_artery_5                      1.000000                     1.000000
# ull_artery_3                      0.870623                     0.620556
#
#               original_firstorder_Mean  \
# lt5_artery_2                  0.980801
# lt5_artery_5                  1.000000
# ull_artery_3                  0.999016
#
#               original_firstorder_MeanAbsoluteDeviation  \
# lt5_artery_2                                   0.996647
# lt5_artery_5                                   1.000000
# ull_artery_3                                   0.929409
#
#               original_firstorder_Median  ...  original_glrlm_RunVariance  \
# lt5_artery_2                    0.975364  ...                    0.393769
# lt5_artery_5                    1.000000  ...                    1.000000
# ull_artery_3                    0.993281  ...                    0.696301
#
#               original_glrlm_ShortRunEmphasis  \
# lt5_artery_2                         1.000000
# lt5_artery_5                         0.902925
# ull_artery_3                         0.938768
#
#               original_glrlm_ShortRunHighGrayLevelEmphasis  \
# lt5_artery_2                                      0.935140
# lt5_artery_5                                      1.000000
# ull_artery_3                                      0.851731
#
#               original_glrlm_ShortRunLowGrayLevelEmphasis  \
# lt5_artery_2                                     0.928734
# lt5_artery_5                                     0.991674
# ull_artery_3                                     1.000000
#
#               original_ngtdm_Busyness  original_ngtdm_Coarseness  \
# lt5_artery_2                 0.460355                   1.000000
# lt5_artery_5                 1.000000                   0.244316
# ull_artery_3                 0.598260                   0.523351
#
#               original_ngtdm_Complexity  original_ngtdm_Contrast  \
# lt5_artery_2                   0.328995                 1.000000
# lt5_artery_5                   1.000000                 0.362893
# ull_artery_3                   0.638440                 0.425820
#
#               original_ngtdm_Strength     type_mask
# lt5_artery_2                 0.409209  lt5_artery_2
# lt5_artery_5                 1.000000  lt5_artery_5
# ull_artery_3                 0.903719  ull_artery_3
#
# [3 rows x 40 columns]

# %%
firstorder = [col for col in df.columns if bool(re.search('firstorder', col))]
glrlm = [col for col in df.columns if bool(re.search('glrlm', col))]
ngtdm = [col for col in df.columns if bool(re.search('ngtdm', col))]

# %%
list(masks.keys())
# Out:
# ['_lt5_artery_2', '_lt5_artery_5', 'full_artery_3']

# %% [markdown]
# # Comparación

# %% [markdown]
# ### First order comparation

# %%
plt.figure(figsize=(20,10))
plt.xticks(rotation=90)

X = firstorder
X_axis = np.arange(len(X))
axis = [-0.2,0, 0.2]

for i in range(3):
    print(list(masks.keys())[i])
    plt.bar(X_axis+axis[i], df[firstorder].iloc[i], 0.2, label = list(masks.keys())[i])

plt.xticks(X_axis, X)
plt.xlabel("Features")
plt.ylabel("max proportion")
plt.title("GLRLM features")
plt.show()
# Out:
# _lt5_artery_2
# _lt5_artery_5
# full_artery_3

# %% [markdown]
# ### GLRLM comparation

# %%
plt.figure(figsize=(20,10))
plt.xticks(rotation=90)

X = glrlm
X_axis = np.arange(len(X))
axis = [-0.2,0, 0.2]

for i in range(3):
    print(list(masks.keys())[i])
    plt.bar(X_axis+axis[i], df[glrlm].iloc[i], 0.2, label = list(masks.keys())[i])

plt.xticks(X_axis, X)
plt.xlabel("Features")
plt.ylabel("max proportion")
plt.title("GLRLM features")
plt.show()
# Out:
# _lt5_artery_2
# _lt5_artery_5
# full_artery_3

# %% [markdown]
# ### NGTDM comparation

# %%
plt.figure(figsize=(20,10))
plt.xticks(rotation=90)

X = ngtdm
X_axis = np.arange(len(X))
axis = [-0.2,0, 0.2]

for i in range(3):
    print(list(masks.keys())[i])
    plt.bar(X_axis+axis[i], df[ngtdm].iloc[i], 0.2, label = list(masks.keys())[i])

plt.xticks(X_axis, X)
plt.xlabel("Features")
plt.ylabel("max proportion")
plt.title("GLRLM features")
plt.show()
# Out:
# _lt5_artery_2
# _lt5_artery_5
# full_artery_3

# %% [markdown]
# # Representación

# %%
df = pd.DataFrame(features)
df.index = masks.keys()
samples = df.iloc[:,0:len(df.columns)-1]
samples = np.transpose(samples.to_numpy())
df
# Out:
#               original_firstorder_10Percentile  \
# lt5_artery_2                            -931.0
# lt5_artery_5                            -940.0
# ull_artery_3                            -938.0
#
#               original_firstorder_90Percentile  original_firstorder_Energy  \
# lt5_artery_2                            -739.0                3.182051e+12
# lt5_artery_5                            -786.0                1.465775e+13
# ull_artery_3                            -771.0                6.774483e+12
#
#               original_firstorder_Entropy  \
# lt5_artery_2                     3.584412
# lt5_artery_5                     3.329525
# ull_artery_3                     3.401110
#
#               original_firstorder_InterquartileRange  \
# lt5_artery_2                                    91.0
# lt5_artery_5                                    64.0
# ull_artery_3                                    72.0
#
#               original_firstorder_Kurtosis  original_firstorder_Maximum  \
# lt5_artery_2                     15.787326                        339.0
# lt5_artery_5                     32.849506                       1294.0
# ull_artery_3                     28.599540                        803.0
#
#               original_firstorder_Mean  \
# lt5_artery_2               -846.918642
# lt5_artery_5               -863.496789
# ull_artery_3               -862.647176
#
#               original_firstorder_MeanAbsoluteDeviation  \
# lt5_artery_2                                  65.718754
# lt5_artery_5                                  65.939839
# ull_artery_3                                  61.285108
#
#               original_firstorder_Median  ...  original_glrlm_RunPercentage  \
# lt5_artery_2                      -871.0  ...                      0.842485
# lt5_artery_5                      -893.0  ...                      0.726272
# ull_artery_3                      -887.0  ...                      0.771686
#
#               original_glrlm_RunVariance  original_glrlm_ShortRunEmphasis  \
# lt5_artery_2                    0.248940                         0.881999
# lt5_artery_5                    0.632198                         0.796379
# ull_artery_3                    0.440200                         0.827992
#
#               original_glrlm_ShortRunHighGrayLevelEmphasis  \
# lt5_artery_2                                     72.196382
# lt5_artery_5                                     77.203847
# ull_artery_3                                     65.756872
#
#               original_glrlm_ShortRunLowGrayLevelEmphasis  \
# lt5_artery_2                                     0.025600
# lt5_artery_5                                     0.027335
# ull_artery_3                                     0.027565
#
#               original_ngtdm_Busyness  original_ngtdm_Coarseness  \
# lt5_artery_2               715.300920               2.402550e-06
# lt5_artery_5              1553.804031               5.869806e-07
# ull_artery_3               929.579249               1.257376e-06
#
#               original_ngtdm_Complexity  original_ngtdm_Contrast  \
# lt5_artery_2                1992.053656                 0.014277
# lt5_artery_5                6054.958270                 0.005181
# ull_artery_3                3865.726989                 0.006080
#
#               original_ngtdm_Strength
# lt5_artery_2                 0.010710
# lt5_artery_5                 0.026172
# ull_artery_3                 0.023652
#
# [3 rows x 39 columns]

# %% [markdown]
# Calculo las distancias euclideas entre las diferentes muestras

# %%
from sklearn import manifold
from sklearn.metrics import euclidean_distances

similarities = euclidean_distances(samples)

seed = np.random.RandomState(seed=3)

mds = manifold.MDS(n_components=2, max_iter=5000, eps=1e-12, random_state=seed,
                   n_init=10,
                   dissimilarity="precomputed", n_jobs=1, metric=False)
pos = mds.fit_transform(similarities)

# %%
# Plot

from matplotlib.collections import LineCollection
import matplotlib.cm as cm


fig = plt.figure(1)
ax = plt.axes([0., 0., 1., 1.])

s = 100

# Tipo de arteria, pongo que muestras son de cada tipo 
_lt5_artery_2 = [0]
_lt5_artery_5 = [1]
full_artery_3 = [2]

plt.scatter(pos[_lt5_artery_2, 0], pos[_lt5_artery_2, 1], color='navy', alpha=1.0, s=s, lw=1, label='lt5_artery_2')
plt.scatter(pos[_lt5_artery_5, 0], pos[_lt5_artery_5, 1], color='turquoise', alpha=1.0, s=s, lw=1, label='lt5_artery_5')
plt.scatter(pos[full_artery_3, 0], pos[full_artery_3, 1], color='darkorange', alpha=0.5, s=s, lw=1, label='full_artery_3')

plt.legend(scatterpoints=1, loc=5, shadow=False)

similarities = similarities.max() / similarities * 100
similarities[np.isinf(similarities)] = 0
plt.show()
# Out:
# /tmp/ipykernel_116725/517333727.py:23: RuntimeWarning: divide by zero encountered in true_divide
#   similarities = similarities.max() / similarities * 100

# %% [markdown]
# ## Heat map

# %%
import seaborn as sns
corr = df.corr()

# Set up the matplotlib figure, make it big!
f, ax = plt.subplots(figsize=(15, 10))

# Draw the heatmap using seaborn
sns.heatmap(corr, vmax=.8, square=True)
plt.show()

# %% [markdown]
# ### Cluster del heatmap

# %%
dd = df.iloc[:,1:10]

pp = sns.clustermap(dd.corr(), linewidths=.5, figsize=(10,10))
_ = plt.setp(pp.ax_heatmap.get_yticklabels(), rotation=0)

plt.show()

# %%
pp = sns.clustermap(df, col_cluster=False, metric='chebyshev', z_score=1)
_ = plt.setp(pp.ax_heatmap.get_yticklabels(), rotation=0)
plt.show()
