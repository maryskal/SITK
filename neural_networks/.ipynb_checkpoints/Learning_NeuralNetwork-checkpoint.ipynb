# %% [markdown]
# # RADIOGRAFÍAS

# %% [markdown]
# ### Paquetes

# %%
# Paquetes de imagen
import SimpleITK as sitk
import skimage
from matplotlib import image
from skimage import exposure

# Paquetes de df y arrays
import numpy as np
import pandas as pd
import os
from ipywidgets import interact, fixed

# %matplotlib inline
import matplotlib.pyplot as plt

# Del propio paquete
from downloaddata import fetch_data as fdata

# OS
from os import listdir
from os.path import isfile, join

image_viewer = sitk.ImageViewer()

# %% [markdown]
# ### Logging

# %%
import logging
import sys

# Configura el logging
log_format = '[%(process)d]\t%(asctime)s %(levelname)s: %(message)s'
logging.basicConfig(format=log_format, level=logging.INFO, datefmt="%H:%M:%S",
                    handlers=[logging.StreamHandler(sys.stdout)])

# %% [markdown]
# ## Dataset

# %%
df = pd.read_csv('/home/maryskal/Documents/SITK/CXR8/Data_Entry_2017_v2020.csv')
df.head()
# Out:
#         Image Index          Finding Labels  Follow-up #  Patient ID  \
# 0  00000001_000.png            Cardiomegaly            0           1
# 1  00000001_001.png  Cardiomegaly|Emphysema            1           1
# 2  00000001_002.png   Cardiomegaly|Effusion            2           1
# 3  00000002_000.png              No Finding            0           2
# 4  00000003_001.png                  Hernia            0           3
#
#    Patient Age Patient Gender View Position  OriginalImage[Width  Height]  \
# 0           57              M            PA                 2682     2749
# 1           58              M            PA                 2894     2729
# 2           58              M            PA                 2500     2048
# 3           80              M            PA                 2500     2048
# 4           74              F            PA                 2500     2048
#
#    OriginalImagePixelSpacing[x     y]
# 0                        0.143  0.143
# 1                        0.143  0.143
# 2                        0.168  0.168
# 3                        0.171  0.171
# 4                        0.168  0.168

# %% [markdown]
# Sacamos los posibles labels que hay

# %%
labels = np.unique(df['Finding Labels'])
labels = '|'.join(labels)
labels = labels.split('|')
labels = np.unique(labels).tolist()

# %% [markdown]
# Creamos una nueva columna por cada uno de los labels

# %%
for lab in labels:
    df[lab] = pd.NA

# %% [markdown]
# Creamos una funcion para rellenar esas columnas por cada paciente

# %%
def fill_label(information, label):
    positive_labels = information.split('|')
    if label in positive_labels:
        return 1
    return 0

# %%
# map(objeto enumerado x: funcion(x, y), lista de x)
for lab in labels:
    df[lab] = list(map(lambda x: fill_label(x, lab), df['Finding Labels'].tolist()))

# %% [markdown]
# Cojo las imagenes con y sin neumonia

# %%
neumo = {'name': df['Image Index'][df.Pneumonia == 0], 'neumonia': df['Pneumonia'][df.Pneumonia == 0]}
no_neumo = {'name': df['Image Index'][df.Pneumonia == 1], 'neumonia': df['Pneumonia'][df.Pneumonia == 1]}

# %% [markdown]
# ## Imagenes

# %%
def charge_specific_img(img_name):
    '''
    Search for an specific image in all folders and charge it
    
    Parameters
    ----------
    img_name (str): name of the image
    
    Returns
    -------
    img (np.array): the image charged
    path (string): path where the image is
    '''
    subfolders = [f.path for f in os.scandir('./CXR8/images/') if f.is_dir()]
    img = np.zeros((1024,1024))
    for folder in subfolders:
        path = os.path.join(folder, 'images')
        try: 
            img = image.imread(os.path.join(path, img_name))
            dicti = {'image': img, 'name': img_name, 'path': path}
            return dicti
        except:
            logging.info('[F]\t{} not found in {}'.format(img_name, path))
    dicti = {'image': img, 'name': '', 'path': ''}
    return dicti

# %%
def charge_images(folder, number):
    '''
    Gets paths and images of an imagen folder
    
    Parameters
    ----------
    folder (string)
    number (int): number of images to get from that folder
    
    Returns
    -------
    data (dictionary): dict with paths and images as np.array
    '''
    path = os.path.join(folder, 'images')
    images_path = [f for f in listdir(path)[0:number] if isfile(join(path, f))]
    images = [image.imread(os.path.join(path, image_path)) for image_path in images_path[0:number]]
    data = {'path': images_path, 'image': images}
    return data

# %% [markdown]
# **CARGO LAS IMAGENES**

# %% [markdown]
# **a) Cargo todas las imagenes**

# %% [markdown]
# Leo todas las carpetas y cargo un numero concreto de imagenes por carpeta

# %%
# subfolders = [f.path for f in os.scandir('./CXR8/images/') if f.is_dir()]

018.png not found in ./CXR8/images/images_001/images
# [40843]	00:50:19 INFO: [F]	00010447_018.png not found in ./CXR8/images/images_002/images
# [40843]	00:50:19 INFO: [F]	00010447_018.png not found in ./CXR8/images/images_003/images
# [40843]	00:50:19 INFO: [F]	00010471_001.png not found in ./CXR8/images/images_001/images
# [40843]	00:50:19 INFO: [F]	00010471_001.png not found in ./CXR8/images/images_002/images
# [40843]	00:50:19 INFO: [F]	00010471_001.png not found in ./CXR8/images/images_003/images
# [40843]	00:50:19 INFO: [F]	00010478_006.png not found in ./CXR8/images/images_001/images
# [40843]	00:50:19 INFO: [F]	00010478_006.png not found in ./CXR8/images/images_002/images
# [40843]	00:50:19 INFO: [F]	00010478_006.png not found in ./CXR8/images/images_003/images
# [40843]	00:50:19 INFO: [F]	00010505_018.png not found in ./CXR8/images/images_001/images
# [40843]	00:50:19 INFO: [F]	00010505_018.png not found in ./CXR8/images/images_002/images
# [40843]	00:50:19 INFO: [F]	00010505_018.png not found in ./CXR8/images/images_003/images
# [40843]	00:50:19 INFO: [F]	00010509_003.png not found in ./CXR8/images/images_001/images
# [40843]	00:50:19 INFO: [F]	00010509_003.png not found in ./CXR8/images/images_002/images
# [40843]	00:50:19 INFO: [F]	00010509_003.png not found in ./CXR8/images/images_003/images
# [40843]	00:50:19 INFO: [F]	00010524_001.png not found in ./CXR8/images/images_001/images
# [40843]	00:50:19 INFO: [F]	00010524_001.png not found in ./CXR8/images/images_002/images
# [40843]	00:50:19 INFO: [F]	00010524_001.png not found in ./CXR8/images/images_003/images
# [40843]	00:50:19 INFO: [F]	00010530_028.png not found in ./CXR8/images/images_001/images
# [40843]	00:50:19 INFO: [F]	00010530_028.png not found in ./CXR8/images/images_002/images
# [40843]	00:50:19 INFO: [F]	00010530_028.png not found in ./CXR8/images/images_003/images
# [40843]	00:50:19 INFO: [F]	00010531_058.png not found in ./CXR8/images/images_001/images
# [40843]	00:50:19 INFO: [F]	00010531_058.png not found in ./CXR8/images/images_002/images
# [40843]	00:50:19 INFO: [F]	00010531_058.png not found in ./CXR8/images/images_003/images
# [40843]	00:50:19 INFO: [F]	00010531_073.png not found in ./CXR8/images/images_001/images
# [40843]	00:50:19 INFO: [F]	00010531_073.png not found in ./CXR8/images/images_002/images
# [40843]	00:50:19 INFO: [F]	00010531_073.png not found in ./CXR8/images/images_003/images
# [40843]	00:50:19 INFO: [F]	00010531_074.png not found in ./CXR8/images/images_001/images
# [40843]	00:50:19 INFO: [F]	00010531_074.png not found in ./CXR8/images/images_002/images
# [40843]	00:50:19 INFO: [F]	00010531_074.png not found in ./CXR8/images/images_003/images
# [40843]	00:50:19 INFO: [F]	00010531_075.png not found in ./CXR8/images/images_001/images
# [40843]	00:50:19 INFO: [F]	00010531_075.png not found in ./CXR8/images/images_002/images
# [40843]	00:50:19 INFO: [F]	00010531_075.png not found in ./CXR8/images/images_003/images
# [40843]	00:50:19 INFO: [F]	00010531_076.png not found in ./CXR8/images/images_001/images
# [40843]	00:50:19 INFO: [F]	00010531_076.png not found in ./CXR8/images/images_002/images
# [40843]	00:50:19 INFO: [F]	00010531_076.png not found in ./CXR8/images/images_003/images
# [40843]	00:50:19 INFO: [F]	00010531_012.png not found in ./CXR8/images/images_001/images
# [40843]	00:50:19 INFO: [F]	00010531_012.png not found in ./CXR8/images/images_002/images
# [40843]	00:50:19 INFO: [F]	00010531_012.png not found in ./CXR8/images/images_003/images
# [40843]	00:50:19 INFO: [F]	00010544_000.png not found in ./CXR8/images/images_001/images
# [40843]	00:50:19 INFO: [F]	00010544_000.png not found in ./CXR8/images/images_002/images
# [40843]	00:50:19 INFO: [F]	00010544_000.png not found in ./CXR8/images/images_003/images
# [40843]	00:50:19 INFO: [F]	00010544_007.png not found in ./CXR8/images/images_001/images
# [40843]	00:50:19 INFO: [F]	00010544_007.png not found in ./CXR8/images/images_002/images
# [40843]	00:50:19 INFO: [F]	00010544_007.png not found in ./CXR8/images/images_003/images
# [40843]	00:50:19 INFO: [F]	00010544_022.png not found in ./CXR8/images/images_001/images
# [40843]	00:50:19 INFO: [F]	00010544_022.png not found in ./CXR8/images/images_002/images
# [40843]	00:50:19 INFO: [F]	00010544_022.png not found in ./CXR8/images/images_003/images
# [40843]	00:50:19 INFO: [F]	00010544_023.png not found in ./CXR8/images/images_001/images
# [40843]	00:50:19 INFO: [F]	00010544_023.png not found in ./CXR8/images/images_002/images
# [40843]	00:50:19 INFO: [F]	00010544_023.png not found in ./CXR8/images/images_003/images
# [40843]	00:50:19 INFO: [F]	00010544_029.png not found in ./CXR8/images/images_001/images
# [40843]	00:50:19 INFO: [F]	00010544_029.png not found in ./CXR8/images/images_002/images
# [40843]	00:50:19 INFO: [F]	00010544_029.png not found in ./CXR8/images/images_003/images
# [40843]	00:50:19 INFO: [F]	00010544_031.png not found in ./CXR8/images/images_001/images
# [40843]	00:50:19 INFO: [F]	00010544_031.png not found in ./CXR8/images/images_002/images
# [40843]	00:50:19 INFO: [F]	00010544_031.png not found in ./CXR8/images/images_003/images
# [40843]	00:50:19 INFO: [F]	00010552_005.png not found in ./CXR8/images/images_001/images
# [40843]	00:50:19 INFO: [F]	00010552_005.png not found in ./CXR8/images/images_002/images
# [40843]	00:50:19 INFO: [F]	00010552_005.png not found in ./CXR8/images/images_003/images
# [40843]	00:50:19 INFO: [F]	00010586_000.png not found in ./CXR8/images/images_001/images
# [40843]	00:50:19 INFO: [F]	00010586_000.png not found in ./CXR8/images/images_002/images
# [40843]	00:50:19 INFO: [F]	00010586_000.png not found in ./CXR8/images/images_003/images
# [40843]	00:50:19 INFO: [F]	00010604_005.png not found in ./CXR8/images/images_001/images
# [40843]	00:50:19 INFO: [F]	00010604_005.png not found in ./CXR8/images/images_002/images
# [40843]	00:50:19 INFO: [F]	00010604_005.png not found in ./CXR8/images/images_003/images
# [40843]	00:50:19 INFO: [F]	00010610_003.png not found in ./CXR8/images/images_001/images
# [40843]	00:50:19 INFO: [F]	00010610_003.png not found in ./CXR8/images/images_002/images
# [40843]	00:50:19 INFO: [F]	00010610_003.png not found in ./CXR8/images/images_003/images
# [40843]	00:50:19 INFO: [F]	00010652_000.png not found in ./CXR8/images/images_001/images
# [40843]	00:50:19 INFO: [F]	00010652_000.png not found in ./CXR8/images/images_002/images
# [40843]	00:50:19 INFO: [F]	00010652_000.png not found in ./CXR8/images/images_003/images
# [40843]	00:50:19 INFO: [F]	00010652_003.png not found in ./CXR8/images/images_001/images
# [40843]	00:50:19 INFO: [F]	00010652_003.png not found in ./CXR8/images/images_002/images
# [40843]	00:50:19 INFO: [F]	00010652_003.png not found in ./CXR8/images/images_003/images
# [40843]	00:50:19 INFO: [F]	00010693_012.png not found in ./CXR8/images/images_001/images
# [40843]	00:50:19 INFO: [F]	00010693_012.png not found in ./CXR8/images/images_002/images
# [40843]	00:50:19 INFO: [F]	00010693_012.png not found in ./CXR8/images/images_003/images
# [40843]	00:50:19 INFO: [F]	00010695_012.png not found in ./CXR8/images/images_001/images
# [40843]	00:50:19 INFO: [F]	00010695_012.png not found in ./CXR8/images/images_002/images
# [40843]	00:50:19 INFO: [F]	00010695_012.png not found in ./CXR8/images/images_003/images
# [40843]	00:50:19 INFO: [F]	00010706_000.png not found in ./CXR8/images/images_001/images
# [40843]	00:50:19 INFO: [F]	00010706_000.png not found in ./CXR8/images/images_002/images
# [40843]	00:50:19 INFO: [F]	00010706_000.png not found in ./CXR8/images/images_003/images
# [40843]	00:50:19 INFO: [F]	00010761_002.png not found in ./CXR8/images/images_001/images
# [40843]	00:50:19 INFO: [F]	00010761_002.png not found in ./CXR8/images/images_002/images
# [40843]	00:50:19 INFO: [F]	00010761_002.png not found in ./CXR8/images/images_003/images
# [40843]	00:50:19 INFO: [F]	00010773_017.png not found in ./CXR8/images/images_001/images
# [40843]	00:50:19 INFO: [F]	00010773_017.png not found in ./CXR8/images/images_002/images
# [40843]	00:50:19 INFO: [F]	00010773_017.png not found in ./CXR8/images/images_003/images
# [40843]	00:50:19 INFO: [F]	00010773_020.png not found in ./CXR8/images/images_001/images
# [40843]	00:50:19 INFO: [F]	00010773_020.png not found in ./CXR8/images/images_002/images
# [40843]	00:50:19 INFO: [F]	00010773_020.png not found in ./CXR8/images/images_003/images
# [40843]	00:50:19 INFO: [F]	00010773_019.png not found in ./CXR8/images/images_001/images
# [40843]	00:50:19 INFO: [F]	00010773_019.png not found in ./CXR8/images/images_002/images
# [40843]	00:50:19 INFO: [F]	00010773_019.png not found in ./CXR8/images/images_003/images
# [40843]	00:50:19 INFO: [F]	00010780_007.png not found in ./CXR8/images/images_001/images
# [40843]	00:50:19 INFO: [F]	00010780_007.png not found in ./CXR8/images/images_002/images
# [40843]	00:50:19 INFO: [F]	00010780_007.png not found in ./CXR8/images/images_003/images
# [40843]	00:50:19 INFO: [F]	00010790_005.png not found in ./CXR8/images/images_001/images
# [40843]	00:50:19 INFO: [F]	00010790_005.png not found in ./CXR8/images/images_002/images
# [40843]	00:50:19 INFO: [F]	00010790_005.png not found in ./CXR8/images/images_003/images
# [40843]	00:50:19 INFO: [F]	00010805_010.png not found in ./CXR8/images/images_001/images
# [40843]	00:50:19 INFO: [F]	00010805_010.png not found in ./CXR8/images/images_002/images
# [40843]	00:50:19 INFO: [F]	00010805_010.png not found in ./CXR8/images/images_003/images
# [40843]	00:50:19 INFO: [F]	00010805_013.png not found in ./CXR8/images/images_001/images
# [40843]	00:50:19 INFO: [F]	00010805_013.png not found in ./CXR8/images/images_002/images
# [40843]	00:50:19 INFO: [F]	00010805_013.png not found in ./CXR8/images/images_003/images
# [40843]	00:50:19 INFO: [F]	00010805_021.png not found in ./CXR8/images/images_001/images
# [40843]	00:50:19 INFO: [F]	00010805_021.png not found in ./CXR8/images/images_002/images
# [40843]	00:50:19 INFO: [F]	00010805_021.png not found in ./CXR8/images/images_003/images
# [40843]	00:50:19 INFO: [F]	00010805_042.png not found in ./CXR8/images/images_001/images
# [40843]	00:50:19 INFO: [F]	00010805_042.png not found in ./CXR8/images/images_002/images
# [40843]	00:50:19 INFO: [F]	00010805_042.png not found in ./CXR8/images/images_003/images
# [40843]	00:50:19 INFO: [F]	00010805_047.png not found in ./CXR8/images/images_001/images
# [40843]	00:50:19 INFO: [F]	00010805_047.png not found in ./CXR8/images/images_002/images
# [40843]	00:50:19 INFO: [F]	00010805_047.png not found in ./CXR8/images/images_003/images
# [40843]	00:50:19 INFO: [F]	00010828_023.png not found in ./CXR8/images/images_001/images
# [40843]	00:50:19 INFO: [F]	00010828_023.png not found in ./CXR8/images/images_002/images
# [40843]	00:50:19 INFO: [F]	00010828_023.png not found in ./CXR8/images/images_003/images
# [40843]	00:50:19 INFO: [F]	00010924_003.png not found in ./CXR8/images/images_001/images
# [40843]	00:50:19 INFO: [F]	00010924_003.png not found in ./CXR8/images/images_002/images
# [40843]	00:50:19 INFO: [F]	00010924_003.png not found in ./CXR8/images/images_003/images
# [40843]	00:50:19 INFO: [F]	00010943_000.png not found in ./CXR8/images/images_001/images
# [40843]	00:50:19 INFO: [F]	00010943_000.png not found in ./CXR8/images/images_002/images
# [40843]	00:50:19 INFO: [F]	00010943_000.png not found in ./CXR8/images/images_003/images
# [40843]	00:50:19 INFO: [F]	00011020_000.png not found in ./CXR8/images/images_001/images
# [40843]	00:50:19 INFO: [F]	00011020_000.png not found in ./CXR8/images/images_002/images
# [40843]	00:50:19 INFO: [F]	00011020_000.png not found in ./CXR8/images/images_003/images
# [40843]	00:50:19 INFO: [F]	00011097_002.png not found in ./CXR8/images/images_001/images
# [40843]	00:50:19 INFO: [F]	00011097_002.png not found in ./CXR8/images/images_002/images
# [40843]	00:50:19 INFO: [F]	00011097_002.png not found in ./CXR8/images/images_003/images

# %%
neumonias = [*list(neumo['neumonia'][0:n]), *list(no_neumo['neumonia'][0:n])]

# %%
all_images = {'name': names, 'image': images, 'neumonia': neumonias}

# %%
all_images = pd.DataFrame(all_images)

# %%
borrar = list(all_images.index[all_images.name == ''])

# %%
logging.info('[F]\tdelete {} with neumonia in {}'.format(len(borrar), np.sum(all_images['neumonia'][borrar])))
# Out:
# [40843]	00:50:19 INFO: [F]	delete 212 with neumonia in 212

# %%
all_images = all_images.drop(labels=borrar, axis=0)

# %% [markdown]
# **AÑADO LA TERCERA DIMENSION**

# %% [markdown]
# Transformo una array de 2 dimensiones (si es de mas lo reduzco), en uno de 3, para la red

# %%
def array_3_dimension(arr):
    if len(arr.shape) > 2:
        arr = arr[...,1]
    arr = np.expand_dims(arr, axis = -1)
    return arr

# %%
all_images['image'] = list(map(lambda x: array_3_dimension(x), all_images['image']))

# %% [markdown]
# ## Filtros sobre imágenes

# %% [markdown]
# ### Downsample

# %%
def downsample(array, quantity):
    ds_array = array/255
    r = skimage.measure.block_reduce(ds_array[:,:,0],
                                     (quantity, quantity),
                                     np.mean)
    r = np.expand_dims(r, axis = -1)
    return r

# %% [markdown]
# ### Equalizar

# %%
def equalizar(imgArr):
    '''
    Equalize a image
    
    Parameters
    ----------
    img (np.array)
    
    Returns
    -------
    img (np.array)    
    '''
   
    # Contrast stretching
    p2, p98 = np.percentile(imgArr, (2, 98))
    img_rescale = exposure.rescale_intensity(imgArr, in_range=(p2, p98))

    # Equalization
    img_eq = exposure.equalize_hist(imgArr)

    # Adaptive Equalization
    img_adapteq = exposure.equalize_adapthist(imgArr, clip_limit=0.03)
        
    return img_adapteq

# %% [markdown]
# **HAGO DOWNSAMPLING Y ECUALIZO**

# %%
all_images['down'] = list(map(lambda x: downsample(x, 2), all_images['image']))
all_images['equalizado'] = list(map(lambda x: equalizar(x), all_images['down']))
# Out:
# /home/maryskal/anaconda3/envs/acil_init/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel, or set channel_axis.
#   return func(*args, **kwargs)

# %% [markdown]
# ## Red neuronal

# %%
import seaborn as sns

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout 
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam

from sklearn.metrics import classification_report,confusion_matrix
from sklearn.model_selection import train_test_split

import tensorflow as tf

import cv2
# Out:
# 2022-06-03 00:50:37.639232: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-06-03 00:50:37.639305: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %% [markdown]
# Defino el modelo

# %%
shape = all_images['equalizado'][0].shape

model = Sequential()
model.add(Conv2D(32,3,padding="same", activation="relu", input_shape=shape))
model.add(MaxPool2D())

model.add(Conv2D(64, 3, padding="same", activation="relu"))
model.add(MaxPool2D())

model.add(Conv2D(128, 3, padding="same", activation="relu"))
model.add(MaxPool2D())
model.add(Dropout(0.4))

model.add(Flatten())
model.add(Dense(128,activation="relu"))
model.add(Dense(2, activation="softmax"))

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 512, 512, 32)      320
#
#  max_pooling2d_6 (MaxPooling  (None, 256, 256, 32)     0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 256, 256, 64)      18496
#
#  max_pooling2d_7 (MaxPooling  (None, 128, 128, 64)     0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 128, 128, 128)     73856
#
#  max_pooling2d_8 (MaxPooling  (None, 64, 64, 128)      0
#  2D)
#
#  dropout_2 (Dropout)         (None, 64, 64, 128)       0
#
#  flatten_2 (Flatten)         (None, 524288)            0
#
#  dense_4 (Dense)             (None, 128)               67108992
#
#  dense_5 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 67,201,922
# Trainable params: 67,201,922
# Non-trainable params: 0
# _________________________________________________________________

# %%
opt = Adam(lr=0.000001)
model.compile(optimizer = opt , loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True) , metrics = ['accuracy'])

# %% [markdown]
# Cojo X e Y. X lo paso por el filtro de equalizar

# %%
X = np.stack(all_images['equalizado'], axis = 0)
Y = np.stack(all_images['neumonia'], axis = 0)

# %% [markdown]
# Divido en train y test

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.33, random_state=42, stratify=Y)

# %% [markdown]
# Normalizo los datos

# %%
X_train = X_train / 255
X_test = X_test / 255

# X_train.reshape(-1, img_size, img_size, 1)
# Y_train = Y_train

# X_test.reshape(-1, img_size, img_size, 1)
# Y_test = Y_test

# %% [markdown]
# Aumento del train data

# %% [markdown]
# datagen = ImageDataGenerator(
#         featurewise_center=False,  # set input mean to 0 over the dataset
#         samplewise_center=False,  # set each sample mean to 0
#         featurewise_std_normalization=False,  # divide inputs by std of the dataset
#         samplewise_std_normalization=False,  # divide each input by its std
#         zca_whitening=False,  # apply ZCA whitening
#         rotation_range = 30,  # randomly rotate images in the range (degrees, 0 to 180)
#         zoom_range = 0.2, # Randomly zoom image
#         width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
#         height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
#         horizontal_flip = True,  # randomly flip images
#         vertical_flip=False)  # randomly flip images
#
#
# datagen.fit(x_train)

# %% [markdown]
# Entreno el modelo

# %%
history = model.fit(X_train,Y_train, batch_size = 50, epochs = 10 , validation_data = (X_test, Y_test))
# Out:
# Epoch 1/10
# 11/11 [==============================] - 14s 1s/step - loss: 0.6931 - accuracy: 0.5142 - val_loss: 0.6931 - val_accuracy: 0.6360
# Epoch 2/10
# 11/11 [==============================] - 16s 1s/step - loss: 0.6931 - accuracy: 0.6376 - val_loss: 0.6930 - val_accuracy: 0.6360
# Epoch 3/10
# 11/11 [==============================] - 18s 2s/step - loss: 0.6930 - accuracy: 0.6338 - val_loss: 0.6929 - val_accuracy: 0.6360
# Epoch 4/10
# 11/11 [==============================] - 18s 2s/step - loss: 0.6929 - accuracy: 0.6338 - val_loss: 0.6928 - val_accuracy: 0.6360
# Epoch 5/10
# 11/11 [==============================] - 17s 2s/step - loss: 0.6927 - accuracy: 0.6338 - val_loss: 0.6926 - val_accuracy: 0.6360
# Epoch 6/10
# 11/11 [==============================] - 17s 2s/step - loss: 0.6926 - accuracy: 0.6338 - val_loss: 0.6924 - val_accuracy: 0.6360
# Epoch 7/10
# 11/11 [==============================] - 17s 2s/step - loss: 0.6924 - accuracy: 0.6338 - val_loss: 0.6922 - val_accuracy: 0.6360
# Epoch 8/10
# 11/11 [==============================] - 18s 2s/step - loss: 0.6922 - accuracy: 0.6338 - val_loss: 0.6920 - val_accuracy: 0.6360
# Epoch 9/10
# 11/11 [==============================] - 19s 2s/step - loss: 0.6919 - accuracy: 0.6338 - val_loss: 0.6917 - val_accuracy: 0.6360
# Epoch 10/10
# 11/11 [==============================] - 17s 2s/step - loss: 0.6916 - accuracy: 0.6338 - val_loss: 0.6913 - val_accuracy: 0.6360

# %%
# model.fit?

# %% [markdown]
# Compruebo el modelo

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(10)

plt.figure(figsize=(15, 15))
plt.subplot(2, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(2, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
