# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import SimpleITK as sitk

# %% [markdown]
# # Datos

# %%
path = 'D:/Users/maryskal/Documents/SITK/CXR8/images/images_001'
path = '/home/mr1142/Documents/Data/seg_prueba'

# %%
masks_name = os.listdir(os.path.join(path, 'mascara'))

# %%
pixels = 256

# %%
def read_img(path, folder, img):
    img = cv2.imread(os.path.join(path, folder, img))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    img = cv2.resize(img, (pixels, pixels))
    img = np.expand_dims(img, axis=-1)
    return img

# %%
def normalize(img):
    return (img - np.mean(img))/ np.std(img)

# %%
def binarize(img):
    img[img>0] = 1
    return img

# %%
masks = np.zeros((len(masks_name), pixels,pixels,1))
for i in range(len(masks_name)):
    masks[i, ...] = binarize(read_img(path, 'mascara', masks_name[i]))

# %%
images = np.zeros((len(masks_name), pixels,pixels,1))
for i in range(len(masks_name)):
    images[i, ...] = normalize(read_img(path, 'images', masks_name[i]))

# %%
r = np.random.randint(0, len(images))
plt.figure(figsize=(10, 10))
plt.subplot(1,2,1)
plt.imshow(masks[r])
plt.subplot(1,2,2)
plt.imshow(images[r])
plt.show()

# %%
images.shape
# Out:
# (80, 256, 256, 1)

# %% [markdown]
# ## Selección de pesos por imagen

# %% [markdown]
# Vamos a ver las imagenes y elegir las de peor calidad para darles más peso

# %%
# for i in range(len(images)):
#     print(i)
#     plt.figure(figsize=(100, 100))
#     plt.subplot(1,len(images),i+1)
#     plt.imshow(images[i])
#     plt.show()

# %%
bad_quality = [14,15,34] + [i for i in range(39,56)] + [65,73,76,77]

# %%
importance = np.array([1 if i in bad_quality else 0.75 for i in range(len(images))])

# %% [markdown]
# # Aumento de datos

# %%
import imutils

# %%
def augment(input_image, input_mask):
    r = np.random.randint(-60,60)
    # Random flipping of the image and mask
    input_image = np.expand_dims(imutils.rotate(input_image, angle=r),  axis=-1)
    input_mask = np.expand_dims(imutils.rotate(input_mask, angle=r), axis=-1)
    return input_image, input_mask

# %% [markdown]
# Nuevas imagenes con rotacion random

# %%
new_img = np.zeros((len(masks_name), pixels,pixels,1))
new_mask = np.zeros((len(masks_name), pixels,pixels,1))
for i in range(len(masks_name)):
    img, mask = augment(images[i], masks[i])
    new_img[i, ...] = img
    new_mask[i,...] = mask

# %%
images = np.concatenate((new_img, images), axis = 0)
masks = np.concatenate((new_mask, masks), axis = 0)
importance = np.concatenate((importance, importance), axis=0)

# %%
r = np.random.randint(0, len(images))
plt.figure(figsize=(10, 10))
plt.subplot(1,2,1)
plt.imshow(images[r])
plt.subplot(1,2,2)
plt.imshow(masks[r])
plt.show()

# %%
images.shape
# Out:
# (160, 256, 256, 1)

# %%
masks.shape
# Out:
# (160, 256, 256, 1)

# %% [markdown]
# # U-Net

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow_datasets as tfds

# %%
os.environ['CUDA_VISIBLE_DEVICES'] = '0'

# %%
def double_conv_block(x, n_filters):
    # Conv2D then eLU activation
    x = layers.Conv2D(n_filters, 3, padding = "same", activation = "elu", kernel_initializer = "he_normal")(x)
    # Conv2D then eLU activation
    x = layers.Conv2D(n_filters, 3, padding = "same", activation = "elu", kernel_initializer = "he_normal")(x)
    return x


def downsample_block(x, n_filters):
    f = double_conv_block(x, n_filters)
    p = layers.MaxPool2D(2)(f)
    p = layers.Dropout(0.3)(p)
    return f, p


def upsample_block(x, conv_features, n_filters):
    # upsample
    x = layers.Conv2DTranspose(n_filters, 3, 2, padding="same")(x)
    # concatenate
    x = layers.concatenate([x, conv_features])
    # dropout
    x = layers.Dropout(0.3)(x)
    # Conv2D twice with eLU activation
    x = double_conv_block(x, n_filters)
    return x

# %%
def build_unet_model():
     # inputs
    inputs = layers.Input(shape=(pixels,pixels,1))

    # encoder: contracting path - downsample
    # 1 - downsample
    f1, p1 = downsample_block(inputs, 64)
    # 2 - downsample
    f2, p2 = downsample_block(p1, 128)
    # 3 - downsample
    f3, p3 = downsample_block(p2, 256)
    # 4 - downsample
    f4, p4 = downsample_block(p3, 512)

    # 5 - bottleneck
    bottleneck = double_conv_block(p4, 1024)

    # decoder: expanding path - upsample
    # 6 - upsample
    u6 = upsample_block(bottleneck, f4, 512)
    # 7 - upsample
    u7 = upsample_block(u6, f3, 256)
    # 8 - upsample
    u8 = upsample_block(u7, f2, 128)
    # 9 - upsample
    u9 = upsample_block(u8, f1, 64)

    # outputs
    outputs = layers.Conv2D(3, 1, padding="same", activation = "softmax")(u9)

    # unet model with Keras Functional API
    unet_model = tf.keras.Model(inputs, outputs, name="U-Net")

    return unet_model

# %%
unet_model = build_unet_model()

# %%
unet_model.summary()
# Out:
# Model: "U-Net"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 1) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 256, 256, 64) 640         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 256, 256, 64) 36928       conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 128, 128, 64) 0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 128, 128, 64) 0           max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 128, 128, 128 73856       dropout[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 128, 128, 128 147584      conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 128)  0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 64, 64, 128)  0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 64, 256)  295168      dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 64, 64, 256)  590080      conv2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 256)  0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 32, 32, 256)  0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 512)  1180160     dropout_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 512)  2359808     conv2d_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 512)  0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 16, 16, 512)  0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 1024) 4719616     dropout_3[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 1024) 9438208     conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 32, 32, 512)  4719104     conv2d_9[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 32, 32, 1024) 0           conv2d_transpose[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 32, 32, 1024) 0           concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 32, 32, 512)  4719104     dropout_4[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 32, 32, 512)  2359808     conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 64, 64, 256)  1179904     conv2d_11[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 64, 64, 512)  0           conv2d_transpose_1[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 64, 64, 512)  0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 64, 64, 256)  1179904     dropout_5[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 64, 64, 256)  590080      conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 128, 128, 128 295040      conv2d_13[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 128, 128, 256 0           conv2d_transpose_2[0][0]
#                                                                  conv2d_3[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 128, 128, 256 0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 128, 128, 128 295040      dropout_6[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 128, 128, 128 147584      conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 256, 256, 64) 73792       conv2d_15[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 256, 256, 128 0           conv2d_transpose_3[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 256, 256, 128 0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 256, 256, 64) 73792       dropout_7[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 256, 256, 64) 36928       conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 256, 256, 3)  195         conv2d_17[0][0]
# ==================================================================================================
# Total params: 34,512,323
# Trainable params: 34,512,323
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
import datetime
log_dir = "/home/mr1142/Documents/Data/logs/fit/" + 'U-Net1_' + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir,
                                                      update_freq='batch',
                                                      histogram_freq=1)

checkpoint_path = "/home/mr1142/Documents/Data/model_weights/" + 'U-Net1/' + datetime.datetime.now().strftime("%Y%m%d-%H%M%S") + '/{epoch:04d}.ckpt'
checkpoint_dir = os.path.dirname(checkpoint_path)
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,
                                                 verbose=1)

early_stop = tf.keras.callbacks.EarlyStopping(monitor="val_loss", restore_best_weights=True, patience = 5)

# %%
datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    featurewise_center=True,
    featurewise_std_normalization=True,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    validation_split=0.2)
datagen.fit(images)

# %%
unet_model.compile(optimizer=tf.keras.optimizers.Adam(),
                  loss="sparse_categorical_crossentropy",
                  metrics=["accuracy", "mean_squared_error"])

# %%
batch = 8
epoch = 500

# %%
history = unet_model.fit(images,masks,
                         batch_size = batch,
                         epochs = epoch,
                         callbacks = [tensorboard_callback, cp_callback, early_stop],
                         sample_weight = importance,
                         shuffle = True,
                         validation_split = 0.2)
# Out:
# Epoch 1/500
# 16/16 [==============================] - 47s 474ms/step - loss: 1.6800 - accuracy: 0.4977 - mean_squared_error: 0.3872 - val_loss: 0.6017 - val_accuracy: 0.6153 - val_mean_squared_error: 0.3615
# Epoch 2/500
# 16/16 [==============================] - 5s 313ms/step - loss: 0.7270 - accuracy: 0.5788 - mean_squared_error: 0.3652 - val_loss: 0.5216 - val_accuracy: 0.6599 - val_mean_squared_error: 0.3320
# Epoch 3/500
# 16/16 [==============================] - 5s 323ms/step - loss: 0.5222 - accuracy: 0.6371 - mean_squared_error: 0.3367 - val_loss: 0.4283 - val_accuracy: 0.7264 - val_mean_squared_error: 0.3770
# Epoch 4/500
# 16/16 [==============================] - 5s 330ms/step - loss: 0.4463 - accuracy: 0.7388 - mean_squared_error: 0.3776 - val_loss: 0.8707 - val_accuracy: 0.5745 - val_mean_squared_error: 0.3655
# Epoch 5/500
# 16/16 [==============================] - 5s 344ms/step - loss: 0.5413 - accuracy: 0.6344 - mean_squared_error: 0.3434 - val_loss: 0.4516 - val_accuracy: 0.7070 - val_mean_squared_error: 0.3798
500
# 16/16 [==============================] - 5s 319ms/step - loss: 0.0476 - accuracy: 0.9711 - mean_squared_error: 0.4612 - val_loss: 0.0684 - val_accuracy: 0.9675 - val_mean_squared_error: 0.4680
# Epoch 70/500
# 16/16 [==============================] - 5s 321ms/step - loss: 0.0443 - accuracy: 0.9730 - mean_squared_error: 0.4619 - val_loss: 0.0824 - val_accuracy: 0.9634 - val_mean_squared_error: 0.4674
# Epoch 71/500
# 16/16 [==============================] - 5s 321ms/step - loss: 0.0488 - accuracy: 0.9697 - mean_squared_error: 0.4613 - val_loss: 0.0810 - val_accuracy: 0.9647 - val_mean_squared_error: 0.4677
# Epoch 72/500
# 16/16 [==============================] - 5s 323ms/step - loss: 0.0468 - accuracy: 0.9711 - mean_squared_error: 0.4627 - val_loss: 0.0752 - val_accuracy: 0.9679 - val_mean_squared_error: 0.4701
# Epoch 73/500
# 16/16 [==============================] - 5s 316ms/step - loss: 0.0428 - accuracy: 0.9733 - mean_squared_error: 0.4647 - val_loss: 0.0851 - val_accuracy: 0.9652 - val_mean_squared_error: 0.4693
# Epoch 74/500
# 16/16 [==============================] - 5s 320ms/step - loss: 0.0407 - accuracy: 0.9743 - mean_squared_error: 0.4621 - val_loss: 0.0715 - val_accuracy: 0.9681 - val_mean_squared_error: 0.4697
# Epoch 75/500
# 16/16 [==============================] - 5s 322ms/step - loss: 0.0413 - accuracy: 0.9743 - mean_squared_error: 0.4593 - val_loss: 0.0874 - val_accuracy: 0.9650 - val_mean_squared_error: 0.4705
# Epoch 76/500
# 16/16 [==============================] - 5s 321ms/step - loss: 0.0397 - accuracy: 0.9750 - mean_squared_error: 0.4638 - val_loss: 0.0788 - val_accuracy: 0.9677 - val_mean_squared_error: 0.4709
# Epoch 77/500
# 16/16 [==============================] - 5s 319ms/step - loss: 0.0395 - accuracy: 0.9748 - mean_squared_error: 0.4632 - val_loss: 0.0725 - val_accuracy: 0.9695 - val_mean_squared_error: 0.4714
# Epoch 78/500
# 16/16 [==============================] - 5s 320ms/step - loss: 0.0363 - accuracy: 0.9757 - mean_squared_error: 0.4646 - val_loss: 0.0808 - val_accuracy: 0.9683 - val_mean_squared_error: 0.4716
# Epoch 79/500
# 16/16 [==============================] - 5s 320ms/step - loss: 0.0369 - accuracy: 0.9768 - mean_squared_error: 0.4640 - val_loss: 0.0785 - val_accuracy: 0.9680 - val_mean_squared_error: 0.4715
# Epoch 80/500
# 16/16 [==============================] - 5s 322ms/step - loss: 0.0367 - accuracy: 0.9759 - mean_squared_error: 0.4641 - val_loss: 0.0776 - val_accuracy: 0.9684 - val_mean_squared_error: 0.4712
# Epoch 81/500
# 16/16 [==============================] - 5s 321ms/step - loss: 0.0357 - accuracy: 0.9767 - mean_squared_error: 0.4642 - val_loss: 0.0720 - val_accuracy: 0.9692 - val_mean_squared_error: 0.4716
# Epoch 82/500
# 16/16 [==============================] - 5s 321ms/step - loss: 0.0393 - accuracy: 0.9751 - mean_squared_error: 0.4626 - val_loss: 0.0980 - val_accuracy: 0.9649 - val_mean_squared_error: 0.4708
# Epoch 83/500
# 16/16 [==============================] - 5s 330ms/step - loss: 0.0382 - accuracy: 0.9751 - mean_squared_error: 0.4639 - val_loss: 0.0762 - val_accuracy: 0.9671 - val_mean_squared_error: 0.4698
# Epoch 84/500
# 16/16 [==============================] - 5s 320ms/step - loss: 0.0400 - accuracy: 0.9750 - mean_squared_error: 0.4624 - val_loss: 0.0708 - val_accuracy: 0.9702 - val_mean_squared_error: 0.4718
# Epoch 85/500
# 16/16 [==============================] - 5s 322ms/step - loss: 0.0372 - accuracy: 0.9760 - mean_squared_error: 0.4623 - val_loss: 0.0790 - val_accuracy: 0.9688 - val_mean_squared_error: 0.4721
# Epoch 86/500
# 16/16 [==============================] - 5s 319ms/step - loss: 0.0349 - accuracy: 0.9775 - mean_squared_error: 0.4659 - val_loss: 0.0945 - val_accuracy: 0.9650 - val_mean_squared_error: 0.4712
# Epoch 87/500
# 16/16 [==============================] - 5s 325ms/step - loss: 0.0340 - accuracy: 0.9774 - mean_squared_error: 0.4660 - val_loss: 0.0754 - val_accuracy: 0.9699 - val_mean_squared_error: 0.4725
# Epoch 88/500
# 16/16 [==============================] - 5s 324ms/step - loss: 0.0327 - accuracy: 0.9776 - mean_squared_error: 0.4647 - val_loss: 0.0809 - val_accuracy: 0.9693 - val_mean_squared_error: 0.4724
# Epoch 89/500
# 16/16 [==============================] - 5s 324ms/step - loss: 0.0313 - accuracy: 0.9791 - mean_squared_error: 0.4652 - val_loss: 0.0862 - val_accuracy: 0.9677 - val_mean_squared_error: 0.4719
# Epoch 90/500
# 16/16 [==============================] - 5s 325ms/step - loss: 0.0320 - accuracy: 0.9782 - mean_squared_error: 0.4651 - val_loss: 0.1225 - val_accuracy: 0.9619 - val_mean_squared_error: 0.4720
# Epoch 91/500
# 16/16 [==============================] - 5s 321ms/step - loss: 0.0342 - accuracy: 0.9777 - mean_squared_error: 0.4649 - val_loss: 0.0832 - val_accuracy: 0.9691 - val_mean_squared_error: 0.4722
# Epoch 92/500
# 16/16 [==============================] - 5s 323ms/step - loss: 0.0367 - accuracy: 0.9762 - mean_squared_error: 0.4661 - val_loss: 0.0952 - val_accuracy: 0.9656 - val_mean_squared_error: 0.4714
# Epoch 93/500
# 16/16 [==============================] - 5s 321ms/step - loss: 0.0331 - accuracy: 0.9776 - mean_squared_error: 0.4648 - val_loss: 0.0875 - val_accuracy: 0.9676 - val_mean_squared_error: 0.4722
# Epoch 94/500
# 16/16 [==============================] - 5s 324ms/step - loss: 0.0299 - accuracy: 0.9793 - mean_squared_error: 0.4659 - val_loss: 0.0885 - val_accuracy: 0.9696 - val_mean_squared_error: 0.4736
# Epoch 95/500
# 16/16 [==============================] - 5s 319ms/step - loss: 0.0300 - accuracy: 0.9800 - mean_squared_error: 0.4676 - val_loss: 0.0827 - val_accuracy: 0.9696 - val_mean_squared_error: 0.4728
# Epoch 96/500
# 12/16 [=====================>........] - ETA: 1s - loss: 0.0284 - accuracy: 0.9796 - mean_squared_error: 0.4655
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-0dd841d6aec3> in <module>
#       5                          sample_weight = importance,
#       6                          shuffle = True,
# ----> 7                          validation_split = 0.2)
#
# ~/miniconda3/envs/init/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1098                 _r=1):
#    1099               callbacks.on_train_batch_begin(step)
# -> 1100               tmp_logs = self.train_function(iterator)
#    1101               if data_handler.should_sync:
#    1102                 context.async_wait()
#
# ~/miniconda3/envs/init/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     826     tracing_count = self.experimental_get_tracing_count()
#     827     with trace.Trace(self._name) as tm:
# --> 828       result = self._call(*args, **kwds)
#     829       compiler = "xla" if self._experimental_compile else "nonXla"
#     830       new_tracing_count = self.experimental_get_tracing_count()
#
# ~/miniconda3/envs/init/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     853       # In this case we have created variables on the first call, so we run the
#     854       # defunned version which is guaranteed to never create variables.
# --> 855       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     856     elif self._stateful_fn is not None:
#     857       # Release the lock early so that multiple threads can perform the call
#
# ~/miniconda3/envs/init/lib/python3.6/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2941        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2942     return graph_function._call_flat(
# -> 2943         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2944
#    2945   @property
#
# ~/miniconda3/envs/init/lib/python3.6/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1917       # No tape is watching; skip to running the function.
#    1918       return self._build_call_outputs(self._inference_function.call(
# -> 1919           ctx, args, cancellation_manager=cancellation_manager))
#    1920     forward_backward = self._select_forward_and_backward_functions(
#    1921         args,
#
# ~/miniconda3/envs/init/lib/python3.6/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     558               inputs=args,
#     559               attrs=attrs,
# --> 560               ctx=ctx)
#     561         else:
#     562           outputs = execute.execute_with_cancellation(
#
# ~/miniconda3/envs/init/lib/python3.6/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# # Validación

# %%
path = '/home/mr1142/Documents/Data/NIH/images_005'

# %%
val_names = os.listdir('/home/mr1142/Documents/Data/NIH/images_005/images')

# %%
def apply_mask(img, mask):
    mask = cv2.GaussianBlur(mask,(5,5),cv2.BORDER_DEFAULT)
    mask = cv2.cvtColor(mask, cv2.COLOR_BGR2GRAY)
    mask[mask>0.3]=1
    img[mask!=1]=0
    return img

# %%
r = np.random.randint(0, len(val_names))
img = normalize(read_img(path, 'images', val_names[r]))
mask = unet_model.predict(img[np.newaxis,...])[0,...]
plt.figure(figsize=(20, 20))
plt.subplot(1,3,1)
plt.imshow(img, cmap = 'gray')
plt.subplot(1,3,2)
plt.imshow(mask, cmap = 'gray')
plt.subplot(1,3,3)
plt.imshow(apply_mask(img, mask), cmap = 'gray')
plt.show()

# %%
unet_model.save('/home/mr1142/Documents/Data/models/unet.h5')
