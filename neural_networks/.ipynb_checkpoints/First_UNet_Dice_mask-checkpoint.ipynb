# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import SimpleITK as sitk

# %% [markdown]
# # Datos

# %%
# path = 'D:/Users/maryskal/Documents/SITK/CXR8/images/images_001'
path = '/home/mr1142/Documents/Data/segmentation'

# %%
masks_name = os.listdir(os.path.join(path, 'mascara'))

# %%
pixels = 256

# %%
def read_img(path, folder, img):
    img = cv2.imread(os.path.join(path, folder, img))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    img = cv2.resize(img, (pixels, pixels))
    img = np.expand_dims(img, axis=-1)
    return img

# %%
def normalize(img):
    return (img - np.mean(img))/ np.std(img)

# %%
def binarize(img):
    img[img>0] = 1
    return img

# %%
masks = np.zeros((len(masks_name), pixels,pixels,1))
for i in range(len(masks_name)):
    masks[i, ...] = binarize(read_img(path, 'mascara', masks_name[i]))

# %%
images = np.zeros((len(masks_name), pixels,pixels,1))
for i in range(len(masks_name)):
    images[i, ...] = normalize(read_img(path, 'images', masks_name[i]))

# %%
np.unique(masks)
# Out:
# array([0., 1.])

# %%
r = np.random.randint(0, len(images))
plt.figure(figsize=(10, 10))
plt.subplot(1,2,1)
plt.imshow(masks[r])
plt.subplot(1,2,2)
plt.imshow(images[r])
plt.show()

# %%
images.shape
# Out:
# (300, 256, 256, 1)

# %% [markdown]
# ## Selección de pesos por imagen

# %% [markdown]
# Vamos a ver las imagenes y elegir las de peor calidad para darles más peso

# %%
# for i in range(len(images)):
#     print(i)
#     plt.figure(figsize=(100, 100))
#     plt.subplot(1,len(images),i+1)
#     plt.imshow(images[i])
#     plt.show()

# %%
# bad_quality = [14,15,34] + [i for i in range(39,56)] + [65,73,76,77]

# %%
# importance = np.array([1 if i in bad_quality else 0.75 for i in range(len(images))])

# %% [markdown]
# # Aumento de datos

# %%
import imutils

# %%
def augment(input_image, input_mask):
    r = np.random.randint(-60,60)
    # Random flipping of the image and mask
    input_image = np.expand_dims(imutils.rotate(input_image, angle=r),  axis=-1)
    input_mask = np.expand_dims(imutils.rotate(input_mask, angle=r), axis=-1)
    input_mask = binarize(input_mask)
    return input_image, input_mask

# %% [markdown]
# Nuevas imagenes con rotacion random (las tengo que binarizar porque sino al rotar se modifica)

# %%
new_img = np.zeros((len(masks_name), pixels,pixels,1))
new_mask = np.zeros((len(masks_name), pixels,pixels,1))
for i in range(len(masks_name)):
    img, mask = augment(images[i], masks[i])
    new_img[i, ...] = img
    new_mask[i,...] = mask

# %%
images = np.concatenate((new_img, images), axis = 0)
masks = np.concatenate((new_mask, masks), axis = 0)
# importance = np.concatenate((importance, importance), axis=0)

# %%
r = np.random.randint(0, len(images))
plt.figure(figsize=(10, 10))
plt.subplot(1,2,1)
plt.imshow(images[r])
plt.subplot(1,2,2)
plt.imshow(masks[r])
plt.show()

# %%
images.shape
# Out:
# (600, 256, 256, 1)

# %%
masks.shape
# Out:
# (600, 256, 256, 1)

# %%
np.unique(masks)
# Out:
# array([0., 1.])

# %% [markdown]
# # U-Net

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow_datasets as tfds

# %%
os.environ['CUDA_VISIBLE_DEVICES'] = '2'

# %%
def double_conv_block(x, n_filters):
    # Conv2D then eLU activation
    x = layers.Conv2D(n_filters, 3, padding = "same", activation = "elu", kernel_initializer = "he_normal")(x)
    # Conv2D then eLU activation
    x = layers.Conv2D(n_filters, 3, padding = "same", activation = "elu", kernel_initializer = "he_normal")(x)
    return x


def downsample_block(x, n_filters):
    f = double_conv_block(x, n_filters)
    p = layers.MaxPool2D(2)(f)
    p = layers.Dropout(0.3)(p)
    return f, p


def upsample_block(x, conv_features, n_filters):
    # upsample
    x = layers.Conv2DTranspose(n_filters, 3, 2, padding="same")(x)
    # concatenate
    x = layers.concatenate([x, conv_features])
    # dropout
    x = layers.Dropout(0.3)(x)
    # Conv2D twice with eLU activation
    x = double_conv_block(x, n_filters)
    return x

# %%
def build_unet_model():
     # inputs
    inputs = layers.Input(shape=(pixels,pixels,1))

    # encoder: contracting path - downsample
    # 1 - downsample
    f1, p1 = downsample_block(inputs, 64)
    # 2 - downsample
    f2, p2 = downsample_block(p1, 128)
    # 3 - downsample
    f3, p3 = downsample_block(p2, 256)
    # 4 - downsample
    f4, p4 = downsample_block(p3, 512)

    # 5 - bottleneck
    bottleneck = double_conv_block(p4, 1024)

    # decoder: expanding path - upsample
    # 6 - upsample
    u6 = upsample_block(bottleneck, f4, 512)
    # 7 - upsample
    u7 = upsample_block(u6, f3, 256)
    # 8 - upsample
    u8 = upsample_block(u7, f2, 128)
    # 9 - upsample
    u9 = upsample_block(u8, f1, 64)

    # outputs
    outputs = layers.Conv2D(1, 1, padding="same", activation = "sigmoid")(u9)

    # unet model with Keras Functional API
    unet_model = tf.keras.Model(inputs, outputs, name="U-Net")

    return unet_model

# %%
unet_model = build_unet_model()

# %%
unet_model.summary()
# Out:
# Model: "U-Net"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 1) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 256, 256, 64) 640         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 256, 256, 64) 36928       conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 128, 128, 64) 0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 128, 128, 64) 0           max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 128, 128, 128 73856       dropout[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 128, 128, 128 147584      conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 128)  0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 64, 64, 128)  0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 64, 256)  295168      dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 64, 64, 256)  590080      conv2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 256)  0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 32, 32, 256)  0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 512)  1180160     dropout_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 512)  2359808     conv2d_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 512)  0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 16, 16, 512)  0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 1024) 4719616     dropout_3[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 1024) 9438208     conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 32, 32, 512)  4719104     conv2d_9[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 32, 32, 1024) 0           conv2d_transpose[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 32, 32, 1024) 0           concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 32, 32, 512)  4719104     dropout_4[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 32, 32, 512)  2359808     conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 64, 64, 256)  1179904     conv2d_11[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 64, 64, 512)  0           conv2d_transpose_1[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 64, 64, 512)  0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 64, 64, 256)  1179904     dropout_5[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 64, 64, 256)  590080      conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 128, 128, 128 295040      conv2d_13[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 128, 128, 256 0           conv2d_transpose_2[0][0]
#                                                                  conv2d_3[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 128, 128, 256 0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 128, 128, 128 295040      dropout_6[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 128, 128, 128 147584      conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 256, 256, 64) 73792       conv2d_15[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 256, 256, 128 0           conv2d_transpose_3[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 256, 256, 128 0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 256, 256, 64) 73792       dropout_7[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 256, 256, 64) 36928       conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 256, 256, 1)  65          conv2d_17[0][0]
# ==================================================================================================
# Total params: 34,512,193
# Trainable params: 34,512,193
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
import datetime
log_dir = "/home/mr1142/Documents/Data/logs/fit/" + 'U-Net1_dice_' + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir,
                                                      update_freq='batch',
                                                      histogram_freq=1)

checkpoint_path = "/home/mr1142/Documents/Data/model_weights/" + 'U-Net_dice/' + datetime.datetime.now().strftime("%Y%m%d-%H%M%S") + '/{epoch:04d}.ckpt'
checkpoint_dir = os.path.dirname(checkpoint_path)
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,
                                                 verbose=1)

early_stop = tf.keras.callbacks.EarlyStopping(monitor="val_loss", restore_best_weights=True, patience = 5)

# %%
from tensorflow.keras import backend as K

def dice_coef(y_true, y_pred, smooth=100):        
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    dice = (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return dice

def dice_coef_loss(y_true, y_pred):
    return 1 - dice_coef(y_true, y_pred)

# %%
unet_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate = 1e-4),
                  loss=dice_coef_loss,
                  metrics=[dice_coef])

# %%
batch = 8
epoch = 100

# %%
history = unet_model.fit(images,masks,
                         batch_size = batch,
                         epochs = epoch,
                         callbacks = [tensorboard_callback, early_stop],
                         # sample_weight = importance,
                         shuffle = True,
                         validation_split=0.2,
                         verbose = 1)
# Out:
# Epoch 1/100
# 60/60 [==============================] - 66s 337ms/step - loss: 0.4403 - dice_coef: 0.5597 - val_loss: 0.3628 - val_dice_coef: 0.6372
# Epoch 2/100
# 60/60 [==============================] - 19s 313ms/step - loss: 0.3471 - dice_coef: 0.6529 - val_loss: 0.3369 - val_dice_coef: 0.6631
# Epoch 3/100
# 60/60 [==============================] - 19s 319ms/step - loss: 0.3111 - dice_coef: 0.6889 - val_loss: 0.2169 - val_dice_coef: 0.7831
# Epoch 4/100
# 60/60 [==============================] - 19s 316ms/step - loss: 0.1975 - dice_coef: 0.8025 - val_loss: 0.1542 - val_dice_coef: 0.8458
# Epoch 5/100
# 60/60 [==============================] - 19s 316ms/step - loss: 0.1585 - dice_coef: 0.8415 - val_loss: 0.1323 - val_dice_coef: 0.8677
# Epoch 6/100
# 60/60 [==============================] - 19s 316ms/step - loss: 0.1275 - dice_coef: 0.8725 - val_loss: 0.1103 - val_dice_coef: 0.8897
# Epoch 7/100
# 60/60 [==============================] - 19s 317ms/step - loss: 0.1087 - dice_coef: 0.8913 - val_loss: 0.0923 - val_dice_coef: 0.9077
# Epoch 8/100
# 60/60 [==============================] - 19s 317ms/step - loss: 0.1073 - dice_coef: 0.8927 - val_loss: 0.1035 - val_dice_coef: 0.8965
# Epoch 9/100
# 60/60 [==============================] - 19s 317ms/step - loss: 0.1053 - dice_coef: 0.8947 - val_loss: 0.0754 - val_dice_coef: 0.9246
# Epoch 10/100
# 60/60 [==============================] - 19s 316ms/step - loss: 0.0789 - dice_coef: 0.9211 - val_loss: 0.0665 - val_dice_coef: 0.9335
# Epoch 11/100
# 60/60 [==============================] - 19s 315ms/step - loss: 0.0771 - dice_coef: 0.9229 - val_loss: 0.0804 - val_dice_coef: 0.9196
# Epoch 12/100
# 60/60 [==============================] - 19s 317ms/step - loss: 0.0712 - dice_coef: 0.9288 - val_loss: 0.0691 - val_dice_coef: 0.9309
# Epoch 13/100
# 60/60 [==============================] - 19s 316ms/step - loss: 0.0682 - dice_coef: 0.9318 - val_loss: 0.0554 - val_dice_coef: 0.9446
# Epoch 14/100
# 60/60 [==============================] - 19s 316ms/step - loss: 0.0591 - dice_coef: 0.9409 - val_loss: 0.0569 - val_dice_coef: 0.9431
# Epoch 15/100
# 60/60 [==============================] - 19s 315ms/step - loss: 0.0643 - dice_coef: 0.9357 - val_loss: 0.0597 - val_dice_coef: 0.9403
# Epoch 16/100
# 60/60 [==============================] - 19s 314ms/step - loss: 0.0584 - dice_coef: 0.9416 - val_loss: 0.0543 - val_dice_coef: 0.9457
# Epoch 17/100
# 60/60 [==============================] - 19s 317ms/step - loss: 0.0571 - dice_coef: 0.9429 - val_loss: 0.0498 - val_dice_coef: 0.9502
# Epoch 18/100
# 60/60 [==============================] - 19s 316ms/step - loss: 0.0497 - dice_coef: 0.9503 - val_loss: 0.0471 - val_dice_coef: 0.9529
# Epoch 19/100
# 60/60 [==============================] - 19s 318ms/step - loss: 0.0434 - dice_coef: 0.9566 - val_loss: 0.0501 - val_dice_coef: 0.9499
# Epoch 20/100
# 60/60 [==============================] - 19s 316ms/step - loss: 0.0482 - dice_coef: 0.9518 - val_loss: 0.0464 - val_dice_coef: 0.9536
# Epoch 21/100
# 60/60 [==============================] - 19s 316ms/step - loss: 0.0447 - dice_coef: 0.9553 - val_loss: 0.0438 - val_dice_coef: 0.9562
# Epoch 22/100
# 60/60 [==============================] - 19s 315ms/step - loss: 0.0425 - dice_coef: 0.9575 - val_loss: 0.0458 - val_dice_coef: 0.9542
# Epoch 23/100
# 60/60 [==============================] - 19s 316ms/step - loss: 0.0405 - dice_coef: 0.9595 - val_loss: 0.0405 - val_dice_coef: 0.9595
# Epoch 24/100
# 60/60 [==============================] - 19s 317ms/step - loss: 0.0376 - dice_coef: 0.9624 - val_loss: 0.0451 - val_dice_coef: 0.9549
# Epoch 25/100
# 60/60 [==============================] - 19s 316ms/step - loss: 0.0405 - dice_coef: 0.9595 - val_loss: 0.0403 - val_dice_coef: 0.9597
# Epoch 26/100
# 60/60 [==============================] - 19s 316ms/step - loss: 0.0345 - dice_coef: 0.9655 - val_loss: 0.0421 - val_dice_coef: 0.9579
# Epoch 27/100
# 60/60 [==============================] - 19s 315ms/step - loss: 0.0378 - dice_coef: 0.9622 - val_loss: 0.0394 - val_dice_coef: 0.9606
# Epoch 28/100
# 60/60 [==============================] - 19s 317ms/step - loss: 0.0344 - dice_coef: 0.9656 - val_loss: 0.0412 - val_dice_coef: 0.9588
# Epoch 29/100
# 60/60 [==============================] - 19s 315ms/step - loss: 0.0334 - dice_coef: 0.9666 - val_loss: 0.0428 - val_dice_coef: 0.9572
# Epoch 30/100
# 60/60 [==============================] - 19s 315ms/step - loss: 0.0322 - dice_coef: 0.9678 - val_loss: 0.0383 - val_dice_coef: 0.9617
# Epoch 31/100
# 60/60 [==============================] - 19s 315ms/step - loss: 0.0296 - dice_coef: 0.9704 - val_loss: 0.0376 - val_dice_coef: 0.9624
# Epoch 32/100
# 60/60 [==============================] - 19s 317ms/step - loss: 0.0310 - dice_coef: 0.9690 - val_loss: 0.0388 - val_dice_coef: 0.9612
# Epoch 33/100
# 60/60 [==============================] - 19s 315ms/step - loss: 0.0292 - dice_coef: 0.9708 - val_loss: 0.0358 - val_dice_coef: 0.9642
# Epoch 34/100
# 60/60 [==============================] - 19s 316ms/step - loss: 0.0271 - dice_coef: 0.9729 - val_loss: 0.0380 - val_dice_coef: 0.9620
# Epoch 35/100
# 60/60 [==============================] - 19s 316ms/step - loss: 0.0279 - dice_coef: 0.9721 - val_loss: 0.0372 - val_dice_coef: 0.9628
# Epoch 36/100
# 60/60 [==============================] - 19s 316ms/step - loss: 0.0277 - dice_coef: 0.9723 - val_loss: 0.0356 - val_dice_coef: 0.9644
# Epoch 37/100
# 60/60 [==============================] - 19s 315ms/step - loss: 0.0262 - dice_coef: 0.9738 - val_loss: 0.0364 - val_dice_coef: 0.9636
# Epoch 38/100
# 60/60 [==============================] - 19s 315ms/step - loss: 0.0261 - dice_coef: 0.9739 - val_loss: 0.0375 - val_dice_coef: 0.9625
# Epoch 39/100
# 60/60 [==============================] - 19s 315ms/step - loss: 0.0252 - dice_coef: 0.9748 - val_loss: 0.0426 - val_dice_coef: 0.9574
# Epoch 40/100
# 60/60 [==============================] - 19s 315ms/step - loss: 0.0268 - dice_coef: 0.9732 - val_loss: 0.0370 - val_dice_coef: 0.9630
# Epoch 41/100
# 60/60 [==============================] - 19s 316ms/step - loss: 0.0252 - dice_coef: 0.9748 - val_loss: 0.0374 - val_dice_coef: 0.9626

# %% [markdown]
# # Validación

# %%
path = '/home/mr1142/Documents/Data/NIH/images_005'

# %%
val_names = os.listdir('/home/mr1142/Documents/Data/NIH/images_005/images')

# %%
def apply_mask(img, mask):
    img[mask!=1]=0
    return img

# %%
r = np.random.randint(0, len(val_names))
img = normalize(read_img(path, 'images', val_names[r]))
mask = unet_model.predict(img[np.newaxis,...])[0,...]
plt.figure(figsize=(20, 20))
plt.subplot(1,3,1)
plt.imshow(img, cmap = 'gray')
plt.subplot(1,3,2)
plt.imshow(mask, cmap = 'gray')
plt.subplot(1,3,3)
plt.imshow(apply_mask(img, mask), cmap = 'gray')
plt.show()

# %%
unet_model.save('/home/mr1142/Documents/Data/models/unet_v2.h5')

# %%
masks.dtype

# %%
np.unique(masks)
