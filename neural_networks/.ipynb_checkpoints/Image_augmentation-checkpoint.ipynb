# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import SimpleITK as sitk

# %% [markdown]
# # Datos

# %%
# path = 'D:/Users/maryskal/Documents/SITK/CXR8/images/images_001'
path = '/home/mr1142/Documents/Data/segmentation'

# %%
masks_name = os.listdir(os.path.join(path, 'mascara'))

# %%
pixels = 256

# %%
def read_img(path, folder, img):
    img = cv2.imread(os.path.join(path, folder, img))
    img = prepare_img(img)
    return img

# %%
def prepare_img(img):
    try:
        img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    except:
        print('', end = '')
    img = cv2.resize(img, (pixels, pixels))
    img = np.expand_dims(img, axis=-1)
    return img

# %%
def normalize(img):
    return (img - np.mean(img))/ np.std(img)

# %%
def binarize(img):
    img[img>0] = 1
    return img

# %%
def clahe(img):
    clahe = cv2.createCLAHE()
    final_img = np.expand_dims(clahe.apply(img), axis=-1)
    return final_img

# %%
masks = np.zeros((len(masks_name), pixels,pixels,1))
for i in range(len(masks_name)):
    masks[i, ...] = binarize(read_img(path, 'mascara', masks_name[i]))

# %%
images = np.zeros((len(masks_name), pixels,pixels,1))
for i in range(len(masks_name)):
    images[i, ...] = normalize(read_img(path, 'images', masks_name[i]))

# %%
r = np.random.randint(0, len(images))
plt.figure(figsize=(10, 10))
plt.subplot(1,2,1)
plt.imshow(masks[r])
plt.subplot(1,2,2)
plt.imshow(images[r])
plt.show()

# %%
images.shape
# Out:
# (492, 256, 256, 1)

# %% [markdown]
# # Aumento de datos

# %%
import albumentations as A

# %%
transform = A.Compose([
    A.Rotate(limit=90, border_mode = None, interpolation=2, p=1),
    A.OneOf([
        A.RandomCrop(p= 1, width=230, height=230),
        A.Downscale(scale_min=0.5, scale_max=0.8, interpolation=0, always_apply=False, p=0.5),
        A.GridDistortion (num_steps=5, distort_limit=0.3, interpolation=2, border_mode=None, p=1),
        A.Sharpen(alpha=(0.2, 0.5), lightness=(0.5, 1.0), always_apply=False, p=0.5),
        A.MotionBlur(blur_limit=7, always_apply=False, p=0.5),
        A.ElasticTransform(alpha=0.5, sigma=50, alpha_affine=50, interpolation=1, border_mode=None, always_apply=False, p=1)
    ], p=0.8),
])

# %%
r = np.random.randint(0, len(images))
transformed = transform(image=images[r].astype(np.float32), mask=masks[r].astype(np.float32))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-388-e70cb206b264> in <module>
#       1 r = np.random.randint(0, len(images))
# ----> 2 transformed = transform(image=images[r].astype(np.float32), mask=masks[r].astype(np.float32))
#
# ~/miniconda3/envs/init/lib/python3.6/site-packages/albumentations/core/composition.py in __call__(self, force_apply, *args, **data)
#     203
#     204         for idx, t in enumerate(transforms):
# --> 205             data = t(force_apply=force_apply, **data)
#     206
#     207             if check_each_transform:
#
# ~/miniconda3/envs/init/lib/python3.6/site-packages/albumentations/core/transforms_interface.py in __call__(self, force_apply, *args, **kwargs)
#      80
#      81         if (random.random() < self.p) or self.always_apply or force_apply:
# ---> 82             params = self.get_params()
#      83
#      84             if self.targets_as_params:
#
# ~/miniconda3/envs/init/lib/python3.6/site-packages/albumentations/augmentations/crops/transforms.py in get_params(self)
#     288
#     289     def get_params(self):
# --> 290         crop_height = random.randint(self.min_max_height[0], self.min_max_height[1])
#     291         return {
#     292             "h_start": random.random(),
#
# TypeError: 'int' object is not subscriptable

# %%
r = np.random.randint(0, len(images))
plt.figure(figsize=(10, 10))
plt.subplot(1,2,1)
plt.imshow(transformed['image'], cmap = 'gray')
plt.subplot(1,2,2)
plt.imshow(transformed['mask'])
plt.show()

# %%
n = 500
new_img = np.zeros((n, pixels,pixels,1))
new_mask = np.zeros((n, pixels,pixels,1))
for i in range(n):
    r = np.random.randint(0, len(images))
    transformed = transform(image=images[r].astype(np.float32), mask=masks[r].astype(np.float32))
    new_img[i, ...] = prepare_img(transformed['image'])
    new_mask[i,...] = prepare_img(transformed['mask'])

# %%
images = np.concatenate((new_img, images), axis = 0)
masks = np.concatenate((new_mask, masks), axis = 0)
# importance = np.concatenate((importance, importance), axis=0)

# %%
r = np.random.randint(0, len(images))
plt.figure(figsize=(10, 10))
plt.subplot(1,2,1)
plt.imshow(images[r])
plt.subplot(1,2,2)
plt.imshow(masks[r])
plt.show()
