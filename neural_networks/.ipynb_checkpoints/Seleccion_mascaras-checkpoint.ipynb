# %%
import pandas as pd
import numpy as np
import os
import cv2

# %%
path = '/home/mr1142/Documents/Data/NIH'
df = pd.read_csv(os.path.join(path, 'Data_Entry_2017.csv'))
df = df.sample(frac=1).reset_index(drop = True)

# %%
random = np.random.randint(0,len(df),300)
df = df.iloc[random].reset_index(drop=True)

# %%
df.head()
# Out:
#         Image Index Finding Labels  Follow-up #  Patient ID  Patient Age  \
# 0  00030580_000.png   Infiltration            0       30580           63
# 1  00029741_000.png     No Finding            0       29741           28
# 2  00001900_004.png     No Finding            4        1900           49
# 3  00012815_005.png     No Finding            5       12815           44
# 4  00002292_002.png     No Finding            2        2292           18
#
#   Patient Gender View Position  OriginalImage[Width  Height]  \
# 0              F            PA                 2544     3056
# 1              F            PA                 2021     2021
# 2              M            AP                 2500     2048
# 3              F            PA                 2914     2991
# 4              F            PA                 2482     2991
#
#    OriginalImagePixelSpacing[x        y]  Unnamed: 11
# 0                     0.139000  0.139000          NaN
# 1                     0.194311  0.194311          NaN
# 2                     0.171000  0.171000          NaN
# 3                     0.143000  0.143000          NaN
# 4                     0.143000  0.143000          NaN

# %%
labels = np.unique(df['Finding Labels'])
labels = '|'.join(labels)
labels = labels.split('|')
labels = np.unique(labels).tolist()

# %%
def fill_label(information, label):
    positive_labels = information.split('|')
    if label in positive_labels:
        return 1
    return 0

# %%
for lab in labels:
    df[lab] = list(map(lambda x: fill_label(x, lab), df['Finding Labels'].tolist()))

# %%
for l in labels:
    print(l)
    print(sum(df[l] == 1))
# Out:
# Atelectasis
# 18
# Cardiomegaly
# 8
# Consolidation
# 15
# Edema
# 12
# Effusion
# 35
# Emphysema
# 6
# Fibrosis
# 1
# Infiltration
# 61
# Mass
# 13
# No Finding
# 163
# Nodule
# 20
# Pleural_Thickening
# 7
# Pneumonia
# 8
# Pneumothorax
# 15

# %%
list(df['Image Index'])
# Out:
# ['00030580_000.png',
#  '00029741_000.png',
#  '00001900_004.png',
#  '00012815_005.png',
#  '00002292_002.png',
#  '00013520_020.png',
#  '00015885_003.png',
#  '00017007_000.png',
#  '00009891_000.png',
#  '00009138_044.png',
#  '00013425_002.png',
#  '00005340_000.png',
#  '00000211_034.png',
#  '00019935_002.png',
#  '00002488_000.png',
#  '00022442_002.png',
#  '00018394_005.png',
#  '00003028_007.png',
#  '00011702_008.png',
#  '00006271_011.png',
#  '00005641_005.png',
#  '00013641_006.png',
#  '00004983_000.png',
#  '00020850_000.png',
#  '00015268_003.png',
#  '00011859_012.png',
#  '00018574_018.png',
#  '00019765_010.png',
#  '00012072_005.png',
#  '00025745_002.png',
#  '00019171_000.png',
#  '00030323_005.png',
#  '00010981_000.png',
#  '00022735_002.png',
#  '00029659_001.png',
#  '00013175_010.png',
#  '00020945_041.png',
#  '00016205_000.png',
#  '00025421_000.png',
#  '00022559_002.png',
#  '00026014_000.png',
#  '00017950_000.png',
#  '00008232_017.png',
#  '00009960_002.png',
#  '00025546_000.png',
#  '00009641_008.png',
#  '00021048_000.png',
#  '00020500_000.png',
#  '00006369_000.png',
#  '00006977_000.png',
#  '00027533_004.png',
#  '00008232_016.png',
#  '00009407_001.png',
#  '00015496_005.png',
#  '00029949_000.png',
#  '00016776_000.png',
#  '00019800_000.png',
#  '00006039_019.png',
#  '00014674_003.png',
#  '00018144_002.png',
#  '00013955_001.png',
#  '00018052_002.png',
#  '00022270_000.png',
#  '00029481_004.png',
#  '00007728_016.png',
#  '00013003_050.png',
#  '00028572_015.png',
#  '00013881_001.png',
#  '00012364_068.png',
#  '00012018_017.png',
#  '00019416_000.png',
#  '00022572_026.png',
#  '00021939_010.png',
#  '00005373_001.png',
#  '00030431_000.png',
#  '00018186_014.png',
#  '00028145_003.png',
#  '00010872_003.png',
#  '00004734_000.png',
#  '00016508_064.png',
#  '00018473_000.png',
#  '00013670_037.png',
#  '00017243_011.png',
#  '00000877_023.png',
#  '00018439_001.png',
#  '00021260_007.png',
#  '00028509_012.png',
#  '00029043_002.png',
#  '00016968_000.png',
#  '00017926_005.png',
#  '00028876_053.png',
#  '00014313_000.png',
#  '00006815_000.png',
#  '00006271_085.png',
#  '00007886_002.png',
#  '00008842_004.png',
#  '00010369_006.png',
#  '00005593_005.png',
#  '00006123_000.png',
#  '00001958_008.png',
#  '00005110_007.png',
#  '00029861_003.png',
#  '00001880_000.png',
#  '00024090_000.png',
#  '00002094_005.png',
#  '00021758_000.png',
#  '00013310_023.png',
#  '00018288_000.png',
#  '00000949_006.png',
#  '00022213_000.png',
#  '00000011_007.png',
#  '00006584_000.png',
#  '00017071_000.png',
#  '00019348_007.png',
#  '00014141_001.png',
#  '00004065_004.png',
#  '00014358_011.png',
#  '00016574_001.png',
#  '00012752_005.png',
#  '00022489_000.png',
#  '00003955_000.png',
#  '00011393_000.png',
#  '00013594_041.png',
#  '00022819_000.png',
#  '00003062_017.png',
#  '00013153_000.png',
#  '00014874_006.png',
#  '00002201_001.png',
#  '00017867_000.png',
#  '00003665_006.png',
#  '00008855_007.png',
#  '00018295_005.png',
#  '00023727_000.png',
#  '00005551_002.png',
#  '00006127_000.png',
#  '00006321_004.png',
#  '00001761_000.png',
#  '00027118_000.png',
#  '00013342_013.png',
#  '00023025_001.png',
#  '00016568_015.png',
#  '00018739_000.png',
#  '00014956_043.png',
#  '00007745_008.png',
#  '00024787_000.png',
#  '00019615_004.png',
#  '00017217_000.png',
#  '00006605_042.png',
#  '00019846_000.png',
#  '00004992_016.png',
#  '00019962_000.png',
#  '00014472_000.png',
#  '00010894_000.png',
#  '00019594_028.png',
#  '00005345_000.png',
#  '00012634_000.png',
#  '00018100_013.png',
#  '00028774_020.png',
#  '00013490_003.png',
#  '00018773_000.png',
#  '00001212_000.png',
#  '00029328_000.png',
#  '00000573_001.png',
#  '00015732_019.png',
#  '00019825_014.png',
#  '00014663_006.png',
#  '00008838_000.png',
#  '00020140_001.png']

# %%
path = '/home/mr1142/Documents/Data/NIH'

# %%
def charge_specific_img(img_name):
    subfolders = [f.path for f in os.scandir(path) if f.is_dir()]
    for folder in subfolders:
        try: 
            img = cv2.imread(os.path.join(folder, 'images', img_name))
            return img
        except:
            logging.info('[F]\t{} not found in {}'.format(img_name, folder))
    img = []
    return img

# %%
images = list(map(charge_specific_img, df['Image Index']))

# %%
len(images)
# Out:
# 300
