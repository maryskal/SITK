# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import SimpleITK as sitk

# %% [markdown]
# # Datos

# %%
# path = 'D:/Users/maryskal/Documents/SITK/CXR8/images/images_001'
path = '/home/mr1142/Documents/Data/segmentation'

# %%
masks_name = os.listdir(os.path.join(path, 'mascara'))

# %%
pixels = 256

# %%
def read_img(path, folder, img):
    img = cv2.imread(os.path.join(path, folder, img))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    img = cv2.resize(img, (pixels, pixels))
    img = np.expand_dims(img, axis=-1)
    return img

# %%
def normalize(img):
    return (img - np.mean(img))/ np.std(img)

# %%
def binarize(img):
    img[img>0] = 1
    return img

# %%
masks = np.zeros((len(masks_name), pixels,pixels,1))
for i in range(len(masks_name)):
    masks[i, ...] = binarize(read_img(path, 'mascara', masks_name[i]))

# %%
images = np.zeros((len(masks_name), pixels,pixels,1))
for i in range(len(masks_name)):
    images[i, ...] = normalize(read_img(path, 'images', masks_name[i]))

# %%
np.unique(masks)
# Out:
# array([0., 1.])

# %%
r = np.random.randint(0, len(images))
plt.figure(figsize=(10, 10))
plt.subplot(1,2,1)
plt.imshow(masks[r])
plt.subplot(1,2,2)
plt.imshow(images[r])
plt.show()

# %%
images.shape
# Out:
# (300, 256, 256, 1)

# %% [markdown]
# ## Selección de pesos por imagen

# %% [markdown]
# Vamos a ver las imagenes y elegir las de peor calidad para darles más peso

# %%
# for i in range(len(images)):
#     print(i)
#     plt.figure(figsize=(100, 100))
#     plt.subplot(1,len(images),i+1)
#     plt.imshow(images[i])
#     plt.show()

# %%
# bad_quality = [14,15,34] + [i for i in range(39,56)] + [65,73,76,77]

# %%
# importance = np.array([1 if i in bad_quality else 0.75 for i in range(len(images))])

# %% [markdown]
# # Aumento de datos

# %%
import imutils

# %%
def augment(input_image, input_mask):
    r = np.random.randint(-60,60)
    # Random flipping of the image and mask
    input_image = np.expand_dims(imutils.rotate(input_image, angle=r),  axis=-1)
    input_mask = np.expand_dims(imutils.rotate(input_mask, angle=r), axis=-1)
    input_mask = binarize(input_mask)
    return input_image, input_mask

# %% [markdown]
# Nuevas imagenes con rotacion random (las tengo que binarizar porque sino al rotar se modifica)

# %%
new_img = np.zeros((len(masks_name), pixels,pixels,1))
new_mask = np.zeros((len(masks_name), pixels,pixels,1))
for i in range(len(masks_name)):
    img, mask = augment(images[i], masks[i])
    new_img[i, ...] = img
    new_mask[i,...] = mask

# %%
images = np.concatenate((new_img, images), axis = 0)
masks = np.concatenate((new_mask, masks), axis = 0)
# importance = np.concatenate((importance, importance), axis=0)

# %%
r = np.random.randint(0, len(images))
plt.figure(figsize=(10, 10))
plt.subplot(1,2,1)
plt.imshow(images[r])
plt.subplot(1,2,2)
plt.imshow(masks[r])
plt.show()

# %%
images.shape
# Out:
# (600, 256, 256, 1)

# %%
masks.shape
# Out:
# (600, 256, 256, 1)

# %%
np.unique(masks)
# Out:
# array([0., 1.])

# %% [markdown]
# # Models

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow_datasets as tfds
from sklearn import model_selection

# %%
os.environ['CUDA_VISIBLE_DEVICES'] = '2'

# %%
from tensorflow.keras import backend as K

def dice_coef(y_true, y_pred, smooth=100):        
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    dice = (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return dice

def dice_coef_loss(y_true, y_pred):
    return 1 - dice_coef(y_true, y_pred)

# %% [markdown]
# ## Mask model

# %% [markdown]
# Cargo el modelo que transforma una máscara en otra igual, y me quedo solo con la priemra parte, hasta el punto de menores dimensiones

# %%
mask_model = keras.models.load_model('/home/mr1142/Documents/Data/models/unet_mask.h5', 
                                     custom_objects={"dice_coef_loss": dice_coef_loss, "dice_coef": dice_coef})

# %%
# Se crea otro modelo con el input del primero y con el output de la capa 18 del otro
sub_mask = tf.keras.Model(inputs=mask_model.input, outputs=mask_model.layers[18].output)

# %%
sub_mask.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 256, 256, 1)]     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 256, 256, 64)      640
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 256, 256, 64)      36928
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 128, 128, 64)      0
# _________________________________________________________________
# dropout (Dropout)            (None, 128, 128, 64)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 128, 128, 128)     73856
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 128, 128, 128)     147584
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 64, 64, 128)       0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64, 64, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 64, 64, 256)       295168
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 64, 64, 256)       590080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 32, 32, 256)       0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 32, 32, 512)       1180160
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 32, 32, 512)       2359808
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 16, 16, 512)       0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 16, 16, 512)       0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 16, 16, 1024)      4719616
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 16, 16, 1024)      9438208
# =================================================================
# Total params: 18,842,048
# Trainable params: 18,842,048
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Modelo completo

# %% [markdown]
# ### Funciones

# %% [markdown]
# Definimos una nueva loss, para la primera parte (mascara vs. mascara) usaremos dice, pero para la segunda utilizaremos diferencia absoluta

# %%
def MyLoss(Y_train, Y_train2, outputs1, outputs2):
    # Loss 1
    loss1 = 1-dice_coef(Y_train, outputs1)
    # Loss 2
    loss2 = abs(Y_train2 - outputs2)
    loss = loss1 + loss2
    return loss1

# %%
def double_conv_block(x, n_filters):
    # Conv2D then eLU activation
    x = layers.Conv2D(n_filters, 3, padding = "same", activation = "elu", kernel_initializer = "he_normal")(x)
    # Conv2D then eLU activation
    x = layers.Conv2D(n_filters, 3, padding = "same", activation = "elu", kernel_initializer = "he_normal")(x)
    return x


def downsample_block(x, n_filters):
    f = double_conv_block(x, n_filters)
    p = layers.MaxPool2D(2)(f)
    p = layers.Dropout(0.3)(p)
    return f, p


def upsample_block(x, conv_features, n_filters):
    # upsample
    x = layers.Conv2DTranspose(n_filters, 3, 2, padding="same")(x)
    # concatenate
    x = layers.concatenate([x, conv_features])
    # dropout
    x = layers.Dropout(0.3)(x)
    # Conv2D twice with eLU activation
    x = double_conv_block(x, n_filters)
    return x

# %% [markdown]
# ### Modelo version 1

# %% [markdown]
# Creamos el modelo introduciendo tres inputs, ya que sino era imposible ejecutar la loss.
#
# Introducimos:
#
# - La imagen de entrada
# - La capa de salida (real)
# - La capa despues de la transformación del segundo modelo
#
# Además al final del modelo añadimos la sub_mask
#
# Y añadimos la loss al final del modelo.

# %%
def build_unet_model():
    # inputs
    X_train = layers.Input(shape=(pixels,pixels,1))
    Y_train = layers.Input(shape=(pixels,pixels,1))
        
    # encoder: contracting path - downsample
    # 1 - downsample
    f1, p1 = downsample_block(X_train, 64)
    # 2 - downsample
    f2, p2 = downsample_block(p1, 128)
    # 3 - downsample
    f3, p3 = downsample_block(p2, 256)
    # 4 - downsample
    f4, p4 = downsample_block(p3, 512)

    # 5 - bottleneck
    bottleneck = double_conv_block(p4, 1024)

    # decoder: expanding path - upsample
    # 6 - upsample
    u6 = upsample_block(bottleneck, f4, 512)
    # 7 - upsample
    u7 = upsample_block(u6, f3, 256)
    # 8 - upsample
    u8 = upsample_block(u7, f2, 128)
    # 9 - upsample
    u9 = upsample_block(u8, f1, 64)

    # outputs
    outputs1 = layers.Conv2D(1, 1, padding="same", activation = "sigmoid", name = 'outputs2')(u9)
    
    # Mask 
    outputs2 = sub_mask(outputs1)
    Y_train2 = sub_mask(Y_train)
    
    unet_model = tf.keras.Model(inputs=[X_train, Y_train], outputs=[outputs2, outputs1, Y_train2], name="U-Net")
    
    unet_model.add_loss(MyLoss(Y_train, Y_train2, outputs1, outputs2))
    
    return unet_model

# %%
unet_model = build_unet_model()

# %%
unet_model.outputs
# Out:
# [<KerasTensor: shape=(None, 16, 16, 1024) dtype=float32 (created by layer 'model')>,
#  <KerasTensor: shape=(None, 256, 256, 1) dtype=float32 (created by layer 'outputs2')>]

# %%
unet_model.summary()
# Out:
# Model: "U-Net"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 1) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 256, 256, 64) 640         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 256, 256, 64) 36928       conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 128, 128, 64) 0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 128, 128, 64) 0           max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 128, 128, 128 73856       dropout[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 128, 128, 128 147584      conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 128)  0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 64, 64, 128)  0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 64, 256)  295168      dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 64, 64, 256)  590080      conv2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 256)  0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 32, 32, 256)  0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 512)  1180160     dropout_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 512)  2359808     conv2d_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 512)  0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 16, 16, 512)  0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 1024) 4719616     dropout_3[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 1024) 9438208     conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 32, 32, 512)  4719104     conv2d_9[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 32, 32, 1024) 0           conv2d_transpose[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 32, 32, 1024) 0           concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 32, 32, 512)  4719104     dropout_4[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 32, 32, 512)  2359808     conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 64, 64, 256)  1179904     conv2d_11[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 64, 64, 512)  0           conv2d_transpose_1[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 64, 64, 512)  0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 64, 64, 256)  1179904     dropout_5[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 64, 64, 256)  590080      conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 128, 128, 128 295040      conv2d_13[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 128, 128, 256 0           conv2d_transpose_2[0][0]
#                                                                  conv2d_3[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 128, 128, 256 0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 128, 128, 128 295040      dropout_6[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 128, 128, 128 147584      conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 256, 256, 64) 73792       conv2d_15[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 256, 256, 128 0           conv2d_transpose_3[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 256, 256, 128 0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 256, 256, 64) 73792       dropout_7[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 256, 256, 64) 36928       conv2d_16[0][0]
# __________________________________________________________________________________________________
# outputs2 (Conv2D)               (None, 256, 256, 1)  65          conv2d_17[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 256, 256, 1) 0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 16, 16, 1024 0
# __________________________________________________________________________________________________
# model (Functional)              (None, 16, 16, 1024) 18842048    outputs2[0][0]
# __________________________________________________________________________________________________
# tf.reshape (TFOpLambda)         (None,)              0           input_2[0][0]
# __________________________________________________________________________________________________
# tf.reshape_1 (TFOpLambda)       (None,)              0           outputs2[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply (TFOpLambda)   (None,)              0           tf.reshape[0][0]
#                                                                  tf.reshape_1[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_sum (TFOpLambda) ()                   0           tf.math.multiply[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_sum_1 (TFOpLambd ()                   0           tf.reshape[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_sum_2 (TFOpLambd ()                   0           tf.reshape_1[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_1 (TFOpLambda) ()                   0           tf.math.reduce_sum[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_1 (TFOpLam ()                   0           tf.math.reduce_sum_1[0][0]
#                                                                  tf.math.reduce_sum_2[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add (TFOpLambd ()                   0           tf.math.multiply_1[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_2 (TFOpLam ()                   0           tf.__operators__.add_1[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv (TFOpLambda)    ()                   0           tf.__operators__.add[0][0]
#                                                                  tf.__operators__.add_2[0][0]
# __________________________________________________________________________________________________
# tf.math.subtract (TFOpLambda)   ()                   0           tf.math.truediv[0][0]
# __________________________________________________________________________________________________
# add_loss (AddLoss)              ()                   0           tf.math.subtract[0][0]
# ==================================================================================================
# Total params: 53,354,241
# Trainable params: 53,354,241
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
len(unet_model.trainable_variables)
# Out:
# 66

# %%
sub_mask.trainable = False

# %%
len(unet_model.trainable_variables)
# Out:
# 46

# %% [markdown]
# ### Añadimos Y2
#
# Creamos a partir de la mascara real, el resultado que se obtendría tras pasarla por sub_mask

# %%
masks2 = list(map(lambda x: sub_mask.predict(x[np.newaxis,...]), masks))

# %%
masks2 = np.concatenate(masks2, axis=0)

# %% [markdown]
# ## Metricas

# %%
import datetime
log_dir = "/home/mr1142/Documents/Data/logs/fit/" + 'U-Net1_doble_loss_' + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir,
                                                      update_freq='batch',
                                                      histogram_freq=1)

early_stop = tf.keras.callbacks.EarlyStopping(monitor="val_loss", restore_best_weights=True, patience = 10)

# %% [markdown]
# ## Compilado

# %%
unet_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate = 1e-4),
                  loss=None)

# %%
batch = 8
epoch = 100

# %%
tf.config.run_functions_eagerly(True)

# %%
history = unet_model.fit([images,masks,masks2],
                         batch_size = batch,
                         epochs = epoch,
                         callbacks = [tensorboard_callback, early_stop],
                         # sample_weight = importance,
                         # validation_data = (X_test, Y_test),
                         shuffle = True,
                         validation_split=0.2,
                         verbose = 1)
# Out:
# /home/mr1142/miniconda3/envs/init/lib/python3.6/site-packages/tensorflow/python/data/ops/dataset_ops.py:3504: UserWarning: Even though the tf.config.experimental_run_functions_eagerly option is set, this option does not apply to tf.data functions. tf.data functions are still traced and executed as graphs.
#   "Even though the tf.config.experimental_run_functions_eagerly "
# Epoch 1/100
# 60/60 [==============================] - 95s 456ms/step - loss: 0.4497 - val_loss: 0.3329
# Epoch 2/100
# 60/60 [==============================] - 26s 437ms/step - loss: 0.2920 - val_loss: 0.1618
# Epoch 3/100
# 60/60 [==============================] - 27s 452ms/step - loss: 0.1644 - val_loss: 0.1262
# Epoch 4/100
# 60/60 [==============================] - 27s 446ms/step - loss: 0.1352 - val_loss: 0.1272
# Epoch 5/100
# 60/60 [==============================] - 27s 446ms/step - loss: 0.1259 - val_loss: 0.1018
# Epoch 6/100
# 60/60 [==============================] - 27s 445ms/step - loss: 0.1216 - val_loss: 0.0934
# Epoch 7/100
# 60/60 [==============================] - 26s 442ms/step - loss: 0.0916 - val_loss: 0.1086
# Epoch 8/100
# 60/60 [==============================] - 27s 445ms/step - loss: 0.0874 - val_loss: 0.0771
# Epoch 9/100
# 60/60 [==============================] - 26s 440ms/step - loss: 0.0827 - val_loss: 0.0713
# Epoch 10/100
# 60/60 [==============================] - 26s 442ms/step - loss: 0.0716 - val_loss: 0.0644
# Epoch 11/100
# 60/60 [==============================] - 27s 447ms/step - loss: 0.0625 - val_loss: 0.0616
# Epoch 12/100
# 60/60 [==============================] - 27s 448ms/step - loss: 0.0644 - val_loss: 0.0677
# Epoch 13/100
# 60/60 [==============================] - 27s 448ms/step - loss: 0.0595 - val_loss: 0.0550
# Epoch 14/100
# 60/60 [==============================] - 27s 449ms/step - loss: 0.0614 - val_loss: 0.0528
# Epoch 15/100
# 60/60 [==============================] - 26s 442ms/step - loss: 0.0463 - val_loss: 0.0548
# Epoch 16/100
# 60/60 [==============================] - 27s 445ms/step - loss: 0.0545 - val_loss: 0.0551
# Epoch 17/100
# 60/60 [==============================] - 26s 440ms/step - loss: 0.0487 - val_loss: 0.0469
# Epoch 18/100
# 60/60 [==============================] - 26s 442ms/step - loss: 0.0453 - val_loss: 0.0460
# Epoch 19/100
# 60/60 [==============================] - 26s 442ms/step - loss: 0.0430 - val_loss: 0.0508
# Epoch 20/100
# 60/60 [==============================] - 26s 442ms/step - loss: 0.0453 - val_loss: 0.0459
# Epoch 21/100
# 60/60 [==============================] - 26s 440ms/step - loss: 0.0392 - val_loss: 0.0446
# Epoch 22/100
# 60/60 [==============================] - 27s 443ms/step - loss: 0.0389 - val_loss: 0.0406
# Epoch 23/100
# 60/60 [==============================] - 27s 443ms/step - loss: 0.0371 - val_loss: 0.0428
# Epoch 24/100
# 60/60 [==============================] - 26s 442ms/step - loss: 0.0359 - val_loss: 0.0446
# Epoch 25/100
# 60/60 [==============================] - 26s 440ms/step - loss: 0.0367 - val_loss: 0.0407
# Epoch 26/100
# 60/60 [==============================] - 27s 443ms/step - loss: 0.0386 - val_loss: 0.0448
# Epoch 27/100
# 60/60 [==============================] - 26s 442ms/step - loss: 0.0366 - val_loss: 0.0416
# Epoch 28/100
# 60/60 [==============================] - 27s 443ms/step - loss: 0.0319 - val_loss: 0.0401
# Epoch 29/100
# 60/60 [==============================] - 27s 445ms/step - loss: 0.0339 - val_loss: 0.0413
# Epoch 30/100
# 60/60 [==============================] - 26s 441ms/step - loss: 0.0322 - val_loss: 0.0394
# Epoch 31/100
# 60/60 [==============================] - 26s 442ms/step - loss: 0.0287 - val_loss: 0.0384
# Epoch 32/100
# 60/60 [==============================] - 27s 443ms/step - loss: 0.0280 - val_loss: 0.0395
# Epoch 33/100
# 60/60 [==============================] - 26s 440ms/step - loss: 0.0277 - val_loss: 0.0387
# Epoch 34/100
# 60/60 [==============================] - 26s 441ms/step - loss: 0.0273 - val_loss: 0.0379
# Epoch 35/100
# 60/60 [==============================] - 27s 444ms/step - loss: 0.0277 - val_loss: 0.0383
# Epoch 36/100
# 60/60 [==============================] - 27s 443ms/step - loss: 0.0257 - val_loss: 0.0367
# Epoch 37/100
# 60/60 [==============================] - 26s 442ms/step - loss: 0.0239 - val_loss: 0.0383
# Epoch 38/100
# 60/60 [==============================] - 26s 440ms/step - loss: 0.0245 - val_loss: 0.0377
# Epoch 39/100
# 60/60 [==============================] - 26s 439ms/step - loss: 0.0256 - val_loss: 0.0355
# Epoch 40/100
# 60/60 [==============================] - 27s 442ms/step - loss: 0.0224 - val_loss: 0.0357
# Epoch 41/100
# 60/60 [==============================] - 26s 440ms/step - loss: 0.0237 - val_loss: 0.0355
# Epoch 42/100
# 60/60 [==============================] - 26s 441ms/step - loss: 0.0222 - val_loss: 0.0364
# Epoch 43/100
# 60/60 [==============================] - 27s 443ms/step - loss: 0.0214 - val_loss: 0.0363
# Epoch 44/100
# 60/60 [==============================] - 26s 441ms/step - loss: 0.0212 - val_loss: 0.0351
# Epoch 45/100
# 60/60 [==============================] - 26s 442ms/step - loss: 0.0208 - val_loss: 0.0379
# Epoch 46/100
# 60/60 [==============================] - 26s 441ms/step - loss: 0.0215 - val_loss: 0.0355
# Epoch 47/100
# 60/60 [==============================] - 27s 444ms/step - loss: 0.0212 - val_loss: 0.0364
# Epoch 48/100
# 60/60 [==============================] - 26s 442ms/step - loss: 0.0196 - val_loss: 0.0375
# Epoch 49/100
# 60/60 [==============================] - 27s 443ms/step - loss: 0.0192 - val_loss: 0.0356
# Epoch 50/100
# 60/60 [==============================] - 27s 443ms/step - loss: 0.0185 - val_loss: 0.0362
# Epoch 51/100
# 60/60 [==============================] - 26s 442ms/step - loss: 0.0181 - val_loss: 0.0370
# Epoch 52/100
# 60/60 [==============================] - 26s 440ms/step - loss: 0.0173 - val_loss: 0.0376
# Epoch 53/100
# 60/60 [==============================] - 27s 444ms/step - loss: 0.0177 - val_loss: 0.0372
# Epoch 54/100
# 60/60 [==============================] - 27s 442ms/step - loss: 0.0170 - val_loss: 0.0365

# %% [markdown]
# # Validación

# %%
path = '/home/mr1142/Documents/Data/NIH/images_005'

# %%
val_names = os.listdir('/home/mr1142/Documents/Data/NIH/images_005/images')

# %%
pixels = 256

# %%
def apply_mask(img, mask):
    img[mask!=1]=0
    return img

# %%
r = np.random.randint(0, len(val_names))
img = normalize(read_img(path, 'images', val_names[r]))
mask = unet_model.predict([img[np.newaxis,...], masks[0][np.newaxis,...], masks2[0][np.newaxis,...]])[1][0]

# %%
plt.imshow(mask)

# %%
r = np.random.randint(0, len(val_names))
img = normalize(read_img(path, 'images', val_names[r]))
mask = unet_model.predict([img[np.newaxis,...], masks[0][np.newaxis,...], masks2[0][np.newaxis,...]])[1][0]
plt.figure(figsize=(20, 20))
plt.subplot(1,3,1)
plt.imshow(img, cmap = 'gray')
plt.subplot(1,3,2)
plt.imshow(mask, cmap = 'gray')
plt.subplot(1,3,3)
plt.imshow(apply_mask(img, mask), cmap = 'gray')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c4d7a71e349b> in <module>
# ----> 1 r = np.random.randint(0, len(val_names))
#       2 img = normalize(read_img(path, 'images', val_names[r]))
#       3 mask = unet_model.predict([img[np.newaxis,...], masks[0][np.newaxis,...], masks2[0][np.newaxis,...]])[1][0]
#       4 plt.figure(figsize=(20, 20))
#       5 plt.subplot(1,3,1)
#
# NameError: name 'np' is not defined

# %%
unet_model.save('/home/mr1142/Documents/Data/models/unet_doble_output.h5')
