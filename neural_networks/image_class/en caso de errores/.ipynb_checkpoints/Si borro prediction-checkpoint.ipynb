# %%
import os
import re
import pandas as pd
import numpy as np

# %%
path = '/home/mr1142/Documents/Data/models/neumonia/validation_results/prediction_validation_metrics.csv'
df = pd.read_csv(path)

# %%
df
# Out:
#                                                  name     auc_0  younden_0  \
# 0   prueba_mask_IncResNet_fine-00_batch-8_lr-0001_...  0.948370   0.371251
# 1        prueba_EffNet3_fine-05_batch-8_lr--05_auc-83  0.941917   0.489427
# 2   prueba_mask_Xception_fine-08_batch-8_lr-001_au...  0.963071   0.336022
# 3      prueba_IncResNet_fine-03_batch-8_lr--05_auc-84  0.940131   0.164189
# 4      prueba_Xception_fine-00_batch-8_lr-0001_auc-93  0.979096   0.253562
# ..                                                ...       ...        ...
# 86    prueba_IncResNet_fine-03_batch-8_lr-0001_auc-94  0.973614   0.771123
# 87       prueba_EffNet3_fine-07_batch-8_lr--05_auc-86  0.974530   0.149635
# 88  prueba_mask_EffNet3_fine-05_batch-8_lr-001_auc-85  0.960647   0.592277
# 89  prueba_mask_EffNet3_fine-03_batch-8_lr--05_auc-90  0.953896   0.178411
# 90  prueba_mask_Xception_fine-05_batch-8_lr-001_au...  0.960190   0.086108
#
#     pr_max_0  pr_cut_0     auc_1  younden_1  pr_max_1  pr_cut_1     auc_2  \
# 0   0.223513  0.380699  0.844468   0.268455  0.116512  0.400980  0.903275
# 1   0.489427  0.485343  0.808271   0.343129  0.228023  0.527453  0.767000
# 2   0.336022  0.500514  0.839006   0.165104  0.143179  0.501799  0.913134
# 3   0.144204  0.150519  0.753790   0.142181  0.048032  0.362270  0.837185
# 4   0.408439  0.238946  0.816032   0.261038  0.053677  0.425123  0.876246
# ..       ...       ...       ...        ...       ...       ...       ...
# 86  0.698279  0.773190  0.893377   0.173651  0.085862  0.395070  0.933973
# 87  0.136348  0.163520  0.836722   0.351744  0.290884  0.413670  0.810089
# 88  0.501548  0.622497  0.812989   0.227295  0.128585  0.402010  0.854651
# 89  0.155638  0.192341  0.826915   0.226422  0.120830  0.403188  0.892942
# 90  0.738284  0.692263  0.696836   0.211493  0.096777  0.863783  0.783080
#
#     ...  recall_score[0, 1]  accuracy_score[0, 1] f1_score[0, 2]  \
# 0   ...            0.712658              0.712658       0.720231
# 1   ...            0.740944              0.740944       0.697778
# 2   ...            0.602603              0.602603       0.829860
# 3   ...            0.685895              0.685895       0.651176
# 4   ...            0.606607              0.606607       0.673439
# ..  ...                 ...                   ...            ...
# 86  ...            0.740208              0.740208       0.779642
# 87  ...            0.742860              0.742860       0.646853
# 88  ...            0.733106              0.733106       0.734732
# 89  ...            0.711785              0.711785       0.681857
# 90  ...            0.598599              0.598599       0.691527
#
#     precision_score[0, 2]  recall_score[0, 2]  accuracy_score[0, 2]  \
# 0                0.870933            0.682917              0.682917
# 1                0.835330            0.657335              0.657335
# 2                0.838758            0.826827              0.826827
# 3                0.869929            0.608977              0.608977
# 4                0.823189            0.671672              0.671672
# ..                    ...                 ...                   ...
# 86               0.882383            0.750886              0.750886
# 87               0.870204            0.604579              0.604579
# 88               0.870349            0.699225              0.699225
# 89               0.872983            0.641216              0.641216
# 90               0.831752            0.688689              0.688689
#
#     f1_score[1, 2]  precision_score[1, 2]  recall_score[1, 2]  \
# 0         0.847090               0.869088            0.836342
# 1         0.752814               0.743028            0.816116
# 2         0.834080               0.834354            0.833834
# 3         0.737668               0.831021            0.703965
# 4         0.794417               0.809672            0.789790
# ..             ...                    ...                 ...
# 86        0.892484               0.891699            0.893427
# 87        0.663734               0.867808            0.621811
# 88        0.767697               0.861493            0.737863
# 89        0.823668               0.864271            0.806756
# 90        0.720538               0.821158            0.714715
#
#     accuracy_score[1, 2]
# 0               0.836342
# 1               0.816116
# 2               0.833834
# 3               0.703965
# 4               0.789790
# ..                   ...
# 86              0.893427
# 87              0.621811
# 88              0.737863
# 89              0.806756
# 90              0.714715
#
# [91 rows x 37 columns]

# %%
p = '/home/mr1142/Documents/Data/models/neumonia'
modelos = os.listdir(p)
modelos = [modelo[:-3] for modelo in modelos if os.path.isfile(os.path.join(p, modelo))]
modelos = [modelo for modelo in modelos if not bool(re.search('completo', modelo))]
modelos_evaluados = list(df['name'])

# %%
len(df)
# Out:
# 91

# %%
modelos_evaluados_resto = [modelo for modelo in modelos_evaluados if 
                           bool(re.search('resto', modelo))]
modelos_evaluados_resto = [re.split('_resto', modelo)[0] for 
                           modelo in modelos_evaluados_resto]

# %%
print(len(modelos))
print(len(set(modelos_evaluados)-set(modelos_evaluados_resto)))
print(len(modelos_evaluados_resto))
print(len(modelos_evaluados))
# Out:
# 90
# 90
# 2
# 91

# %%
evaluados_de_mas = list(set(modelos_evaluados) - set(modelos))
evaluados_de_mas = [modelo for modelo in evaluados_de_mas if not
                  bool(re.search('resto', modelo))]
ix = [i for i in df.index if df.name[i] in evaluados_de_mas]
evaluados_de_mas
# Out:
# []

# %%
df = df.drop(ix)
# df.to_csv(path, index = False)

# %%
evaluados_de_menos = list(set(modelos)-set(modelos_evaluados))
evaluados_de_menos
# Out:
# ['prueba_mask_Xception_fine-05_batch-8_lr-001_auc-88']

# %%
modelos_a_evaluar_resto = list(set(modelos)-set(modelos_evaluados_resto))
len(modelos_a_evaluar_resto)
# Out:
# 88

# %%
import os
import cv2
import json

# %%
def guardar(p, name):
    with open(os.path.join(p, 'metricas.json')) as json_file:
        data = json.load(json_file)
    save = [name] + list(data.values())
    try:
        # Si ya existe el modelo, se sobreescriben las métricas
        i = df[df['name'] == name].index
        df.loc[i[0]] = save
    except:
        df.loc[len(df.index)] = save

# %%
for model_name in evaluados_de_menos:
    print(f'-----------{model_name}-------------')
    try:
        p = os.path.join('/home/mr1142/Documents/Data/models/neumonia/validation_results', model_name)
        guardar(p, model_name)
        print('guardaro el normal')
    except:
        print('error en el normal')
    try:
        p = os.path.join('/home/mr1142/Documents/Data/models/neumonia/validation_results', model_name + '_resto')
        guardar(p, model_name+'_resto')
        print('guardado el resto')
    except:
        print('error en el resto')
# Out:
# -----------prueba_EffNet3_fine-05_batch-8_lr-0001_auc-92-------------
# guardaro el normal
# guardado el resto
# -----------prueba_Xception_fine-08_batch-8_lr--05_auc-93-------------
# guardaro el normal
# guardado el resto
# -----------prueba_mask_Xception_fine-08_batch-8_lr-0001_auc-91-------------
# guardaro el normal
# guardado el resto
# -----------prueba_Xception_fine-07_batch-8_lr--05_auc-92-------------
# guardaro el normal
# guardado el resto
# -----------prueba_Xception_fine-05_batch-8_lr--05_auc-91-------------
# guardaro el normal
# guardado el resto
# -----------prueba_EffNet3_fine-07_batch-8_lr-001_auc-91-------------
# guardaro el normal
# guardado el resto
# -----------prueba_EffNet3_fine-03_batch-8_lr-0001_auc-95-------------
# guardaro el normal
# guardado el resto
# -----------prueba_EffNet3_fine-03_batch-8_lr-001_auc-94-------------
# guardaro el normal
# guardado el resto
# -----------prueba_mask_Xception_fine-07_batch-8_lr-0001_auc-90-------------
# guardaro el normal
# guardado el resto
# -----------prueba_Xception_fine-08_batch-8_lr-0001_auc-92-------------
# guardaro el normal
# guardado el resto
# -----------prueba_mask_EffNet3_fine-08_batch-8_lr-0001_auc-88-------------
# guardaro el normal
# guardado el resto
# -----------prueba_mask_EffNet3_fine-08_batch-8_lr-001_auc-85-------------
# guardaro el normal
# guardado el resto
# -----------prueba_mask_EffNet3_fine-07_batch-8_lr-0001_auc-87-------------
# guardaro el normal
# guardado el resto
# -----------prueba_Xception_fine-07_batch-8_lr-0001_auc-93-------------
# guardaro el normal
# guardado el resto
# -----------prueba_mask_EffNet3_fine-05_batch-8_lr-0001_auc-91-------------
# guardaro el normal
# guardado el resto
# -----------prueba_mask_EffNet3_fine-03_batch-8_lr-0001_auc-86-------------
# guardaro el normal
# guardado el resto
# -----------prueba_IncResNet_fine-00_batch-8_lr-0001_auc-90-------------
# guardaro el normal
# guardado el resto
# -----------prueba_Xception_fine-05_batch-8_lr-0001_auc-94-------------
# guardaro el normal
# guardado el resto
# -----------prueba_mask_EffNet3_fine-05_batch-8_lr-001_auc-85-------------
# guardaro el normal
# guardado el resto
# -----------prueba_mask_Xception_fine-05_batch-8_lr-0001_auc-91-------------
# guardaro el normal
# guardado el resto
# -----------prueba_Xception_fine-00_batch-8_lr--05_auc-88-------------
# guardaro el normal
# guardado el resto
# -----------prueba_mask_EffNet3_fine-03_batch-8_lr-001_auc-91-------------
# guardaro el normal
# guardado el resto
# -----------prueba_mask_Xception_fine-03_batch-8_lr-0001_auc-91-------------
# guardaro el normal
# guardado el resto
# -----------prueba_Xception_fine-03_batch-8_lr--05_auc-89-------------
# guardaro el normal
# guardado el resto
# -----------prueba_IncResNet_fine-08_batch-8_lr-0001_auc-91-------------
# guardaro el normal
# guardado el resto
# -----------prueba_IncResNet_fine-07_batch-8_lr-0001_auc-90-------------
# guardaro el normal
# guardado el resto
# -----------prueba_EffNet3_fine-05_batch-8_lr-001_auc-89-------------
# guardaro el normal
# guardado el resto
# -----------prueba_IncResNet_fine-05_batch-8_lr-0001_auc-92-------------
# guardaro el normal
# guardado el resto
# -----------prueba_IncResNet_fine-03_batch-8_lr-0001_auc-94-------------
# guardaro el normal
# guardado el resto
# -----------prueba_EffNet3_fine-07_batch-8_lr--05_auc-86-------------
# guardaro el normal
# guardado el resto
# -----------prueba_EffNet3_fine-05_batch-8_lr--05_auc-83-------------
# guardaro el normal
# guardado el resto
# -----------prueba_mask_IncResNet_fine-00_batch-8_lr-0001_auc-90-------------
# guardaro el normal
# guardado el resto
# -----------prueba_Xception_fine-03_batch-8_lr-0001_auc-96-------------
# guardaro el normal
# guardado el resto
# -----------prueba_mask_IncResNet_fine-08_batch-8_lr-0001_auc-92-------------
# guardaro el normal
# guardado el resto
# -----------prueba_mask_IncResNet_fine-07_batch-8_lr-0001_auc-93-------------
# guardaro el normal
# guardado el resto
# -----------prueba_mask_Xception_fine-00_batch-8_lr--05_auc-89-------------
# guardaro el normal
# guardado el resto
# -----------prueba_mask_IncResNet_fine-03_batch-8_lr-0001_auc-91-------------
# guardaro el normal
# guardado el resto
# -----------prueba_mask_EffNet3_fine-07_batch-8_lr--05_auc-84-------------
# guardaro el normal
# guardado el resto
# -----------prueba_mask_IncResNet_fine-05_batch-8_lr-0001_auc-95-------------
# guardaro el normal
# guardado el resto
# -----------prueba_EffNet3_fine-08_batch-8_lr-001_auc-56-------------
# guardaro el normal
# error en el resto
# -----------prueba_mask_IncResNet_fine-07_batch-8_lr-001_auc-91-------------
# guardaro el normal
# error en el resto
# -----------prueba_mask_IncResNet_fine-00_batch-8_lr-0001_auc-90-------------
# guardaro el normal
# guardado el resto
# -----------prueba_mask_IncResNet_fine-00_batch-8_lr--05_auc-89-------------
# guardaro el normal
# error en el resto
# -----------prueba_EffNet3_fine-08_batch-8_lr-0001_auc-57-------------
# guardaro el normal
# error en el resto
# -----------prueba_mask_Xception_fine-08_batch-8_lr-0001_auc-91-------------
# guardaro el normal
# guardado el resto
# -----------prueba_EffNet3_fine-00_batch-8_lr-0001_auc-84-------------
# guardaro el normal
# error en el resto
# -----------prueba_mask_Xception_fine-00_batch-8_lr--05_auc-89-------------
# guardaro el normal
# guardado el resto
# -----------prueba_IncResNet_fine-08_batch-8_lr--05_auc-84-------------
# guardaro el normal
# error en el resto
# -----------prueba_mask_Xception_fine-07_batch-8_lr--05_auc-90-------------
# guardaro el normal
# error en el resto
# -----------prueba_mask_IncResNet_fine-00_batch-8_lr-001_auc-89-------------
# guardaro el normal
# error en el resto
# -----------prueba_Xception_fine-03_batch-8_lr-001_auc-93-------------
# guardaro el normal
# error en el resto
# -----------prueba_mask_EffNet3_fine-07_batch-8_lr-001_auc-87-------------
# guardaro el normal
# error en el resto
# -----------prueba_IncResNet_fine-08_batch-8_lr-0001_auc-91-------------
# guardaro el normal
# guardado el resto
# -----------prueba_mask_IncResNet_fine-05_batch-8_lr-0001_auc-95-------------
# guardaro el normal
# guardado el resto
# -----------prueba_IncResNet_fine-03_batch-8_lr-001_auc-87-------------
# guardaro el normal
# error en el resto
# -----------prueba_mask_Xception_fine-07_batch-8_lr-0001_auc-90-------------
# guardaro el normal
# guardado el resto
# -----------prueba_mask_Xception_fine-08_batch-8_lr-001_auc-94-------------
# guardaro el normal
# error en el resto
# -----------prueba_EffNet3_fine-08_batch-8_lr-001_auc-56-------------
# guardaro el normal
# error en el resto
# -----------prueba_mask_IncResNet_fine-07_batch-8_lr--05_auc-87-------------
# guardaro el normal
# error en el resto
# -----------prueba_EffNet3_fine-05_batch-8_lr-0001_auc-92-------------
# guardaro el normal
# guardado el resto
# -----------prueba_IncResNet_fine-07_batch-8_lr--05_auc-85-------------
# guardaro el normal
# error en el resto
# -----------prueba_mask_Xception_fine-07_batch-8_lr-001_auc-93-------------
# guardaro el normal
# error en el resto
# -----------prueba_IncResNet_fine-03_batch-8_lr-0001_auc-94-------------
# guardaro el normal
# guardado el resto
# -----------prueba_Xception_fine-05_batch-8_lr-001_auc-90-------------
# guardaro el normal
# error en el resto
# -----------prueba_mask_EffNet3_fine-00_batch-8_lr--05_auc-51-------------
# guardaro el normal
# error en el resto
# -----------prueba_IncResNet_fine-08_batch-8_lr-001_auc-90-------------
# guardaro el normal
# guardado el resto
# -----------prueba_EffNet3_fine-07_batch-8_lr-0001_auc-92-------------
# guardaro el normal
# guardado el resto
# -----------prueba_EffNet3_fine-00_batch-8_lr-0001_auc-54-------------
# guardaro el normal
# error en el resto
# -----------prueba_IncResNet_fine-00_batch-8_lr--05_auc-89-------------
# guardaro el normal
# guardado el resto
# -----------prueba_mask_Xception_fine-05_batch-8_lr-001_auc-88-------------
# error en el normal
# error en el resto
# -----------prueba_IncResNet_fine-07_batch-8_lr-001_auc-91-------------
# guardaro el normal
# guardado el resto
# -----------prueba_EffNet3_fine-00_batch-8_lr-001_auc-51-------------
# guardaro el normal
# error en el resto
# -----------prueba_Xception_fine-07_batch-8_lr-001_auc-89-------------
# guardaro el normal
# guardado el resto
# -----------prueba_IncResNet_fine-03_batch-8_lr--05_auc-84-------------
# guardaro el normal
# guardado el resto
# -----------prueba_mask_Xception_fine-08_batch-8_lr--05_auc-91-------------
# guardaro el normal
# guardado el resto
# -----------prueba_EffNet3_fine-03_batch-8_lr--05_auc-86-------------
# guardaro el normal
# guardado el resto
# -----------prueba_mask_Xception_fine-05_batch-8_lr--05_auc-90-------------
# guardaro el normal
# guardado el resto
# -----------prueba_EffNet3_fine-08_batch-8_lr--05_auc-56-------------
# guardaro el normal
# guardado el resto
# -----------prueba_IncResNet_fine-00_batch-8_lr-001_auc-86-------------
# guardaro el normal
# guardado el resto
# -----------prueba_EffNet3_fine-00_batch-8_lr--05_auc-57-------------
# guardaro el normal
# guardado el resto
# -----------prueba_mask_EffNet3_fine-08_batch-8_lr--05_auc-59-------------
# guardaro el normal
# guardado el resto
# -----------prueba_mask_EffNet3_fine-03_batch-8_lr--05_auc-90-------------
# guardaro el normal
# guardado el resto
# -----------prueba_Xception_fine-00_batch-8_lr-001_auc-91-------------
# guardaro el normal
# error en el resto

# %%
len(df)
# Out:
# 143

# %%
# df.to_csv(path, index = False)

# %%
model_name = 'prueba_mask_Xception_fine-05_batch-8_lr-001_auc-88'

# %%
p = os.path.join('/home/mr1142/Documents/Data/models/neumonia/validation_results', model_name)

# %%
os.listdir(p)
# Out:
# ['metricas.json',
#  'pred_rec_plot_0.png',
#  'auc_plot_0.png',
#  'pr_re_th_plot_0.png',
#  'pred_rec_plot_1.png',
#  'auc_plot_1.png',
#  'pr_re_th_plot_1.png',
#  'pred_rec_plot_2.png',
#  'auc_plot_2.png',
#  'pr_re_th_plot_2.png',
#  'class_report.csv']

# %%
img = cv2.imread(os.path.join(p, 'pr_re_th_plot_0.png'))
plt.figure(figsize=(10,10))
plt.imshow(img)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-221-8205032cd861> in <module>
#       1 img = cv2.imread(os.path.join(p, 'pr_re_th_plot_0.png'))
# ----> 2 plt.figure(figsize=(10,10))
#       3 plt.imshow(img)
#
# NameError: name 'plt' is not defined

# %%
with open(os.path.join(p, 'metricas.json')) as json_file:
    data = json.load(json_file)
data
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-222-9b2c9edb8283> in <module>
#       1 with open(os.path.join(p, 'metricas.json')) as json_file:
# ----> 2     data = json.load(json_file)
#       3 data
#
# ~/miniconda3/envs/init/lib/python3.6/json/__init__.py in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     297         cls=cls, object_hook=object_hook,
#     298         parse_float=parse_float, parse_int=parse_int,
# --> 299         parse_constant=parse_constant, object_pairs_hook=object_pairs_hook, **kw)
#     300
#     301
#
# ~/miniconda3/envs/init/lib/python3.6/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352             parse_int is None and parse_float is None and
#     353             parse_constant is None and object_pairs_hook is None and not kw):
# --> 354         return _default_decoder.decode(s)
#     355     if cls is None:
#     356         cls = JSONDecoder
#
# ~/miniconda3/envs/init/lib/python3.6/json/decoder.py in decode(self, s, _w)
#     337
#     338         """
# --> 339         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     340         end = _w(s, end).end()
#     341         if end != len(s):
#
# ~/miniconda3/envs/init/lib/python3.6/json/decoder.py in raw_decode(self, s, idx)
#     355             obj, end = self.scan_once(s, idx)
#     356         except StopIteration as err:
# --> 357             raise JSONDecodeError("Expecting value", s, err.value) from None
#     358         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 363 (char 362)

# %%
# list(set(modelos_evaluados)-set(modelos))

# %%
modelos_train = set(df_train['name'])
list(set(modelos_train)-set(modelos_evaluados))
# Out:
# []

# %%
modelos_a_evaluar_resto = list(set(modelos)-set(modelos_evaluados_resto))
len(modelos_a_evaluar_resto)
# Out:
# 24

# %%
subname = ''

# %%
p = '/home/mr1142/Documents/Data/models/neumonia/validation_results'
df = pd.read_csv(os.path.join(p, 'prediction_validation_metrics' + subname + '.csv'))

# %%
os.path.join(p, 'prediction_validation_metrics' + subname + '.csv')
# Out:
# '/home/mr1142/Documents/Data/models/neumonia/validation_results/prediction_validation_metrics.csv'
