# %%
import pandas as pd
import numpy as np
import re
import os

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %% [markdown]
# # TRAIN RESULTS
#
# Estos son los resultados del entrenamiento (history). Está recogido el máximo valor de cada una de las métricas y de la loss (no sabemos que epoch es)

# %%
path = '/home/mr1142/Documents/Data/models/neumonia/training_data/train_max.csv'
df_train = pd.read_csv(path)

# %%
df_train = df_train.reset_index(drop = True)
index = [i for i in df_train.index if not bool(re.search('completo', df_train['name'][i]))]
df_train = df_train.iloc[index]

# %%
# df_train[df_train['modelo'] == 'EffNet3'].sort_values(['fine', 'lr', 'mask'])

# %%
p = '/home/mr1142/Documents/Data/models/neumonia'
modelos = os.listdir(p)
modelos = [modelo[:-3] for modelo in modelos if os.path.isfile(os.path.join(p, modelo))]
modelos = [modelo for modelo in modelos if not bool(re.search('completo', modelo))]
modelos_evaluados = list(df_train['name'])

# %%
print(len(modelos))
print(len(modelos_evaluados))
# Out:
# 75
# 75

# %%
list(set(modelos)-set(modelos_evaluados))
# Out:
# ['prueba_EffNet3_fine-07_batch-8_lr-0001_auc-92',
#  'prueba_mask_IncResNet_fine-08_batch-8_lr--05_auc-84',
#  'prueba_mask_Xception_fine-05_batch-8_lr-001_auc-88']

# %% [markdown]
# ## Ploteo

# %%
y = 'val_precision'
data = df_train
lim = np.percentile(data[y], 20)

# %%
plt.subplots(figsize=(10,5))
p = sns.boxplot(x="modelo", y=y,
                hue="mask",
                data=data)
p.set(ylim=(lim, 1))
# Out:
# [(0.7259175777435303, 1.0)]

# %%
plt.subplots(figsize=(10,5))
p = sns.boxplot(x="modelo", y=y,
                hue="fine",
                data=data)
p.set(ylim=(lim, 1))
# Out:
# [(0.7259175777435303, 1.0)]

# %%
plt.subplots(figsize=(10,5))
p = sns.boxplot(x="modelo", y=y,
                hue="lr",
                data=data)
p.set(ylim=(lim, 1))
# Out:
# [(0.7259175777435303, 1.0)]

# %%
plt.subplots(figsize=(10,5))
p = sns.boxplot(x="fine", y=y,
                hue="lr",
                data=data)
p.set(ylim=(lim, 1))
# Out:
# [(0.7259175777435303, 1.0)]

# %%
plt.subplots(figsize=(10,5))
p = sns.boxplot(x="lr", y=y,
                hue="mask",
                data=data)
p.set(ylim=(lim, 1))
# Out:
# [(0.7259175777435303, 1.0)]

# %% [markdown]
# # SUBSET TEST EVALUATION RESULTS
#
# Estos son los resultados de aplicar model.evaluate() sobre el subset de X_train que he seleccionado para test.

# %%
path = '/home/mr1142/Documents/Data/models/neumonia/validation_results/image_class_evaluation.csv'
df_test = pd.read_csv(path)

# %% [markdown]
# ### Modelos sin evaluar

# %%
p = '/home/mr1142/Documents/Data/models/neumonia'
modelos = os.listdir(p)
modelos = [modelo[:-3] for modelo in modelos if os.path.isfile(os.path.join(p, modelo))]
modelos = [modelo for modelo in modelos if not bool(re.search('completo', modelo))]
modelos_evaluados = list(df_test['nombre'])

# %%
print(len(modelos))
print(len(modelos_evaluados))
# Out:
# 75
# 83

# %%
modelos_a_evaluar = list(set(modelos)-set(modelos_evaluados) )
modelos_a_evaluar
# Out:
# []

# %%
modelos_train = set(df_train['name'])
list(set(modelos_train)-set(modelos_evaluados))
# Out:
# []

# %% [markdown]
# ## RESTO

# %%
index = [i for i in df_test.index if bool(re.search('resto', df_test['nombre'][i]))]
df_resto = df_test.iloc[index]

# %%
df_resto = df_resto.reset_index(drop = True)

# %%
df_resto
# Out:
#                                               nombre      loss  \
# 0  prueba_EffNet3_fine-05_batch-8_lr-0001_auc-92_...  0.522258
# 1  prueba_Xception_fine-08_batch-8_lr--05_auc-93_...  0.492753
# 2  prueba_mask_Xception_fine-08_batch-8_lr-0001_a...  0.580660
# 3  prueba_Xception_fine-07_batch-8_lr--05_auc-92_...  0.536018
# 4  prueba_Xception_fine-05_batch-8_lr--05_auc-91_...  0.594727
# 5  prueba_EffNet3_fine-07_batch-8_lr-001_auc-91_r...  0.608744
# 6  prueba_EffNet3_fine-03_batch-8_lr-0001_auc-95_...  0.430632
# 7  prueba_EffNet3_fine-03_batch-8_lr-001_auc-94_r...  0.449572
#
#    binary_accuracy  precision       auc
# 0         0.852604   0.790152  0.926065
# 1         0.861533   0.799576  0.936951
# 2         0.832953   0.758784  0.907422
# 3         0.848225   0.783377  0.925145
# 4         0.816369   0.734754  0.899587
# 5         0.810349   0.733094  0.898770
# 6         0.872832   0.814099  0.950276
# 7         0.875653   0.822589  0.944469

# %%
df_resto['mask'] = list(map(lambda x: bool(re.search('mask', x)), df_resto['nombre']))

# %%
df_resto['modelo'] = list(map(lambda x: re.split('_', x)[-6], df_resto['nombre']))
df_resto['lr'] = list(map(lambda x: re.split('-', re.split('_', x)[-3])[1], df_resto['nombre']))
df_resto['batch'] = list(map(lambda x: re.split('-', re.split('_', x)[-4])[1], df_resto['nombre']))
df_resto['fine'] = list(map(lambda x: re.split('-', re.split('_', x)[-5])[1], df_resto['nombre']))

# %% [markdown]
# ### Ploteo

# %%
y = 'auc'
data = df_resto
lim = np.percentile(data[y], 20)

# %%
plt.subplots(figsize=(10,5))
p = sns.boxplot(x="modelo", y=y,
                hue="mask",
                data=data)
p.set(ylim=(lim, 1))
# Out:
# [(0.9027209043502809, 1.0)]

# %%
plt.subplots(figsize=(10,5))
p = sns.boxplot(x="modelo", y=y,
                hue="fine",
                data=data)
p.set(ylim=(lim, 1))
# Out:
# [(0.9027209043502809, 1.0)]

# %%
plt.subplots(figsize=(10,5))
p = sns.boxplot(x="fine", y=y,
                hue="lr",
                data=data)
p.set(ylim=(lim, 1))
# Out:
# [(0.9027209043502809, 1.0)]

# %%
plt.subplots(figsize=(10,5))
p = sns.boxplot(x="lr", y=y,
                hue="mask",
                data=data)
p.set(ylim=(lim, 1))
# Out:
# [(0.9027209043502809, 1.0)]

# %% [markdown]
# ## SUBSET

# %%
index = list(set(df_test.index) - set(index))
df_test = df_test.iloc[index]

# %%
df_test = df_test.reset_index(drop = True)

# %%
df_test['mask'] = list(map(lambda x: bool(re.search('mask', x)), df_test['nombre']))

# %%
df_test['modelo'] = list(map(lambda x: re.split('_', x)[-5], df_test['nombre']))
df_test['lr'] = list(map(lambda x: re.split('-', re.split('_', x)[-2])[1], df_test['nombre']))
df_test['batch'] = list(map(lambda x: re.split('-', re.split('_', x)[-3])[1], df_test['nombre']))
df_test['fine'] = list(map(lambda x: re.split('-', re.split('_', x)[-4])[1], df_test['nombre']))

# %%
df_test.sort_values('auc').tail()
# Out:
#                                             nombre      loss  binary_accuracy  \
# 35  prueba_Xception_fine-03_batch-8_lr-0001_auc-96  0.549459         0.848849
# 10  prueba_Xception_fine-07_batch-8_lr-0001_auc-93  0.485459         0.848849
# 4     prueba_EffNet3_fine-03_batch-8_lr-001_auc-94  0.488490         0.863196
# 59   prueba_Xception_fine-08_batch-8_lr-001_auc-92  0.525883         0.861862
# 3    prueba_EffNet3_fine-03_batch-8_lr-0001_auc-95  0.436792         0.871204
#
#     precision       auc   mask    modelo    lr batch fine
# 35   0.775202  0.928931  False  Xception  0001     8   03
# 10   0.786164  0.930917  False  Xception  0001     8   07
# 4    0.803296  0.931229  False   EffNet3   001     8   03
# 59   0.796954  0.931729  False  Xception   001     8   08
# 3    0.813075  0.945697  False   EffNet3  0001     8   03

# %% [markdown]
# ### Ploteo

# %%
y = 'auc'
data = df_test
lim = np.percentile(data[y], 20)

# %%
plt.subplots(figsize=(10,5))
p = sns.boxplot(x="modelo", y=y,
                hue="mask",
                data=data)
p.set(ylim=(lim, 1))
# Out:
# [(0.8509599208831787, 1.0)]

# %%
plt.subplots(figsize=(10,5))
p = sns.boxplot(x="modelo", y=y,
                hue="fine",
                data=data)
p.set(ylim=(lim, 1))
# Out:
# [(0.8509599208831787, 1.0)]

# %%
plt.subplots(figsize=(10,5))
p = sns.boxplot(x="fine", y=y,
                hue="lr",
                data=data)
p.set(ylim=(lim, 1))
# Out:
# [(0.8509599208831787, 1.0)]

# %%
plt.subplots(figsize=(10,5))
p = sns.boxplot(x="lr", y=y,
                hue="mask",
                data=data)
p.set(ylim=(lim, 1))
# Out:
# [(0.8509599208831787, 1.0)]

# %% [markdown]
# # SUBSET TEST PREDICTION METRICS
#
# Estos son los resultados de aplicar model.predict() sobre el subset de X_train que he seleccionado para test. Sobre las predicciones se calculan unas métricas personalizadas

# %%
path = '/home/mr1142/Documents/Data/models/neumonia/validation_results/prediction_validation_metrics.csv'
df = pd.read_csv(path)

# %% [markdown]
# ### Modelos sin evaluar

# %%
p = '/home/mr1142/Documents/Data/models/neumonia'
modelos = os.listdir(p)
modelos = [modelo[:-3] for modelo in modelos if os.path.isfile(os.path.join(p, modelo))]
modelos = [modelo for modelo in modelos if not bool(re.search('completo', modelo))]
modelos_evaluados = list(df['name'])

# %%
print(len(modelos))
print(len(modelos_evaluados))
# Out:
# 76
# 82

# %%
modelos_a_evaluar = list(set(modelos)-set(modelos_evaluados))
modelos_a_evaluar
# Out:
# ['prueba_EffNet3_fine-07_batch-8_lr-0001_auc-92',
#  'prueba_mask_Xception_fine-05_batch-8_lr-001_auc-88']

# %%
modelos_train = set(df_train['name'])
list(set(modelos_train)-set(modelos_evaluados))
# Out:
# ['prueba_EffNet3_fine-07_batch-8_lr-0001_auc-92',
#  'prueba_mask_Xception_fine-05_batch-8_lr-001_auc-88']

# %% [markdown]
# ## RESTO

# %%
index = [i for i in df.index if bool(re.search('resto', df['name'][i]))]
df_resto = df.iloc[index]

# %%
df_resto = df_resto.reset_index(drop = True)

# %%
df_resto
# Out:
#                                                 name     auc_0  younden_0  \
# 0  prueba_EffNet3_fine-05_batch-8_lr-0001_auc-92_...  0.973876   0.236019
# 1  prueba_Xception_fine-08_batch-8_lr--05_auc-93_...  0.981312   0.357225
# 2  prueba_mask_Xception_fine-08_batch-8_lr-0001_a...  0.965078   0.139708
# 3  prueba_Xception_fine-07_batch-8_lr--05_auc-92_...  0.976156   0.395211
# 4  prueba_Xception_fine-05_batch-8_lr--05_auc-91_...  0.973160   0.217472
# 5  prueba_EffNet3_fine-07_batch-8_lr-001_auc-91_r...  0.976713   0.268943
# 6  prueba_EffNet3_fine-03_batch-8_lr-0001_auc-95_...  0.986002   0.373820
# 7  prueba_EffNet3_fine-03_batch-8_lr-001_auc-94_r...  0.974926   0.391551
#
#    pr_max_0  pr_cut_0     auc_1  younden_1  pr_max_1  pr_cut_1     auc_2  ...  \
# 0  0.200979  0.298371  0.879770   0.262744  0.136612  0.447380  0.886909  ...
# 1  0.325617  0.415404  0.889641   0.189903  0.078036  0.397654  0.901754  ...
# 2  0.139708  0.151026  0.846997   0.360175  0.216142  0.547280  0.931631  ...
# 3  0.352145  0.452430  0.874615   0.151968  0.053256  0.312510  0.903362  ...
# 4  0.198265  0.230831  0.821306   0.225050  0.083557  0.380341  0.886582  ...
# 5  0.216286  0.332265  0.846903   0.106868  0.082499  0.232616  0.876901  ...
# 6  0.373820  0.427705  0.916031   0.160859  0.132412  0.306705  0.934488  ...
# 7  0.364874  0.346703  0.897896   0.325556  0.318853  0.457360  0.929047  ...
#
#    recall_score[0, 1]  accuracy_score[0, 1]  f1_score[0, 2]  \
# 0            0.756105              0.756105        0.688220
# 1            0.764592              0.764592        0.715762
# 2            0.688359              0.688359        0.696751
# 3            0.762094              0.762094        0.727982
# 4            0.730266              0.730266        0.705881
# 5            0.757508              0.757508        0.688564
# 6            0.771060              0.771060        0.725724
# 7            0.753949              0.753949        0.740555
#
#    precision_score[0, 2]  recall_score[0, 2]  accuracy_score[0, 2]  \
# 0               0.871026            0.647906              0.647906
# 1               0.874894            0.678040              0.678040
# 2               0.880158            0.657506              0.657506
# 3               0.873899            0.691627              0.691627
# 4               0.876501            0.667243              0.667243
# 5               0.873258            0.648385              0.648385
# 6               0.880094            0.689197              0.689197
# 7               0.879674            0.705830              0.705830
#
#    f1_score[1, 2]  precision_score[1, 2]  recall_score[1, 2]  \
# 0        0.752257               0.808033            0.725320
# 1        0.795177               0.834918            0.775954
# 2        0.875286               0.886011            0.869437
# 3        0.772837               0.844296            0.745684
# 4        0.815205               0.862917            0.796181
# 5        0.784859               0.864939            0.758261
# 6        0.862553               0.888442            0.851828
# 7        0.881764               0.884650            0.879584
#
#    accuracy_score[1, 2]
# 0              0.725320
# 1              0.775954
# 2              0.869437
# 3              0.745684
# 4              0.796181
# 5              0.758261
# 6              0.851828
# 7              0.879584
#
# [8 rows x 37 columns]

# %%
df_resto['mask'] = list(map(lambda x: bool(re.search('mask', x)), df_resto['name']))

# %%
df_resto['modelo'] = list(map(lambda x: re.split('_', x)[-6], df_resto['name']))
df_resto['lr'] = list(map(lambda x: re.split('-', re.split('_', x)[-3])[1], df_resto['name']))
df_resto['batch'] = list(map(lambda x: re.split('-', re.split('_', x)[-4])[1], df_resto['name']))
df_resto['fine'] = list(map(lambda x: re.split('-', re.split('_', x)[-5])[1], df_resto['name']))

# %% [markdown]
# ### Ploteo

# %%
y = 'auc_0'
data = df_resto
lim = np.percentile(data[y], 20)

# %%
plt.subplots(figsize=(10,5))
p = sns.boxplot(x="modelo", y=y,
                hue="mask",
                data=data)
p.set(ylim=(lim, 1))
# Out:
# [(0.9734464511989827, 1.0)]

# %%
plt.subplots(figsize=(10,5))
p = sns.boxplot(x="modelo", y=y,
                hue="fine",
                data=data)
p.set(ylim=(lim, 1))
# Out:
# [(0.9734464511989827, 1.0)]

# %%
plt.subplots(figsize=(10,5))
p = sns.boxplot(x="fine", y=y,
                hue="lr",
                data=data)
p.set(ylim=(lim, 1))
# Out:
# [(0.9734464511989827, 1.0)]

# %%
plt.subplots(figsize=(10,5))
p = sns.boxplot(x="lr", y=y,
                hue="mask",
                data=data)
p.set(ylim=(lim, 1))
# Out:
# [(0.9734464511989827, 1.0)]

# %% [markdown]
# ## SUBSET

# %%
df = df.reset_index(drop = True)

# %%
index = list(set(df.index) - set(index))
df = df.iloc[index]

# %%
df['mask'] = list(map(lambda x: bool(re.search('mask', x)), df['name']))

# %%
df['modelo'] = list(map(lambda x: re.split('_', x)[-5], df['name']))
df['lr'] = list(map(lambda x: re.split('-', re.split('_', x)[-2])[1], df['name']))
df['batch'] = list(map(lambda x: re.split('-', re.split('_', x)[-3])[1], df['name']))
df['fine'] = list(map(lambda x: re.split('-', re.split('_', x)[-4])[1], df['name']))

# %%
df['auc_mean'] = (df['auc_0']+df['auc_1']+df['auc_2'])/3

# %%
df.sort_values('auc_mean').tail()
# Out:
#                                                  name     auc_0  younden_0  \
# 36  prueba_mask_IncResNet_fine-05_batch-8_lr-0001_...  0.974515   0.066946
# 59      prueba_Xception_fine-08_batch-8_lr-001_auc-92  0.982717   0.196502
# 22  prueba_mask_Xception_fine-03_batch-8_lr-0001_a...  0.977626   0.079139
# 34  prueba_mask_IncResNet_fine-03_batch-8_lr-0001_...  0.975083   0.455335
# 6       prueba_EffNet3_fine-03_batch-8_lr-0001_auc-95  0.991293   0.122462
#
#     pr_max_0  pr_cut_0     auc_1  younden_1  pr_max_1  pr_cut_1     auc_2  \
# 36  0.066946  0.110425  0.872377   0.057974  0.049864  0.544718  0.930372
# 59  0.331068  0.138229  0.873779   0.382627  0.135059  0.590140  0.923374
# 22  0.098225  0.109531  0.877251   0.567552  0.562125  0.666493  0.942451
# 34  0.673091  0.626435  0.878748   0.110022  0.026167  0.206303  0.943782
# 6   0.366291  0.366291  0.893384   0.219937  0.219937  0.366731  0.931752
#
#     ...  f1_score[1, 2]  precision_score[1, 2]  recall_score[1, 2]  \
# 36  ...        0.856353               0.859571            0.854855
# 59  ...        0.842979               0.842476            0.843844
# 22  ...        0.875634               0.876968            0.877878
# 34  ...        0.807455               0.859248            0.801802
# 6   ...        0.855620               0.865743            0.852853
#
#     accuracy_score[1, 2]   mask     modelo    lr  batch  fine  auc_mean
# 36              0.854855   True  IncResNet  0001      8    05  0.925755
# 59              0.843844  False   Xception   001      8    08  0.926623
# 22              0.877878   True   Xception  0001      8    03  0.932443
# 34              0.801802   True  IncResNet  0001      8    03  0.932538
# 6               0.852853  False    EffNet3  0001      8    03  0.938810
#
# [5 rows x 43 columns]

# %%
df.columns
# Out:
# Index(['name', 'auc_0', 'younden_0', 'pr_max_0', 'pr_cut_0', 'auc_1',
#        'younden_1', 'pr_max_1', 'pr_cut_1', 'auc_2', 'younden_2', 'pr_max_2',
#        'pr_cut_2', 'f1_score_0', 'precision_score_0', 'recall_score_0',
#        'accuracy_score_0', 'f1_score_1', 'precision_score_1', 'recall_score_1',
#        'accuracy_score_1', 'f1_score_2', 'precision_score_2', 'recall_score_2',
#        'accuracy_score_2', 'f1_score[0, 1]', 'precision_score[0, 1]',
#        'recall_score[0, 1]', 'accuracy_score[0, 1]', 'f1_score[0, 2]',
#        'precision_score[0, 2]', 'recall_score[0, 2]', 'accuracy_score[0, 2]',
#        'f1_score[1, 2]', 'precision_score[1, 2]', 'recall_score[1, 2]',
#        'accuracy_score[1, 2]', 'mask', 'modelo', 'lr', 'batch', 'fine',
#        'auc_mean'],
#       dtype='object')

# %% [markdown]
# ### Ploteo

# %%
y = 'auc_2'
data = df
lim = np.percentile(data[y], 10)

# %%
plt.subplots(figsize=(10,5))
p = sns.boxplot(x="modelo", y=y,
                hue="mask",
                data=data)
p.set(ylim=(lim, 1))
# Out:
# [(0.7675955234513793, 1.0)]

# %%
plt.subplots(figsize=(10,5))
p = sns.boxplot(x="modelo", y=y,
                hue="fine",
                data=data)
p.set(ylim=(lim, 1))
# Out:
# [(0.7675955234513793, 1.0)]

# %%
plt.subplots(figsize=(10,5))
p = sns.boxplot(x="fine", y=y,
                hue="lr",
                data=data)
p.set(ylim=(lim, 1))
# Out:
# [(0.7675955234513793, 1.0)]

# %%
plt.subplots(figsize=(10,5))
p = sns.boxplot(x="lr", y=y,
                hue="mask",
                data=data)
p.set(ylim=(lim, 1))
# Out:
# [(0.7675955234513793, 1.0)]

# %% [markdown]
# ## Cada modelo

# %%
import os
import cv2
import json

# %%
model_name = 'prueba_mask_Xception_fine-05_batch-8_lr-0001_auc-91'

# %%
p = os.path.join('/home/mr1142/Documents/Data/models/neumonia/validation_results', model_name)

# %%
os.listdir(p)
# Out:
# ['metricas.json',
#  'pred_rec_plot_0.png',
#  'auc_plot_0.png',
#  'pr_re_th_plot_0.png',
#  'pred_rec_plot_1.png',
#  'auc_plot_1.png',
#  'pr_re_th_plot_1.png',
#  'pred_rec_plot_2.png',
#  'auc_plot_2.png',
#  'pr_re_th_plot_2.png',
#  'class_report.csv']

# %%
img = cv2.imread(os.path.join(p, 'auc_plot_1.png'))
plt.figure(figsize=(10,10))
plt.imshow(img)

# %%
with open(os.path.join(p, model_name + '.json')) as json_file:
    data = json.load(json_file)
data
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-859-398f6558f67a> in <module>
# ----> 1 with open(os.path.join(p, model_name + '.json')) as json_file:
#       2     data = json.load(json_file)
#       3 data
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/mr1142/Documents/Data/models/neumonia/validation_results/prueba_IncResNet_fine-00_batch-8_lr-0001_auc-90/prueba_IncResNet_fine-00_batch-8_lr-0001_auc-90.json'

# %%
df = pd.read_csv(os.path.join(p, 'class_report.csv'))
df
# Out:
#      Unnamed: 0  precision    recall  f1-score  support
# 0        normal   0.940299  0.887324  0.913043     71.0
# 1      moderado   0.630137  0.741935  0.681481     62.0
# 2        severo   0.750000  0.671642  0.708661     67.0
# 3     micro avg   0.770000  0.770000  0.770000    200.0
# 4     macro avg   0.773478  0.766967  0.767729    200.0
# 5  weighted avg   0.780398  0.770000  0.772791    200.0
# 6   samples avg   0.770000  0.770000  0.770000    200.0
