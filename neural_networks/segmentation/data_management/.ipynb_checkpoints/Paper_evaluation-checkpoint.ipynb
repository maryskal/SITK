# %%
import pandas as pd
import re

# %% [markdown]
# # Comparativa de modelos

# %%
path = '/home/mr1142/Documents/Data/models/mascaras/validation_results/validation_results' + '' + '.csv'
df = pd.read_csv(path)

# %%
df['doble_loss'] = df['dice_coef_loss'] + df['loss_mask']

# %%
df.reset_index(drop = True)
index = [i for i in df.index if bool(re.search('comparacion', df['name'][i]))]

# %%
df = df.loc[index]

# %%
df['patologic'] = [1 if bool(re.search('patologic', df['name'][i])) else 0 for i in df.index]

# %%
df.sort_values('doble_loss')
# Out:
#       type                     name      loss  dice_coef_loss  loss_mask  \
# 73    unet            comparacion_1  0.027100        0.026661   0.077886
# 80    unet  patologic_comparacion_4  0.026244        0.026244   0.078352
# 94   uloss  patologic_comparacion_3  0.106143        0.028961   0.077182
# 96   uloss  patologic_comparacion_4  0.107596        0.028621   0.078975
# 97    unet            comparacion_5  0.029030        0.028591   0.079203
# 76    unet  patologic_comparacion_2  0.026814        0.026814   0.081001
# 98    unet  patologic_comparacion_5  0.028347        0.028347   0.080317
# 92   uloss  patologic_comparacion_2  0.109170        0.028944   0.080226
# 77    unet            comparacion_3  0.029059        0.028470   0.080745
# 79    unet            comparacion_4  0.029805        0.029209   0.080191
# 95   uloss            comparacion_4  0.111228        0.030425   0.080340
# 78    unet  patologic_comparacion_3  0.028407        0.028407   0.082873
# 93   uloss            comparacion_3  0.112335        0.030393   0.081485
# 91   uloss            comparacion_2  0.113316        0.030553   0.082287
# 74    unet  patologic_comparacion_1  0.028853        0.028853   0.084413
# 75    unet            comparacion_2  0.031356        0.030843   0.086869
# 85    ueff            comparacion_3  0.061531        0.060831   0.162529
# 99    ueff            comparacion_5  0.065494        0.064855   0.168261
# 86    ueff  patologic_comparacion_3  0.064402        0.064402   0.168810
# 100   ueff  patologic_comparacion_5  0.068732        0.068732   0.176437
# 83    ueff            comparacion_2  0.070140        0.069492   0.188925
# 87    ueff            comparacion_4  0.075016        0.074590   0.191158
# 84    ueff  patologic_comparacion_2  0.074860        0.074860   0.196457
# 88    ueff  patologic_comparacion_4  0.080048        0.080048   0.201849
# 81    ueff            comparacion_1  0.101905        0.100846   0.245200
# 82    ueff  patologic_comparacion_1  0.105417        0.105417   0.251617
# 101  uloss            comparacion_5  0.580846        0.185035   0.395140
# 89   uloss            comparacion_1  0.583175        0.184190   0.397775
# 102  uloss  patologic_comparacion_5  0.586621        0.188347   0.398274
# 90   uloss  patologic_comparacion_1  0.595229        0.189449   0.405780
#
#      accuracy       AUC  false_positives  false_negatives  doble_loss  \
# 73   0.978180  0.978374          71854.0          71143.0    0.104548
# 80   0.979271  0.978564         111964.0         159738.0    0.104595
# 94   0.977206  0.977977         102447.0         196322.0    0.106143
# 96   0.977312  0.978957         129756.0         167622.0    0.107596
# 97   0.976481  0.977642          96393.0          57738.0    0.107794
# 76   0.978853  0.978568         104918.0         172255.0    0.107815
# 98   0.977537  0.977796         158898.0         135525.0    0.108664
# 92   0.977202  0.978554         112884.0         185930.0    0.109170
# 77   0.976631  0.976750          77299.0          75852.0    0.109214
# 79   0.975901  0.976535          88364.0          69573.0    0.109400
# 95   0.975095  0.977643          89173.0          74047.0    0.110764
# 78   0.977658  0.976140         100450.0         192386.0    0.111280
# 93   0.975162  0.977430          83719.0          79062.0    0.111878
# 91   0.975083  0.977439          81522.0          81777.0    0.112840
# 74   0.977188  0.976521         127335.0         171661.0    0.113266
# 75   0.974777  0.975854          87972.0          77327.0    0.117712
# 85   0.950760  0.953145         154177.0         168519.0    0.223360
# 99   0.946635  0.954498         221561.0         128174.0    0.233117
# 86   0.949829  0.950470         287505.0         370101.0    0.233212
# 100  0.945639  0.951863         423630.0         288884.0    0.245169
# 83   0.945561  0.947316         109750.0         247019.0    0.258417
# 87   0.941383  0.944170         144686.0         239467.0    0.265749
# 84   0.943368  0.943263         214976.0         527310.0    0.271317
# 88   0.939215  0.939071         260567.0         536148.0    0.281897
# 81   0.924592  0.917781          55572.0         438623.0    0.346046
# 82   0.923488  0.914570         125005.0         877852.0    0.357034
# 101  0.835784  0.845215         795441.0         280764.0    0.580176
# 89   0.835285  0.845554         811661.0         267817.0    0.581965
# 102  0.835417  0.847578        1665067.0         492151.0    0.586621
# 90   0.833663  0.846576        1702247.0         477959.0    0.595229
#
#      patologic
# 73           0
# 80           1
# 94           1
# 96           1
# 97           0
# 76           1
# 98           1
# 92           1
# 77           0
# 79           0
# 95           0
# 78           1
# 93           0
# 91           0
# 74           1
# 75           0
# 85           0
# 99           0
# 86           1
# 100          1
# 83           0
# 87           0
# 84           1
# 88           1
# 81           0
# 82           1
# 101          0
# 89           0
# 102          1
# 90           1

# %%
df_normal = df[df.patologic == 0]
df_pato = df[df.patologic == 1]

# %%
df.columns
# Out:
# Index(['type', 'name', 'loss', 'dice_coef_loss', 'loss_mask', 'accuracy',
#        'AUC', 'false_positives', 'false_negatives', 'doble_loss'],
#       dtype='object')

# %% [markdown]
# # Results

# %% [markdown]
# ## PLOT

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df.columns
# Out:
# Index(['type', 'name', 'loss', 'dice_coef_loss', 'loss_mask', 'accuracy',
#        'AUC', 'false_positives', 'false_negatives', 'doble_loss', 'patologic'],
#       dtype='object')

# %%
y = 'doble_loss'
data = df
low_lim = np.percentile(data[y], 25)
high_lim = np.percentile(data[y], 75)
ir =  high_lim - low_lim

# %%
plt.subplots(figsize=(10,5))
p = sns.boxplot(x="type", y=y, hue='patologic',
                data=data)
p.set(ylim=(0.05, high_lim+2.2*ir))
# Out:
# [(0.05, 0.6235608201473952)]

# %%
p.figure.savefig('paper_results/' + y + '.png')
