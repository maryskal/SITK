# %%
import numpy as np
import pandas as pd
import re

# %%
df = pd.read_csv('/home/mr1142/Documents/Data/segmentation/splited/validation/validation_data.csv')
labels = [re.split('[|]', df['Finding Labels'][i]) for i in df.index]
labels = [x for xs in labels for x in xs]
labels = list(np.unique(labels))
labels
# Out:
# ['Atelectasis',
#  'Cardiomegaly',
#  'Consolidation',
#  'Edema',
#  'Effusion',
#  'Emphysema',
#  'Infiltration',
#  'Mass',
#  'No Finding',
#  'Nodule',
#  'Pleural_Thickening',
#  'Pneumonia',
#  'Pneumothorax']

# %%
path = '/home/mr1142/Documents/Data/models/mascaras/validation_results/validation_results' + '' + '.csv'
df = pd.read_csv(path)

# %%
df['doble_loss'] = df['dice_coef_loss'] + df['loss_mask']

# %%
df.sort_values('doble_loss').head(50)
# Out:
#       type                                         name      loss  \
# 72    unet    patologic_final_renacimiento_validation_6  0.010329
# 35   uloss                           new_segmentation_8  0.100327
# 21   uloss              final_renacimiento_validation_8  0.100469
# 24    unet                           new_segmentation_1  0.026739
# 19   uloss              final_renacimiento_validation_6  0.102747
# 26   uloss                           new_segmentation_2  0.102601
# 82   uloss                            patologic_paper_9  0.102882
# 64   uloss                 patologic_new_segmentation_6  0.103185
# 29    unet                           new_segmentation_8  0.028016
# 88    unet                            patologic_paper_9  0.026736
# 32   uloss                           new_segmentation_3  0.105276
# 55   uloss    patologic_final_renacimiento_validation_6  0.104725
# 104   unet                            patologic_paper_7  0.026942
# 20    unet              final_renacimiento_validation_7  0.028393
# 78    unet                            patologic_paper_1  0.026476
# 71    unet              final_renacimiento_validation_6  0.027664
# 59   uloss                 patologic_new_segmentation_2  0.106732
# 90   uloss                           patologic_paper_10  0.107822
# 60   uloss                 patologic_new_segmentation_3  0.107975
# 92    unet                           patologic_paper_10  0.027638
# 23    unet                           new_segmentation_2  0.029598
# 53   uloss    patologic_final_renacimiento_validation_8  0.109311
# 67   uloss    patologic_final_renacimiento_validation_8  0.109311
# 84   uloss                            patologic_paper_4  0.109501
# 80    unet                            patologic_paper_3  0.028549
# 33   uloss                           new_segmentation_6  0.111097
# 66   uloss                 patologic_new_segmentation_8  0.110758
# 56   uloss          patologic_renacimiento_validation_3  0.111251
# 108   unet                            patologic_paper_8  0.028670
# 100  uloss                            patologic_paper_7  0.112514
# 18    unet              final_renacimiento_validation_5  0.030735
# 25    unet                           new_segmentation_7  0.031301
# 57   uloss          patologic_renacimiento_validation_4  0.115367
# 27    unet                           new_segmentation_3  0.032637
# 31    unet                           new_segmentation_3  0.031624
# 15   uloss                    renacimiento_validation_3  0.119526
# 17   uloss                    renacimiento_validation_4  0.119882
# 54   uloss          patologic_renacimiento_validation_2  0.120208
# 58   uloss  patologic_validation_rotate_normalization_1  0.121715
# 12    unet                    renacimiento_validation_2  0.032413
# 10    unet                    renacimiento_validation_1  0.032621
# 62   uloss  patologic_validation_rotate_normalization_3  0.126290
# 22    unet              final_renacimiento_validation_8  0.034788
# 6    uloss          albumentation_rotate_3_validation_1  0.128454
# 7    uloss          albumentation_rotate_3_validation_2  0.129951
# 61   uloss  patologic_validation_rotate_normalization_2  0.130081
# 2     unet               _albumentation_validation_2.h5  0.034487
# 13   uloss                    renacimiento_validation_2  0.131064
# 14    unet                    renacimiento_validation_3  0.033088
# 16    unet                    renacimiento_validation_4  0.034823
#
#      dice_coef_loss  loss_mask  accuracy       AUC  false_positives  \
# 72         0.010329   0.033800  0.991868  0.990991          29619.0
# 35         0.027026   0.072820  0.977854  0.979740          79161.0
# 21         0.026820   0.073125  0.978087  0.979268          68079.0
# 24         0.026341   0.075169  0.978365  0.979378          81964.0
# 19         0.028376   0.073854  0.976893  0.977792          70053.0
# 26         0.027155   0.075076  0.977825  0.979799          80248.0
# 82         0.025683   0.077199  0.979702  0.982104         130249.0
# 64         0.027132   0.076053  0.978723  0.979761        3743327.0
# 29         0.027544   0.076408  0.977614  0.976839          57872.0
# 88         0.026736   0.077313  0.978962  0.978022         113528.0
# 32         0.028231   0.076457  0.976861  0.978157          73210.0
# 55         0.027288   0.077437  0.978551  0.978354         342536.0
# 104        0.026942   0.078071  0.978850  0.977175          78794.0
# 20         0.027809   0.077276  0.977255  0.977421          72967.0
# 78         0.026476   0.079112  0.979208  0.977998          99421.0
# 71         0.027216   0.078634  0.977579  0.977706          72640.0
# 59         0.027362   0.079371  0.978450  0.979824        1066693.0
# 90         0.027850   0.079972  0.978066  0.978738         118328.0
# 60         0.029015   0.078960  0.977211  0.977244        1165999.0
# 92         0.027638   0.081565  0.978267  0.977341         122530.0
# 23         0.029114   0.080106  0.976126  0.977194          93158.0
# 53         0.028401   0.080910  0.977675  0.977669         101605.0
# 67         0.028401   0.080910  0.977675  0.977669        8309586.0
# 84         0.027529   0.081972  0.978294  0.979468         125105.0
# 80         0.028549   0.081565  0.977533  0.976385         123255.0
# 33         0.029996   0.080656  0.975554  0.977975          81662.0
# 66         0.029832   0.080926  0.976418  0.976644        8207981.0
# 56         0.029183   0.082068  0.977041  0.977651         444439.0
# 108        0.028670   0.082816  0.977558  0.975833         104854.0
# 100        0.028879   0.083635  0.977413  0.977311         106017.0
# 18         0.030172   0.084180  0.975373  0.975297          76188.0
# 25         0.030931   0.083835  0.974916  0.974708          73954.0
# 57         0.030165   0.085202  0.976367  0.976576         545836.0
# 27         0.032066   0.085404  0.973690  0.974328          94769.0
# 31         0.031161   0.087606  0.974575  0.975396          86012.0
# 15         0.030919   0.088200  0.975120  0.976994          80190.0
# 17         0.030873   0.088655  0.975076  0.976777          80748.0
# 54         0.033043   0.087165  0.974292  0.974027         249264.0
# 58         0.033772   0.087943  0.973592  0.972668         937586.0
# 12         0.031955   0.089793  0.974418  0.973736          70983.0
# 10         0.032179   0.092485  0.973949  0.974434          88665.0
# 62         0.034340   0.091950  0.973029  0.972075        1421131.0
# 22         0.034296   0.092406  0.972122  0.972886          93011.0
# 6          0.035279   0.092766  0.971818  0.972174          78499.0
# 7          0.034909   0.094568  0.971946  0.973499          87304.0
# 61         0.035721   0.094361  0.971967  0.971112        1290785.0
# 2          0.034487   0.095812  0.973940  0.974166           7962.0
# 13         0.034971   0.095523  0.971893  0.973108          74191.0
# 14         0.032720   0.098321  0.973591  0.974356          92355.0
# 16         0.034295   0.098386  0.972277  0.971930          88000.0
#
#      false_negatives  doble_loss
# 72           76975.0    0.044129
# 35           65976.0    0.099846
# 21           75530.0    0.099945
# 24           59824.0    0.101509
# 19           81382.0    0.102230
# 26           65079.0    0.102231
# 82          135805.0    0.102882
# 64         3023843.0    0.103185
# 29           88834.0    0.103952
# 88          162215.0    0.104049
# 32           78431.0    0.104688
# 55          724644.0    0.104725
# 104         198428.0    0.105013
# 20           76094.0    0.105085
# 78          173100.0    0.105588
# 71           74298.0    0.105850
# 59         1886679.0    0.106732
# 90          169165.0    0.107822
# 60         2086071.0    0.107975
# 92          162327.0    0.109203
# 23           63302.0    0.109220
# 53          191015.0    0.109311
# 67         3744618.0    0.109311
# 84          159396.0    0.109501
# 80          171227.0    0.110113
# 33           78549.0    0.110652
# 66         3553603.0    0.110758
# 56          923666.0    0.111251
# 108         189301.0    0.111486
# 100         190038.0    0.112514
# 18           85209.0    0.114352
# 25           90438.0    0.114766
# 57         1132029.0    0.115367
# 27           77654.0    0.117470
# 31           80613.0    0.118767
# 15           81231.0    0.119119
# 17           80958.0    0.119528
# 54          536778.0    0.120208
# 58         1733331.0    0.121715
# 12           94992.0    0.121748
# 10           80353.0    0.124665
# 62         2551887.0    0.126290
# 22           89689.0    0.126702
# 6           104346.0    0.128045
# 7            94711.0    0.129478
# 61         2328724.0    0.130081
# 2             5701.0    0.130299
# 13          108172.0    0.130494
# 14           78991.0    0.131041
# 16           91869.0    0.132681

# %%
index = [i for i in df.index if bool(re.search('patologic', df['name'][i]))]

# %%
df.iloc[index].sort_values('dice_coef_loss').head(20)
# Out:
#       type                                            name      loss  \
# 131   unet  paper_patologicfinal_renacimiento_validation_6  0.010329
# 42    unet       patologic_final_renacimiento_validation_6  0.010329
# 41    unet                    patologic_new_segmentation_2  0.026118
# 126   unet                         patologic_comparacion_7  0.026119
# 108   unet                         patologic_comparacion_9  0.026142
# 80    unet                         patologic_comparacion_4  0.026244
# 47    unet       patologic_final_renacimiento_validation_5  0.026621
# 112  uloss                         patologic_comparacion_6  0.102951
# 76    unet                         patologic_comparacion_2  0.026814
# 43    unet                    patologic_new_segmentation_1  0.027093
# 66   uloss                    patologic_new_segmentation_6  0.103185
# 57   uloss       patologic_final_renacimiento_validation_6  0.104725
# 61   uloss                    patologic_new_segmentation_2  0.106732
# 51    unet                    patologic_new_segmentation_3  0.027587
# 46    unet                    patologic_new_segmentation_7  0.027836
# 37    unet       patologic_final_renacimiento_validation_7  0.028050
# 48    unet             patologic_renacimiento_validation_1  0.028204
# 38    unet       patologic_final_renacimiento_validation_8  0.028280
# 98    unet                         patologic_comparacion_5  0.028347
# 52    unet                    patologic_new_segmentation_8  0.028385
#
#      dice_coef_loss  loss_mask  accuracy       AUC  false_positives  \
# 131        0.010329   0.033800  0.991868  0.990991          29619.0
# 42         0.010329   0.084500  0.991868  0.990991         728103.0
# 41         0.026118   0.191623  0.979343  0.979141         698484.0
# 126        0.026119   0.075131  0.979315  0.978712         105806.0
# 108        0.026142   0.073354  0.979301  0.978284         103354.0
# 80         0.026244   0.078352  0.979271  0.978564         111964.0
# 47         0.026621   0.196282  0.979081  0.977774        1146235.0
# 112        0.026670   0.076282  0.978900  0.979681         111270.0
# 76         0.026814   0.081001  0.978853  0.978568         104918.0
# 43         0.027093   0.202216  0.978595  0.978217         849302.0
# 66         0.027132   0.076053  0.978723  0.979761        3743327.0
# 57         0.027288   0.077437  0.978551  0.978354         342536.0
# 61         0.027362   0.079371  0.978450  0.979824        1066693.0
# 51         0.027587   0.209517  0.978267  0.977902        1870899.0
# 46         0.027836   0.195432  0.978214  0.976372        1055048.0
# 37         0.028050   0.208446  0.977999  0.977043         109233.0
# 48         0.028204   0.209544  0.977812  0.977078        1499667.0
# 38         0.028280   0.201186  0.977707  0.977706         231254.0
# 98         0.028347   0.080317  0.977537  0.977796         158898.0
# 52         0.028385   0.198268  0.977662  0.975669        1955631.0
#
#      false_negatives  doble_loss
# 131          76975.0    0.044129
# 42         1223909.0    0.094829
# 41         1146934.0    0.217741
# 126         165321.0    0.101249
# 108         167951.0    0.099496
# 80          159738.0    0.104595
# 47         1979773.0    0.222902
# 112         165288.0    0.102951
# 76          172255.0    0.107815
# 43         1383274.0    0.229309
# 66         3023843.0    0.103185
# 57          724644.0    0.104725
# 61         1886679.0    0.106732
# 51         3162686.0    0.237104
# 46         1796768.0    0.223268
# 37          179141.0    0.236496
# 48         2512436.0    0.237748
# 38          349315.0    0.229465
# 98          135525.0    0.108664
# 52         3370743.0    0.226653

# %%
m = {}
for tipo in np.unique(df['type']):
    u = df[df.type == tipo]
    models = [re.split('patologic_', name)[0] for name in u['name']]

    for model in models:
        models_model = [mod for mod in models if bool(re.search(model, mod))]
        lista = []
        for col in df.columns[2:10]:
            values = list(df[col][df.name == model])
            lista.append(np.mean(values))
        m[tipo + '_' + model] = lista
# Out:
# /home/mr1142/miniconda3/envs/init/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/mr1142/miniconda3/envs/init/lib/python3.6/site-packages/numpy/core/_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
n = pd.DataFrame(m).transpose()
n.columns = df.columns[2:10]
n.sort_values('dice_coef_loss')
# Out:
#                                                         loss  dice_coef_loss  \
# unet_paper_patologicfinal_renacimiento_validati...  0.010329        0.010329
# unet_new_segmentation_1                             0.026739        0.026341
# unet_new_segmentation_8                             0.064171        0.027285
# uloss_new_segmentation_8                            0.064171        0.027285
# unet_final_renacimiento_validation_7                0.028393        0.027809
# ...                                                      ...             ...
# uloss_comparacion_10                                0.657779        0.395912
# unet_comparacion_10                                 0.657779        0.395912
# ueff_                                                    NaN             NaN
# uloss_                                                   NaN             NaN
# unet_                                                    NaN             NaN
#
#                                                     loss_mask  accuracy  \
# unet_paper_patologicfinal_renacimiento_validati...   0.033800  0.991868
# unet_new_segmentation_1                              0.075169  0.978365
# unet_new_segmentation_8                              0.074614  0.977734
# uloss_new_segmentation_8                             0.074614  0.977734
# unet_final_renacimiento_validation_7                 0.077276  0.977255
# ...                                                       ...       ...
# uloss_comparacion_10                                 0.575071  0.511699
# unet_comparacion_10                                  0.575071  0.511699
# ueff_                                                     NaN       NaN
# uloss_                                                    NaN       NaN
# unet_                                                     NaN       NaN
#
#                                                          AUC  false_positives  \
# unet_paper_patologicfinal_renacimiento_validati...  0.990991          29619.0
# unet_new_segmentation_1                             0.979378          81964.0
# unet_new_segmentation_8                             0.978290          68516.5
# uloss_new_segmentation_8                            0.978290          68516.5
# unet_final_renacimiento_validation_7                0.977421          72967.0
# ...                                                      ...              ...
# uloss_comparacion_10                                0.574605        2937275.0
# unet_comparacion_10                                 0.574605        2937275.0
# ueff_                                                    NaN              NaN
# uloss_                                                   NaN              NaN
# unet_                                                    NaN              NaN
#
#                                                     false_negatives  \
# unet_paper_patologicfinal_renacimiento_validati...          76975.0
# unet_new_segmentation_1                                     59824.0
# unet_new_segmentation_8                                     77405.0
# uloss_new_segmentation_8                                    77405.0
# unet_final_renacimiento_validation_7                        76094.0
# ...                                                             ...
# uloss_comparacion_10                                       262857.0
# unet_comparacion_10                                        262857.0
# ueff_                                                           NaN
# uloss_                                                          NaN
# unet_                                                           NaN
#
#                                                     doble_loss
# unet_paper_patologicfinal_renacimiento_validati...    0.044129
# unet_new_segmentation_1                               0.101509
# unet_new_segmentation_8                               0.101899
# uloss_new_segmentation_8                              0.101899
# unet_final_renacimiento_validation_7                  0.105085
# ...                                                        ...
# uloss_comparacion_10                                  0.970982
# unet_comparacion_10                                   0.970982
# ueff_                                                      NaN
# uloss_                                                     NaN
# unet_                                                      NaN
#
# [72 rows x 8 columns]

# %%
len(df[df.type == 'uloss'])
# Out:
# 53

# %%
len(df[df.type == 'uloss']) == len(df[df.type == 'unet'])
# Out:
# False

# %%
evaluations = list(df.columns[3:9])

for ev in evaluations:
    print(ev)
    print('unet: {}'.format(np.mean(df[ev][df.type == 'unet'])))
    print('uloss: {}'.format(np.mean(df[ev][df.type == 'uloss'])))
    print('ueff: {}'.format(np.mean(df[ev][df.type == 'ueff'])))
    print('-----')
# Out:
# dice_coef_loss
# unet: 0.06195354997983266
# uloss: 0.09515846900220187
# ueff: 0.07656705734275636
# -----
# loss_mask
# unet: 0.17743373662233353
# uloss: 0.202615628264985
# ueff: 0.19443350320770628
# -----
# accuracy
# unet: 0.9317952980255259
# uloss: 0.9069509641179498
# ueff: 0.9401993950208029
# -----
# AUC
# unet: 0.9391624506177574
# uloss: 0.9161129762541573
# ueff: 0.942155503091358
# -----
# false_positives
# unet: 867366.051724138
# uloss: 1263513.0377358492
# ueff: 215740.19047619047
# -----
# false_negatives
# unet: 642808.8448275862
# uloss: 709474.9056603773
# ueff: 342178.7619047619
# -----

# %%
names = ['_albumentation', 'rotate', 'renacimiento']

# %%
tipos = {}
tipos['unet'] = {}
tipos['uloss'] = {}
tipos['ueff'] = {}

for ev in evaluations:
    tipos['unet'][ev] = np.mean(df[ev][df.type == 'unet'])
    tipos['uloss'][ev] = np.mean(df[ev][df.type == 'uloss'])
    tipos['ueff'][ev] = np.mean(df[ev][df.type == 'uloss'])
    for name in names:
        index = [i for i in df.index if bool(re.search(name, df['name'][i]))]
        try:
            tipos[name][ev] = np.mean(df[ev].iloc[index])
        except:
            tipos[name] = {}
            tipos[name][ev] = np.mean(df[ev].iloc[index])

# %%
tipos
# Out:
# {'unet': {'dice_coef_loss': 0.06195354997983266,
#   'loss_mask': 0.17743373662233353,
#   'accuracy': 0.9317952980255259,
#   'AUC': 0.9391624506177574,
#   'false_positives': 867366.051724138,
#   'false_negatives': 642808.8448275862},
#  'uloss': {'dice_coef_loss': 0.09515846900220187,
#   'loss_mask': 0.202615628264985,
#   'accuracy': 0.9069509641179498,
#   'AUC': 0.9161129762541573,
#   'false_positives': 1263513.0377358492,
#   'false_negatives': 709474.9056603773},
#  'ueff': {'dice_coef_loss': 0.09515846900220187,
#   'loss_mask': 0.202615628264985,
#   'accuracy': 0.9069509641179498,
#   'AUC': 0.9161129762541573,
#   'false_positives': 1263513.0377358492,
#   'false_negatives': 709474.9056603773},
#  '_albumentation': {'dice_coef_loss': 0.03676915168762207,
#   'loss_mask': 0.10717159509658813,
#   'accuracy': 0.9723238945007324,
#   'AUC': 0.9721685945987701,
#   'false_positives': 7447.25,
#   'false_negatives': 7063.0},
#  'rotate': {'dice_coef_loss': 0.03561512505014738,
#   'loss_mask': 0.13074392142395178,
#   'accuracy': 0.9717204322417577,
#   'AUC': 0.9711131105820338,
#   'false_positives': 803023.4166666666,
#   'false_negatives': 1382430.5},
#  'renacimiento': {'dice_coef_loss': 0.028692140376993587,
#   'loss_mask': 0.11508567604635443,
#   'accuracy': 0.9771108350583485,
#   'AUC': 0.9770867909703936,
#   'false_positives': 597291.1785714285,
#   'false_negatives': 641809.6071428572}}

# %%
comparation = {}
for k in tipos['unet'].keys():
    comparation[k] = []
    for j in tipos.keys():
        comparation[k].append(tipos[j][k])
comparation = pd.DataFrame(comparation)
comparation.index = tipos.keys()

# %%
comparation.sort_values('dice_coef_loss')
# Out:
#                 dice_coef_loss  loss_mask  accuracy       AUC  \
# renacimiento          0.028692   0.115086  0.977111  0.977087
# rotate                0.035615   0.130744  0.971720  0.971113
# _albumentation        0.036769   0.107172  0.972324  0.972169
# unet                  0.061954   0.177434  0.931795  0.939162
# uloss                 0.095158   0.202616  0.906951  0.916113
# ueff                  0.095158   0.202616  0.906951  0.916113
#
#                 false_positives  false_negatives
# renacimiento       5.972912e+05     6.418096e+05
# rotate             8.030234e+05     1.382430e+06
# _albumentation     7.447250e+03     7.063000e+03
# unet               8.673661e+05     6.428088e+05
# uloss              1.263513e+06     7.094749e+05
# ueff               1.263513e+06     7.094749e+05

# %%
index = [i for i in df.index if any([bool(re.search(name, df['name'][i])) for name in ['old', 'clahe', 'gamma']])]

# %%
df = df.drop(index).reset_index()

# %%
tipos = {}
for tipo in ['unet', 'uloss', 'ueff']:
    for ev in evaluations:
        for name in names:
            index = [i for i in df.index if bool(re.search(name, df['name'][i]))]
            try:
                tipos[tipo + '_' + name][ev] = np.mean(df[ev].iloc[index][df['type']==tipo])
            except:
                tipos[tipo + '_' + name] = {}
                tipos[tipo + '_' + name][ev] = np.mean(df[ev].iloc[index][df['type']==tipo])

# %%
tipos
# Out:
# {'unet__albumentation': {'dice_coef_loss': 0.03589135408401489,
#   'loss_mask': 0.10652638971805573,
#   'accuracy': 0.9729394912719727,
#   'AUC': 0.972397118806839,
#   'false_positives': 7674.0,
#   'false_negatives': 6513.5},
#  'unet_rotate': {'dice_coef_loss': 0.03600939859946569,
#   'loss_mask': 0.16832411537567774,
#   'accuracy': 0.9713170528411865,
#   'AUC': 0.9701360166072845,
#   'false_positives': 954860.1666666666,
#   'false_negatives': 1612645.0},
#  'unet_renacimiento': {'dice_coef_loss': 0.027937649584868374,
#   'loss_mask': 0.1358441412448883,
#   'accuracy': 0.9776725488550523,
#   'AUC': 0.9772084635846755,
#   'false_positives': 373978.0,
#   'false_negatives': 605332.1176470588},
#  'uloss__albumentation': {'dice_coef_loss': 0.03764694929122925,
#   'loss_mask': 0.10781680047512054,
#   'accuracy': 0.9717082977294922,
#   'AUC': 0.9719400703907014,
#   'false_positives': 7220.5,
#   'false_negatives': 7612.5},
#  'uloss_rotate': {'dice_coef_loss': 0.03522085150082906,
#   'loss_mask': 0.09316372747222583,
#   'accuracy': 0.9721238116423289,
#   'AUC': 0.9720902045567831,
#   'false_positives': 651186.6666666666,
#   'false_negatives': 1152216.0},
#  'uloss_renacimiento': {'dice_coef_loss': 0.0298581716011871,
#   'loss_mask': 0.08300441164862025,
#   'accuracy': 0.9762427319179882,
#   'AUC': 0.9768987514755942,
#   'false_positives': 942411.5454545454,
#   'false_negatives': 698183.9090909091},
#  'ueff__albumentation': {'dice_coef_loss': nan,
#   'loss_mask': nan,
#   'accuracy': nan,
#   'AUC': nan,
#   'false_positives': nan,
#   'false_negatives': nan},
#  'ueff_rotate': {'dice_coef_loss': nan,
#   'loss_mask': nan,
#   'accuracy': nan,
#   'AUC': nan,
#   'false_positives': nan,
#   'false_negatives': nan},
#  'ueff_renacimiento': {'dice_coef_loss': nan,
#   'loss_mask': nan,
#   'accuracy': nan,
#   'AUC': nan,
#   'false_positives': nan,
#   'false_negatives': nan}}

# %%
comparation = {}
for k in tipos['uloss_renacimiento'].keys():
    comparation[k] = []
    for j in tipos.keys():
        comparation[k].append(tipos[j][k])
comparation = pd.DataFrame(comparation)
comparation.index = tipos.keys()

# %%
comparation.sort_values('dice_coef_loss')
# Out:
#                       dice_coef_loss  loss_mask  accuracy       AUC  \
# unet_renacimiento           0.027938   0.135844  0.977673  0.977208
# uloss_renacimiento          0.029858   0.083004  0.976243  0.976899
# uloss_rotate                0.035221   0.093164  0.972124  0.972090
# unet__albumentation         0.035891   0.106526  0.972939  0.972397
# unet_rotate                 0.036009   0.168324  0.971317  0.970136
# uloss__albumentation        0.037647   0.107817  0.971708  0.971940
# ueff__albumentation              NaN        NaN       NaN       NaN
# ueff_rotate                      NaN        NaN       NaN       NaN
# ueff_renacimiento                NaN        NaN       NaN       NaN
#
#                       false_positives  false_negatives
# unet_renacimiento       373978.000000     6.053321e+05
# uloss_renacimiento      942411.545455     6.981839e+05
# uloss_rotate            651186.666667     1.152216e+06
# unet__albumentation       7674.000000     6.513500e+03
# unet_rotate             954860.166667     1.612645e+06
# uloss__albumentation      7220.500000     7.612500e+03
# ueff__albumentation               NaN              NaN
# ueff_rotate                       NaN              NaN
# ueff_renacimiento                 NaN              NaN

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
unet = df[['name'] + evaluations][df.type == 'unet'].reset_index()
uloss = df[['name'] + evaluations][df.type == 'uloss'].reset_index()
ueff = df[['name'] + evaluations][df.type == 'ueff'].reset_index()

fig, ax = plt.subplots(3, 2)
fig.set_size_inches(10,10)

for i, ev in enumerate(evaluations):
    if i%2 == 0:
        y = 0
    else:
        y = 1
    x = int(i/2)
    ax[x,y].boxplot([unet[ev], uloss[ev], ueff[ev]], labels = ['unet', 'uloss', 'ueff'])
    q1, q3 = np.percentile(df[ev], [20, 80])
    r = q1-q3
    ax[x,y].set_ylim(q1-1.1*r, q3+1.1*r)
    ax[x,y].set_title(ev)

# %%
# data = {}
# for tipo in ['unet', 'uloss']:
#     data[tipo] = {}
#     for name in names:
#         d = df[df.type == 'unet'].reset_index()
#         index = [i for i in d.index if bool(re.search(name, d['name'][i]))]
#         data[tipo][name] = d.iloc[index]

# %%
data = {}
for name in names:
    index = [i for i in df.index if bool(re.search(name, df['name'][i]))]
    data[name] = df.iloc[index]

# %%
data
# Out:
# {'_albumentation':    index   type                            name      loss  dice_coef_loss  \
#  0      0   unet  _albumentation_validation_1.h5  0.037296        0.037296
#  1      1  uloss  _albumentation_validation_1.h5  0.141863        0.038948
#  2      2   unet  _albumentation_validation_2.h5  0.034487        0.034487
#  3      3  uloss  _albumentation_validation_2.h5  0.149065        0.036346
#
#     loss_mask  accuracy       AUC  false_positives  false_negatives  doble_loss
#  0   0.117240  0.971939  0.970628           7386.0           7326.0    0.154537
#  1   0.102915  0.970747  0.970617           7504.0           7833.0    0.141863
#  2   0.095812  0.973940  0.974166           7962.0           5701.0    0.130299
#  3   0.112719  0.972670  0.973263           6937.0           7392.0    0.149065  ,
#  'rotate':     index   type                                         name      loss  \
#  4       4   unet          albumentation_rotate_3_validation_1  0.037508
#  5       5   unet          albumentation_rotate_3_validation_2  0.035893
#  6       6  uloss          albumentation_rotate_3_validation_1  0.128454
#  7       7  uloss          albumentation_rotate_3_validation_2  0.129951
#  8       8   unet            validation_rotate_normalization_1  0.038100
#  9       9  uloss            validation_rotate_normalization_1  0.134512
#  49     49   unet  patologic_validation_rotate_normalization_1  0.037598
#  50     50   unet  patologic_validation_rotate_normalization_2  0.034066
#  53     53   unet  patologic_validation_rotate_normalization_3  0.034422
#  59     60  uloss  patologic_validation_rotate_normalization_1  0.121715
#  62     63  uloss  patologic_validation_rotate_normalization_2  0.130081
#  63     64  uloss  patologic_validation_rotate_normalization_3  0.126290
#
#      dice_coef_loss  loss_mask  accuracy       AUC  false_positives  \
#  4         0.036994   0.104480  0.970098  0.969842          87088.0
#  5         0.035434   0.097252  0.971598  0.971085          81626.0
#  6         0.035279   0.092766  0.971818  0.972174          78499.0
#  7         0.034909   0.094568  0.971946  0.973499          87304.0
#  8         0.037542   0.103917  0.969410  0.968877          90885.0
#  9         0.037305   0.097394  0.970390  0.971013          91815.0
#  49        0.037598   0.248425  0.970464  0.968790        1642957.0
#  50        0.034066   0.229497  0.973336  0.971311        1761751.0
#  53        0.034422   0.226372  0.972996  0.970911        2064854.0
#  59        0.033772   0.087943  0.973592  0.972668         937586.0
#  62        0.035721   0.094361  0.971967  0.971112        1290785.0
#  63        0.034340   0.091950  0.973029  0.972075        1421131.0
#
#      false_negatives  doble_loss
#  4          106918.0    0.141474
#  5          102645.0    0.132686
#  6          104346.0    0.128045
#  7           94711.0    0.129478
#  8          107587.0    0.141460
#  9          100297.0    0.134699
#  49        2756279.0    0.286023
#  50        2986977.0    0.263564
#  53        3615464.0    0.260794
#  59        1733331.0    0.121715
#  62        2328724.0    0.130081
#  63        2551887.0    0.126290  ,
#  'renacimiento':      index   type                                            name      loss  \
#  10      10   unet                       renacimiento_validation_1  0.032621
#  12      12   unet                       renacimiento_validation_2  0.032413
#  13      13  uloss                       renacimiento_validation_2  0.131064
#  14      14   unet                       renacimiento_validation_3  0.033088
#  15      15  uloss                       renacimiento_validation_3  0.119526
#  16      16   unet                       renacimiento_validation_4  0.034823
#  17      17  uloss                       renacimiento_validation_4  0.119882
#  18      18   unet                 final_renacimiento_validation_5  0.030735
#  19      19  uloss                 final_renacimiento_validation_6  0.102747
#  20      20   unet                 final_renacimiento_validation_6  0.027842
#  21      21   unet                 final_renacimiento_validation_7  0.028393
#  22      22  uloss                 final_renacimiento_validation_8  0.100469
#  23      23   unet                 final_renacimiento_validation_8  0.034788
#  37      37   unet       patologic_final_renacimiento_validation_7  0.028050
#  38      38   unet       patologic_final_renacimiento_validation_8  0.028280
#  39      39   unet             patologic_renacimiento_validation_2  0.029483
#  40      40   unet             patologic_renacimiento_validation_3  0.030374
#  42      42   unet       patologic_final_renacimiento_validation_6  0.010329
#  45      45   unet             patologic_renacimiento_validation_4  0.032370
#  47      47   unet       patologic_final_renacimiento_validation_5  0.026621
#  48      48   unet             patologic_renacimiento_validation_1  0.028204
#  54      55  uloss       patologic_final_renacimiento_validation_8  0.109311
#  55      56  uloss             patologic_renacimiento_validation_2  0.120208
#  56      57  uloss       patologic_final_renacimiento_validation_6  0.104725
#  57      58  uloss             patologic_renacimiento_validation_3  0.111251
#  58      59  uloss             patologic_renacimiento_validation_4  0.115367
#  68      69  uloss       patologic_final_renacimiento_validation_8  0.109311
#  130    131   unet  paper_patologicfinal_renacimiento_validation_6  0.010329
#
#       dice_coef_loss  loss_mask  accuracy       AUC  false_positives  \
#  10         0.032179   0.092485  0.973949  0.974434          88665.0
#  12         0.031955   0.089793  0.974418  0.973736          70983.0
#  13         0.034971   0.095523  0.971893  0.973108          74191.0
#  14         0.032720   0.098321  0.973591  0.974356          92355.0
#  15         0.030919   0.088200  0.975120  0.976994          80190.0
#  16         0.034295   0.098386  0.972277  0.971930          88000.0
#  17         0.030873   0.088655  0.975076  0.976777          80748.0
#  18         0.030172   0.084180  0.975373  0.975297          76188.0
#  19         0.028376   0.073854  0.976893  0.977792          70053.0
#  20         0.027473   0.078634  0.977579  0.977706          72640.0
#  21         0.027809   0.077276  0.977255  0.977421          72967.0
#  22         0.026820   0.073125  0.978087  0.979268          68079.0
#  23         0.034296   0.092406  0.972122  0.972886          93011.0
#  37         0.028050   0.208446  0.977999  0.977043         109233.0
#  38         0.028280   0.201186  0.977707  0.977706         231254.0
#  39         0.029483   0.207453  0.976890  0.974784         409416.0
#  40         0.030374   0.226983  0.976103  0.975419         573974.0
#  42         0.010329   0.084500  0.991868  0.990991         728103.0
#  45         0.032370   0.229676  0.974542  0.972990         975316.0
#  47         0.026621   0.196282  0.979081  0.977774        1146235.0
#  48         0.028204   0.209544  0.977812  0.977078        1499667.0
#  54         0.028401   0.080910  0.977675  0.977669         101605.0
#  55         0.033043   0.087165  0.974292  0.974027         249264.0
#  56         0.027288   0.077437  0.978551  0.978354         342536.0
#  57         0.029183   0.082068  0.977041  0.977651         444439.0
#  58         0.030165   0.085202  0.976367  0.976576         545836.0
#  68         0.028401   0.080910  0.977675  0.977669        8309586.0
#  130        0.010329   0.033800  0.991868  0.990991          29619.0
#
#       false_negatives  doble_loss
#  10           80353.0    0.124665
#  12           94992.0    0.121748
#  13          108172.0    0.130494
#  14           78991.0    0.131041
#  15           81231.0    0.119119
#  16           91869.0    0.132681
#  17           80958.0    0.119528
#  18           85209.0    0.114352
#  19           81382.0    0.102230
#  20           74298.0    0.106107
#  21           76094.0    0.105085
#  22           75530.0    0.099945
#  23           89689.0    0.126702
#  37          179141.0    0.236496
#  38          349315.0    0.229465
#  39          705976.0    0.236936
#  40         1000683.0    0.257357
#  42         1223909.0    0.094829
#  45         1590943.0    0.262046
#  47         1979773.0    0.222902
#  48         2512436.0    0.237748
#  54          191015.0    0.109311
#  55          536778.0    0.120208
#  56          724644.0    0.104725
#  57          923666.0    0.111251
#  58         1132029.0    0.115367
#  68         3744618.0    0.109311
#  130          76975.0    0.044129  }

# %%
len(datos_unet)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-a254ba56c680> in <module>
# ----> 1 len(datos_unet)
#
# NameError: name 'datos_unet' is not defined

# %%
fig, ax = plt.subplots(3, 2)
fig.set_size_inches(20,30)

for i, ev in enumerate(evaluations):
    if i%2 == 0:
        y = 0
    else:
        y = 1
    x = int(i/2)
    datos_unet = [data[name][ev][data[name].type == 'unet'] for name in names]
    datos_uloss = [data[name][ev][data[name].type == 'uloss'] for name in names]
    labels = [name + '_unet' for name in names]
    ax[x,y].boxplot(datos_unet, positions = [1,3,5], patch_artist=True)
    labels = [name + '_uloss' for name in names]
    ax[x,y].boxplot(datos_uloss, positions = [2,4,6])
    q1, q3 = np.percentile(df[ev], [25, 75])
    r = q1-q3
    ax[x,y].set_xticklabels(names*2, rotation=90)
    ax[x,y].set_ylim(q1-3*r, q3+3*r)
    ax[x,y].set_title(ev)
