# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import SimpleITK as sitk

# %% [markdown]
# # Datos

# %%
# path = 'D:/Users/maryskal/Documents/SITK/CXR8/images/images_001'
path = '/home/mr1142/Documents/Data/segmentation'

# %%
masks_name = os.listdir(os.path.join(path, 'mascara'))

# %%
pixels = 256

# %%
def read_img(path, folder, img):
    img = cv2.imread(os.path.join(path, folder, img))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    img = cv2.resize(img, (pixels, pixels))
    img = np.expand_dims(img, axis=-1)
    return img

# %%
def normalize(img):
    return (img - np.mean(img))/ np.std(img)

# %%
def binarize(img):
    img[img>0] = 1
    return img

# %%
masks = np.zeros((len(masks_name), pixels,pixels,1))
for i in range(len(masks_name)):
    masks[i, ...] = binarize(read_img(path, 'mascara', masks_name[i]))

# %%
images = np.zeros((len(masks_name), pixels,pixels,1))
for i in range(len(masks_name)):
    images[i, ...] = normalize(read_img(path, 'images', masks_name[i]))

# %%
r = np.random.randint(0, len(images))
plt.figure(figsize=(10, 10))
plt.subplot(1,2,1)
plt.imshow(masks[r])
plt.subplot(1,2,2)
plt.imshow(images[r])
plt.show()

# %%
images.shape
# Out:
# (300, 256, 256, 1)

# %% [markdown]
# # Aumento de datos

# %%
import imutils

# %%
def augment(input_image, input_mask):
    r = np.random.randint(-60,60)
    # Random flipping of the image and mask
    input_image = np.expand_dims(imutils.rotate(input_image, angle=r),  axis=-1)
    input_mask = np.expand_dims(imutils.rotate(input_mask, angle=r), axis=-1)
    return input_image, input_mask

# %% [markdown]
# Nuevas imagenes con rotacion random

# %%
new_img = np.zeros((len(masks_name), pixels,pixels,1))
new_mask = np.zeros((len(masks_name), pixels,pixels,1))
for i in range(len(masks_name)):
    img, mask = augment(images[i], masks[i])
    new_img[i, ...] = img
    new_mask[i,...] = mask

# %%
images = np.concatenate((new_img, images), axis = 0)
masks = np.concatenate((new_mask, masks), axis = 0)
# importance = np.concatenate((importance, importance), axis=0)

# %%
r = np.random.randint(0, len(images))
plt.figure(figsize=(10, 10))
plt.subplot(1,2,1)
plt.imshow(images[r])
plt.subplot(1,2,2)
plt.imshow(masks[r])
plt.show()

# %%
images.shape
# Out:
# (600, 256, 256, 1)

# %%
masks.shape
# Out:
# (600, 256, 256, 1)

# %% [markdown]
# # U-Net

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow_datasets as tfds

# %%
os.environ['CUDA_VISIBLE_DEVICES'] = '2'

# %%
def double_conv_block(x, n_filters):
    # Conv2D then eLU activation
    x = layers.Conv2D(n_filters, 3, padding = "same", activation = "elu", kernel_initializer = "he_normal")(x)
    # Conv2D then eLU activation
    x = layers.Conv2D(n_filters, 3, padding = "same", activation = "elu", kernel_initializer = "he_normal")(x)
    return x


def downsample_block(x, n_filters):
    f = double_conv_block(x, n_filters)
    p = layers.MaxPool2D(2)(f)
    p = layers.Dropout(0.3)(p)
    return f, p


def upsample_block(x, conv_features, n_filters):
    # upsample
    x = layers.Conv2DTranspose(n_filters, 3, 2, padding="same")(x)
    # concatenate
    x = layers.concatenate([x, conv_features])
    # dropout
    x = layers.Dropout(0.3)(x)
    # Conv2D twice with eLU activation
    x = double_conv_block(x, n_filters)
    return x

# %%
def build_unet_model():
     # inputs
    inputs = layers.Input(shape=(pixels,pixels,1))

    # encoder: contracting path - downsample
    # 1 - downsample
    f1, p1 = downsample_block(inputs, 64)
    # 2 - downsample
    f2, p2 = downsample_block(p1, 128)
    # 3 - downsample
    f3, p3 = downsample_block(p2, 256)
    # 4 - downsample
    f4, p4 = downsample_block(p3, 512)

    # 5 - bottleneck
    bottleneck = double_conv_block(p4, 1024)

    # decoder: expanding path - upsample
    # 6 - upsample
    u6 = upsample_block(bottleneck, f4, 512)
    # 7 - upsample
    u7 = upsample_block(u6, f3, 256)
    # 8 - upsample
    u8 = upsample_block(u7, f2, 128)
    # 9 - upsample
    u9 = upsample_block(u8, f1, 64)

    # outputs
    outputs = layers.Conv2D(3, 1, padding="same", activation = "softmax")(u9)

    # unet model with Keras Functional API
    unet_model = tf.keras.Model(inputs, outputs, name="U-Net")

    return unet_model

# %%
unet_model = build_unet_model()

# %%
unet_model.summary()
# Out:
# Model: "U-Net"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 1) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 256, 256, 64) 640         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 256, 256, 64) 36928       conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 128, 128, 64) 0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 128, 128, 64) 0           max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 128, 128, 128 73856       dropout[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 128, 128, 128 147584      conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 128)  0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 64, 64, 128)  0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 64, 256)  295168      dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 64, 64, 256)  590080      conv2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 256)  0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 32, 32, 256)  0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 512)  1180160     dropout_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 512)  2359808     conv2d_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 512)  0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 16, 16, 512)  0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 1024) 4719616     dropout_3[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 1024) 9438208     conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 32, 32, 512)  4719104     conv2d_9[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 32, 32, 1024) 0           conv2d_transpose[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 32, 32, 1024) 0           concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 32, 32, 512)  4719104     dropout_4[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 32, 32, 512)  2359808     conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 64, 64, 256)  1179904     conv2d_11[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 64, 64, 512)  0           conv2d_transpose_1[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 64, 64, 512)  0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 64, 64, 256)  1179904     dropout_5[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 64, 64, 256)  590080      conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 128, 128, 128 295040      conv2d_13[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 128, 128, 256 0           conv2d_transpose_2[0][0]
#                                                                  conv2d_3[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 128, 128, 256 0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 128, 128, 128 295040      dropout_6[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 128, 128, 128 147584      conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 256, 256, 64) 73792       conv2d_15[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 256, 256, 128 0           conv2d_transpose_3[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 256, 256, 128 0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 256, 256, 64) 73792       dropout_7[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 256, 256, 64) 36928       conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 256, 256, 3)  195         conv2d_17[0][0]
# ==================================================================================================
# Total params: 34,512,323
# Trainable params: 34,512,323
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
import datetime
log_dir = "/home/mr1142/Documents/Data/logs/fit/" + 'U-Net1_3chanel_' + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir,
                                                      update_freq='batch',
                                                      histogram_freq=1)

early_stop = tf.keras.callbacks.EarlyStopping(monitor="val_loss", restore_best_weights=True, patience = 10)

# %%
unet_model.compile(optimizer=tf.keras.optimizers.Adam(),
                  loss='sparse_categorical_crossentropy',
                  metrics=["accuracy", "mean_squared_error"])

# %%
batch = 8
epoch = 500

# %%
history = unet_model.fit(images,masks,
                         batch_size = batch,
                         epochs = epoch,
                         callbacks = [tensorboard_callback, early_stop],
                         # sample_weight = importance,
                         shuffle = True,
                         verbose = 2,
                         validation_split = 0.2)
# Out:
# Epoch 1/500
# 60/60 - 66s - loss: 2.0864 - accuracy: 0.6027 - mean_squared_error: 0.3704 - val_loss: 0.5428 - val_accuracy: 0.7109 - val_mean_squared_error: 0.3421
# Epoch 2/500
# 60/60 - 19s - loss: 0.4991 - accuracy: 0.7461 - mean_squared_error: 0.3680 - val_loss: 0.3935 - val_accuracy: 0.8185 - val_mean_squared_error: 0.3685
# Epoch 3/500
# 60/60 - 18s - loss: 0.3603 - accuracy: 0.8396 - mean_squared_error: 0.3912 - val_loss: 0.3445 - val_accuracy: 0.8499 - val_mean_squared_error: 0.3977
# Epoch 4/500
# 60/60 - 19s - loss: 0.3224 - accuracy: 0.8624 - mean_squared_error: 0.4009 - val_loss: 0.2785 - val_accuracy: 0.8895 - val_mean_squared_error: 0.4026
# Epoch 5/500
# 60/60 - 19s - loss: 0.2790 - accuracy: 0.8828 - mean_squared_error: 0.4074 - val_loss: 0.2208 - val_accuracy: 0.9136 - val_mean_squared_error: 0.4088
# Epoch 6/500
# 60/60 - 19s - loss: 0.2355 - accuracy: 0.9020 - mean_squared_error: 0.4166 - val_loss: 0.1881 - val_accuracy: 0.9244 - val_mean_squared_error: 0.4238
# Epoch 7/500
# 60/60 - 19s - loss: 0.2143 - accuracy: 0.9099 - mean_squared_error: 0.4212 - val_loss: 0.2036 - val_accuracy: 0.9179 - val_mean_squared_error: 0.4200
# Epoch 8/500
# 60/60 - 19s - loss: 0.2400 - accuracy: 0.8982 - mean_squared_error: 0.4169 - val_loss: 0.1863 - val_accuracy: 0.9279 - val_mean_squared_error: 0.4303
# Epoch 9/500
# 60/60 - 19s - loss: 0.2007 - accuracy: 0.9151 - mean_squared_error: 0.4238 - val_loss: 0.1664 - val_accuracy: 0.9349 - val_mean_squared_error: 0.4284
# Epoch 10/500
# 60/60 - 19s - loss: 0.1759 - accuracy: 0.9263 - mean_squared_error: 0.4281 - val_loss: 0.1484 - val_accuracy: 0.9416 - val_mean_squared_error: 0.4334
# Epoch 11/500
# 60/60 - 19s - loss: 0.1629 - accuracy: 0.9312 - mean_squared_error: 0.4315 - val_loss: 0.1666 - val_accuracy: 0.9373 - val_mean_squared_error: 0.4267
# Epoch 12/500
# 60/60 - 19s - loss: 0.1571 - accuracy: 0.9328 - mean_squared_error: 0.4317 - val_loss: 0.1348 - val_accuracy: 0.9505 - val_mean_squared_error: 0.4255
# Epoch 13/500
# 60/60 - 19s - loss: 0.1443 - accuracy: 0.9385 - mean_squared_error: 0.4343 - val_loss: 0.1344 - val_accuracy: 0.9478 - val_mean_squared_error: 0.4299
# Epoch 14/500
# 60/60 - 19s - loss: 0.1380 - accuracy: 0.9409 - mean_squared_error: 0.4354 - val_loss: 0.1113 - val_accuracy: 0.9555 - val_mean_squared_error: 0.4424
# Epoch 15/500
# 60/60 - 19s - loss: 0.1322 - accuracy: 0.9432 - mean_squared_error: 0.4368 - val_loss: 0.1109 - val_accuracy: 0.9551 - val_mean_squared_error: 0.4416
# Epoch 16/500
# 60/60 - 19s - loss: 0.1373 - accuracy: 0.9401 - mean_squared_error: 0.4357 - val_loss: 0.1526 - val_accuracy: 0.9412 - val_mean_squared_error: 0.4430
# Epoch 17/500
# 60/60 - 19s - loss: 0.1394 - accuracy: 0.9407 - mean_squared_error: 0.4355 - val_loss: 0.1133 - val_accuracy: 0.9543 - val_mean_squared_error: 0.4401
# Epoch 18/500
# 60/60 - 19s - loss: 0.1205 - accuracy: 0.9476 - mean_squared_error: 0.4390 - val_loss: 0.1007 - val_accuracy: 0.9595 - val_mean_squared_error: 0.4447
# Epoch 19/500
# 60/60 - 19s - loss: 0.1197 - accuracy: 0.9490 - mean_squared_error: 0.4391 - val_loss: 0.1141 - val_accuracy: 0.9545 - val_mean_squared_error: 0.4428
# Epoch 20/500
# 60/60 - 19s - loss: 0.1092 - accuracy: 0.9528 - mean_squared_error: 0.4417 - val_loss: 0.0934 - val_accuracy: 0.9628 - val_mean_squared_error: 0.4443
# Epoch 21/500
# 60/60 - 19s - loss: 0.1068 - accuracy: 0.9527 - mean_squared_error: 0.4415 - val_loss: 0.1024 - val_accuracy: 0.9614 - val_mean_squared_error: 0.4465
# Epoch 22/500
# 60/60 - 19s - loss: 0.1002 - accuracy: 0.9550 - mean_squared_error: 0.4429 - val_loss: 0.0823 - val_accuracy: 0.9668 - val_mean_squared_error: 0.4474
# Epoch 23/500
# 60/60 - 19s - loss: 0.0971 - accuracy: 0.9566 - mean_squared_error: 0.4430 - val_loss: 0.0958 - val_accuracy: 0.9636 - val_mean_squared_error: 0.4476
# Epoch 24/500
# 60/60 - 19s - loss: 0.0971 - accuracy: 0.9562 - mean_squared_error: 0.4438 - val_loss: 0.0877 - val_accuracy: 0.9657 - val_mean_squared_error: 0.4409
# Epoch 25/500
# 60/60 - 19s - loss: 0.0825 - accuracy: 0.9620 - mean_squared_error: 0.4457 - val_loss: 0.0878 - val_accuracy: 0.9654 - val_mean_squared_error: 0.4496
# Epoch 26/500
# 60/60 - 19s - loss: 0.0843 - accuracy: 0.9608 - mean_squared_error: 0.4456 - val_loss: 0.0947 - val_accuracy: 0.9641 - val_mean_squared_error: 0.4475
# Epoch 27/500
# 60/60 - 19s - loss: 0.0856 - accuracy: 0.9612 - mean_squared_error: 0.4452 - val_loss: 0.0868 - val_accuracy: 0.9654 - val_mean_squared_error: 0.4486
# Epoch 28/500
# 60/60 - 19s - loss: 0.0841 - accuracy: 0.9612 - mean_squared_error: 0.4459 - val_loss: 0.0806 - val_accuracy: 0.9683 - val_mean_squared_error: 0.4458
# Epoch 29/500
# 60/60 - 19s - loss: 0.0735 - accuracy: 0.9653 - mean_squared_error: 0.4475 - val_loss: 0.0774 - val_accuracy: 0.9691 - val_mean_squared_error: 0.4494
# Epoch 30/500
# 60/60 - 19s - loss: 0.0686 - accuracy: 0.9673 - mean_squared_error: 0.4484 - val_loss: 0.0788 - val_accuracy: 0.9676 - val_mean_squared_error: 0.4489
# Epoch 31/500
# 60/60 - 19s - loss: 0.0664 - accuracy: 0.9680 - mean_squared_error: 0.4490 - val_loss: 0.0797 - val_accuracy: 0.9685 - val_mean_squared_error: 0.4501
# Epoch 32/500
# 60/60 - 19s - loss: 0.0716 - accuracy: 0.9662 - mean_squared_error: 0.4481 - val_loss: 0.0882 - val_accuracy: 0.9654 - val_mean_squared_error: 0.4488
# Epoch 33/500
# 60/60 - 19s - loss: 0.0774 - accuracy: 0.9640 - mean_squared_error: 0.4467 - val_loss: 0.0787 - val_accuracy: 0.9697 - val_mean_squared_error: 0.4515
# Epoch 34/500
# 60/60 - 19s - loss: 0.0673 - accuracy: 0.9675 - mean_squared_error: 0.4488 - val_loss: 0.0773 - val_accuracy: 0.9693 - val_mean_squared_error: 0.4499
# Epoch 35/500
# 60/60 - 19s - loss: 0.0659 - accuracy: 0.9678 - mean_squared_error: 0.4490 - val_loss: 0.0775 - val_accuracy: 0.9689 - val_mean_squared_error: 0.4495
# Epoch 36/500
# 60/60 - 19s - loss: 0.0609 - accuracy: 0.9700 - mean_squared_error: 0.4498 - val_loss: 0.0811 - val_accuracy: 0.9690 - val_mean_squared_error: 0.4517
# Epoch 37/500
# 60/60 - 19s - loss: 0.0571 - accuracy: 0.9714 - mean_squared_error: 0.4505 - val_loss: 0.0808 - val_accuracy: 0.9704 - val_mean_squared_error: 0.4532
# Epoch 38/500
# 60/60 - 19s - loss: 0.0543 - accuracy: 0.9726 - mean_squared_error: 0.4512 - val_loss: 0.0725 - val_accuracy: 0.9711 - val_mean_squared_error: 0.4516
# Epoch 39/500
# 60/60 - 19s - loss: 0.0543 - accuracy: 0.9725 - mean_squared_error: 0.4511 - val_loss: 0.0738 - val_accuracy: 0.9717 - val_mean_squared_error: 0.4529
# Epoch 40/500
# 60/60 - 19s - loss: 0.0509 - accuracy: 0.9738 - mean_squared_error: 0.4518 - val_loss: 0.0775 - val_accuracy: 0.9706 - val_mean_squared_error: 0.4522
# Epoch 41/500
# 60/60 - 19s - loss: 0.0528 - accuracy: 0.9731 - mean_squared_error: 0.4514 - val_loss: 0.0755 - val_accuracy: 0.9713 - val_mean_squared_error: 0.4521
# Epoch 42/500
# 60/60 - 19s - loss: 0.0518 - accuracy: 0.9734 - mean_squared_error: 0.4517 - val_loss: 0.0893 - val_accuracy: 0.9669 - val_mean_squared_error: 0.4508
# Epoch 43/500
# 60/60 - 19s - loss: 0.0586 - accuracy: 0.9710 - mean_squared_error: 0.4502 - val_loss: 0.0746 - val_accuracy: 0.9721 - val_mean_squared_error: 0.4532
# Epoch 44/500
# 60/60 - 19s - loss: 0.0510 - accuracy: 0.9739 - mean_squared_error: 0.4518 - val_loss: 0.0760 - val_accuracy: 0.9716 - val_mean_squared_error: 0.4528
# Epoch 45/500
# 60/60 - 19s - loss: 0.1004 - accuracy: 0.9564 - mean_squared_error: 0.4432 - val_loss: 0.0938 - val_accuracy: 0.9638 - val_mean_squared_error: 0.4407
# Epoch 46/500
# 60/60 - 19s - loss: 0.0738 - accuracy: 0.9656 - mean_squared_error: 0.4477 - val_loss: 0.0827 - val_accuracy: 0.9673 - val_mean_squared_error: 0.4496
# Epoch 47/500
# 60/60 - 19s - loss: 0.0654 - accuracy: 0.9684 - mean_squared_error: 0.4490 - val_loss: 0.0807 - val_accuracy: 0.9692 - val_mean_squared_error: 0.4518
# Epoch 48/500
# 60/60 - 19s - loss: 0.0535 - accuracy: 0.9730 - mean_squared_error: 0.4514 - val_loss: 0.0705 - val_accuracy: 0.9707 - val_mean_squared_error: 0.4521
# Epoch 49/500
# 60/60 - 19s - loss: 0.0519 - accuracy: 0.9734 - mean_squared_error: 0.4516 - val_loss: 0.0776 - val_accuracy: 0.9701 - val_mean_squared_error: 0.4521
# Epoch 50/500
# 60/60 - 19s - loss: 0.0509 - accuracy: 0.9739 - mean_squared_error: 0.4518 - val_loss: 0.0781 - val_accuracy: 0.9698 - val_mean_squared_error: 0.4521
# Epoch 51/500
# 60/60 - 19s - loss: 0.0637 - accuracy: 0.9692 - mean_squared_error: 0.4496 - val_loss: 0.0840 - val_accuracy: 0.9671 - val_mean_squared_error: 0.4505
# Epoch 52/500
# 60/60 - 19s - loss: 0.0566 - accuracy: 0.9716 - mean_squared_error: 0.4507 - val_loss: 0.0846 - val_accuracy: 0.9697 - val_mean_squared_error: 0.4526
# Epoch 53/500
# 60/60 - 19s - loss: 0.0524 - accuracy: 0.9733 - mean_squared_error: 0.4514 - val_loss: 0.0757 - val_accuracy: 0.9716 - val_mean_squared_error: 0.4528
# Epoch 54/500
# 60/60 - 19s - loss: 0.0473 - accuracy: 0.9751 - mean_squared_error: 0.4524 - val_loss: 0.0751 - val_accuracy: 0.9722 - val_mean_squared_error: 0.4531
# Epoch 55/500
# 60/60 - 19s - loss: 0.0442 - accuracy: 0.9764 - mean_squared_error: 0.4531 - val_loss: 0.0706 - val_accuracy: 0.9733 - val_mean_squared_error: 0.4534
# Epoch 56/500
# 60/60 - 19s - loss: 0.0432 - accuracy: 0.9768 - mean_squared_error: 0.4532 - val_loss: 0.0761 - val_accuracy: 0.9726 - val_mean_squared_error: 0.4541
# Epoch 57/500
# 60/60 - 19s - loss: 0.0412 - accuracy: 0.9775 - mean_squared_error: 0.4536 - val_loss: 0.0745 - val_accuracy: 0.9738 - val_mean_squared_error: 0.4545
# Epoch 58/500
# 60/60 - 19s - loss: 0.0414 - accuracy: 0.9774 - mean_squared_error: 0.4536 - val_loss: 0.0793 - val_accuracy: 0.9720 - val_mean_squared_error: 0.4538

# %% [markdown]
# # Validación

# %%
path = '/home/mr1142/Documents/Data/NIH/images_005'

# %%
val_names = os.listdir('/home/mr1142/Documents/Data/NIH/images_005/images')

# %%
def apply_mask(img, mask):
    mask = mask[...,1]
    mask = cv2.blur(mask, (5,5))
    mask[mask>0.3]=1
    img[mask!=1]=0
    return img

# %%
r = np.random.randint(0, len(val_names))
img = normalize(read_img(path, 'images', val_names[r]))
mask = unet_model.predict(img[np.newaxis,...])[0,...]
plt.figure(figsize=(20, 20))
plt.subplot(1,3,1)
plt.imshow(img, cmap = 'gray')
plt.subplot(1,3,2)
plt.imshow(mask[...,1], cmap = 'gray')
plt.subplot(1,3,3)
plt.imshow(apply_mask(img, mask), cmap = 'gray')
plt.show()

# %%
unet_model.save('/home/mr1142/Documents/Data/models/unet_3chanels.h5')
