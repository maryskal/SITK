# %%
import os
import numpy as np
import cv2
import tensorflow.keras as keras
import matplotlib.pyplot as plt
import re
import pandas as pd
from skimage import measure
from scipy import ndimage

# %%
os.environ['CUDA_VISIBLE_DEVICES'] = '3'

# %%
path = '/home/mr1142/Documents/Data/NIH/images_005'
val_names = os.listdir('/home/mr1142/Documents/Data/NIH/images_005/images')

# %% [markdown]
# # Set de validación

# %%
# path = 'D:/Users/maryskal/Documents/SITK/CXR8/images/images_001'
path = '/home/mr1142/Documents/Data/patologic'

# %%
masks_name = [f for f in os.listdir(os.path.join(path, 'mascara')) 
              if os.path.isfile(os.path.join(os.path.join(path, 'mascara'), f))]

# %%
path = '/home/mr1142/Documents/Data/NIH/images_001/images'
masks_name = [f for f in os.listdir(os.path.join(path)) 
              if os.path.isfile(os.path.join(os.path.join(path), f))]

# %%
len(masks_name)
# Out:
# 4999

# %%
pixels = 256

# %%
def read_img(path, folder, img):
    img = cv2.imread(os.path.join(path, folder, img))
    try:
        img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    except:
        print('', end='')
    img = cv2.resize(img, (pixels, pixels))
    img = np.expand_dims(img, axis=-1)
    return img

# %%
def normalize(img):
    return (img - np.mean(img))/ np.std(img)
    # return img/np.max(img)

# %%
def binarize(img):
    img[img>0] = 1
    return img

# %% [markdown]
# # Preprocesado de imagen de entrada al modelo

# %%
modelos = os.listdir('/home/mr1142/Documents/Data/models')
modelos.sort()
modelos
# Out:
# ['imagenes.h5',
#  'mask_1.h5',
#  'ueff_1.h5',
#  'ueff_2.h5',
#  'uloss_1.h5',
#  'uloss_2.h5',
#  'uloss_final_renacimiento_validation_6.h5',
#  'uloss_final_renacimiento_validation_8.h5',
#  'uloss_final_renacimiento_validation_8_fine_tuning.h5',
#  'uloss_final_renacimiento_validation_8_fine_tuning_1.h5',
#  'uloss_final_renacimiento_validation_8_fine_tuning_2.h5',
#  'uloss_final_renacimiento_validation_8_fine_tuning_3.h5',
#  'uloss_final_renacimiento_validation_8_fine_tuning_4.h5',
#  'uloss_new_segmentation_2.h5',
#  'uloss_new_segmentation_3.h5',
#  'uloss_new_segmentation_5.h5',
#  'uloss_new_segmentation_6.h5',
#  'uloss_new_segmentation_7.h5',
#  'uloss_new_segmentation_8.h5',
#  'uloss_renacimiento_validation_2.h5',
#  'uloss_renacimiento_validation_3.h5',
#  'uloss_renacimiento_validation_4.h5',
#  'uloss_validation_rotate_normalization_1.h5',
#  'uloss_validation_rotate_normalization_2.h5',
#  'uloss_validation_rotate_normalization_3.h5',
#  'unet3.h5',
#  'unet_1.h5',
#  'unet_2.h5',
#  'unet_3.h5',
#  'unet_final_renacimiento_validation_5.h5',
#  'unet_final_renacimiento_validation_6.h5',
#  'unet_final_renacimiento_validation_6.h5_fine_tuning.h5',
#  'unet_final_renacimiento_validation_6_fine_tuning.h5',
#  'unet_final_renacimiento_validation_6_fine_tuning_1.h5',
#  'unet_final_renacimiento_validation_6_fine_tuning_2.h5',
#  'unet_final_renacimiento_validation_6_fine_tuning_3.h5',
#  'unet_final_renacimiento_validation_6_fine_tuning_4.h5',
#  'unet_final_renacimiento_validation_7.h5',
#  'unet_final_renacimiento_validation_8.h5',
#  'unet_new_segmentation_1.h5',
#  'unet_new_segmentation_2.h5',
#  'unet_new_segmentation_3.h5',
#  'unet_new_segmentation_7.h5',
#  'unet_new_segmentation_8.h5',
#  'unet_nuevos_validation_oldest_1.h5',
#  'unet_renacimiento_validation_1.h5',
#  'unet_renacimiento_validation_2.h5',
#  'unet_renacimiento_validation_3.h5',
#  'unet_renacimiento_validation_4.h5',
#  'unet_validation_rotate_normalization_1.h5',
#  'unet_validation_rotate_normalization_2.h5',
#  'unet_validation_rotate_normalization_3.h5',
#  'validation_results']

# %%
from tensorflow.keras import backend as K

def dice_coef(y_true, y_pred, smooth=100):        
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    dice = (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return dice

def dice_coef_loss(y_true, y_pred):
    return 1 - dice_coef(y_true, y_pred)

# %%
def loss_mask(y_true, y_pred):
    y_pred = sub_mask(y_pred)
    y_true = sub_mask(y_true)
    return abs(y_true - y_pred)


def MyLoss(y_true, y_pred):
    # Loss 1
    loss1 = ex.dice_coef_loss(y_true, y_pred)
    # Loss 2
    loss2 = loss_mask(y_true, y_pred)
    loss = loss1 + 0.5*loss2
    return loss

# %%
def quitar_trozos(mask):
    mask = measure.label(mask)
    # regions = regionprops(all_labels)
    ntotal = {k: (k==mask).sum() for k in np.unique(mask) if k >0}
    print(ntotal)
    k = list(ntotal.keys())[np.argmax(list(ntotal.values()))]
    print(k)
    mask = k==mask
    mask = ndimage.binary_fill_holes(mask,structure=np.ones((5,5,1)))
    return mask

# %%
def apply_mask(img, mask):
    mask = quitar_trozos(mask > 0.5)
    return img * mask

# %% [markdown]
# # 1 canal

# %%
unet = keras.models.load_model('/home/mr1142/Documents/Data/models/unet_new_segmentation_1.h5', 
                                     custom_objects={"MyLoss": MyLoss, 
                                                     "loss_mask": loss_mask, 
                                                     "dice_coef_loss": dice_coef_loss,
                                                     "dice_coef": dice_coef})

# %% [markdown]
# # Custom loss mejorada

# %%
uloss = keras.models.load_model('/home/mr1142/Documents/Data/models/unet_final_renacimiento_validation_6.h5', 
                                     custom_objects={"MyLoss": MyLoss, 
                                                     "loss_mask": loss_mask, 
                                                     "dice_coef_loss": dice_coef_loss,
                                                     "dice_coef": dice_coef})

# %%
# path = 'D:/Users/maryskal/Documents/SITK/CXR8/images/images_001'
path = '/home/mr1142/Documents/Data/patologic/images'

# %%
masks_name = [f for f in os.listdir(os.path.join(path, '')) 
              if os.path.isfile(os.path.join(os.path.join(path, ''), f))]

# %%
a = ndimage.binary_fill_holes(quitar_trozos(net_mask>0.5), structure=np.ones((5,5,1)))
# Out:
# {1: 25906}
# 1

# %%
plt.imshow(a)

# %%
r = 0

# %%
un = 0
ul = 0

# %%
# r = np.random.randint(0, len(masks_name))
img = normalize(read_img(path, '', masks_name[r]))
net_mask = unet.predict(img[np.newaxis,...])[0,...]
loss_mask = uloss.predict(img[np.newaxis,...])[0,...]

plt.figure(figsize=(20, 20))
plt.subplot(1,3,1)
plt.imshow(img, cmap = 'gray')
plt.subplot(1,3,2)
plt.imshow(apply_mask(img, net_mask), cmap = 'gray')
# plt.imshow(apply_mask(img, loss_mask), cmap = 'gray')
plt.subplot(1,3,3)
plt.imshow(apply_mask(img, loss_mask), cmap = 'gray')
# plt.imshow(apply_mask(img, net_mask), cmap = 'gray')
plt.show()
r += 1
# Out:
# {1: 2, 2: 21140}
# 2
# {1: 20679}
# 1

# %%
r
# Out:
# -0.27462686567164196

# %%
ul += 1
ul
# Out:
# 13

# %%
un += 1
un
# Out:
# 21

# %% [markdown]
# # Ver los agujeros

# %%
datos = {}

# %%
path = '/home/mr1142/Documents/Data/patologic/images'
images = [f for f in os.listdir(path) 
              if os.path.isfile(os.path.join(path, f))]

# %%
len(images)
# Out:
# 200

# %%
r = np.random.randint(0,len(images), 500)
images = [images[i] for i in r]

# %%
len(images)
# Out:
# 500

# %%
models = [model for model in modelos if bool(re.search('renacimiento', model))]+[model for model in modelos if bool(re.search('new', model))]

# %%
models = [model for model in models if not bool(re.search('fine_tuning', model))]

# %%
models
# Out:
# ['uloss_final_renacimiento_validation_6.h5',
#  'uloss_final_renacimiento_validation_8.h5',
#  'uloss_renacimiento_validation_2.h5',
#  'uloss_renacimiento_validation_3.h5',
#  'uloss_renacimiento_validation_4.h5',
#  'unet_final_renacimiento_validation_5.h5',
#  'unet_final_renacimiento_validation_6.h5',
#  'unet_final_renacimiento_validation_7.h5',
#  'unet_final_renacimiento_validation_8.h5',
#  'unet_renacimiento_validation_1.h5',
#  'unet_renacimiento_validation_2.h5',
#  'unet_renacimiento_validation_3.h5',
#  'unet_renacimiento_validation_4.h5',
#  'uloss_new_segmentation_2.h5',
#  'uloss_new_segmentation_3.h5',
#  'uloss_new_segmentation_5.h5',
#  'uloss_new_segmentation_6.h5',
#  'uloss_new_segmentation_7.h5',
#  'uloss_new_segmentation_8.h5',
#  'unet_new_segmentation_1.h5',
#  'unet_new_segmentation_2.h5',
#  'unet_new_segmentation_3.h5',
#  'unet_new_segmentation_7.h5',
#  'unet_new_segmentation_8.h5']

# %%
for i, modelo in enumerate(models):
    print(modelo)
    datos[modelo] = []
    p = os.path.join('/home/mr1142/Documents/Data/models', modelo)
    model = keras.models.load_model(p, 
                                     custom_objects={"MyLoss": MyLoss, 
                                                     "loss_mask": loss_mask, 
                                                     "dice_coef_loss": dice_coef_loss,
                                                     "dice_coef": dice_coef})
    for image in images:
        img = normalize(read_img(path, '', image))
        mask = model.predict(img[np.newaxis,...])[0,...]
        mask = measure.label(mask)
        datos[modelo].append(len(np.unique(mask))-1)
    print('{}%'.format(i/len(models)*100))
# Out:
# uloss_final_renacimiento_validation_6.h5
# 0.0%
# uloss_final_renacimiento_validation_8.h5
# 4.166666666666666%
# uloss_renacimiento_validation_2.h5
# 8.333333333333332%
# uloss_renacimiento_validation_3.h5
# 12.5%
# uloss_renacimiento_validation_4.h5
# 16.666666666666664%
# unet_final_renacimiento_validation_5.h5
# 20.833333333333336%
# unet_final_renacimiento_validation_6.h5
# 25.0%
# unet_final_renacimiento_validation_7.h5
# 29.166666666666668%
# unet_final_renacimiento_validation_8.h5
# 33.33333333333333%
# unet_renacimiento_validation_1.h5
# 37.5%
# unet_renacimiento_validation_2.h5
# 41.66666666666667%
# unet_renacimiento_validation_3.h5
# 45.83333333333333%
# unet_renacimiento_validation_4.h5
# 50.0%
# uloss_new_segmentation_2.h5
# 54.166666666666664%
# uloss_new_segmentation_3.h5
# 58.333333333333336%
# uloss_new_segmentation_5.h5
# 62.5%
# uloss_new_segmentation_6.h5
# 66.66666666666666%
# uloss_new_segmentation_7.h5
# 70.83333333333334%
# uloss_new_segmentation_8.h5
# 75.0%
# unet_new_segmentation_1.h5
# 79.16666666666666%
# unet_new_segmentation_2.h5
# 83.33333333333334%
# unet_new_segmentation_3.h5
# 87.5%
# unet_new_segmentation_7.h5
# 91.66666666666666%
# unet_new_segmentation_8.h5
# 95.83333333333334%

# %%
df = pd.DataFrame(datos)
df = df.transpose()

# %%
df['incorrectas'] = [np.sum(df.loc[model] > 1) for model in list(df.index)]
df['media'] = [np.mean(df.loc[model]) for model in list(df.index)]
df['type'] = [list(re.split('_', model))[0] for model in list(df.index)]

# %%
df = df.drop(labels=['unet3.h5', 'unet_nuevos_validation_oldest_1.h5', 'unet_1.h5', 'unet_2.h5', 'unet_3.h5'], axis=0)

# %%
df.sort_values('incorrectas')
# Out:
#                                            0   1   2   3   4   5   6   7   8  \
# uloss_new_segmentation_5.h5                1   1   1   1   1   1   1   1   1
# unet_final_renacimiento_validation_6.h5    1   1   1   1   1   1   1   1   1
# unet_renacimiento_validation_2.h5          1   1   1   1   1   1   1   1   1
# uloss_final_renacimiento_validation_8.h5   2   1   1   1   1   1   1   1   1
# uloss_final_renacimiento_validation_6.h5   1   1   1   1   1   1   1   2   1
# unet_new_segmentation_7.h5                 6   1   1   1   1   1   1   1   3
# unet_new_segmentation_2.h5                 1   1   1   1   1   1   1   1   1
# unet_renacimiento_validation_1.h5          1   1   1   1   1   1   1   1   1
# unet_final_renacimiento_validation_8.h5    1   1   1   1   1   1   1   1   1
# unet_new_segmentation_8.h5                 1   1   1   1   1   1   1   1   1
# unet_final_renacimiento_validation_7.h5    1   1   1   1   1   1   1   1   1
# uloss_new_segmentation_8.h5                3   1   1   1   1   1   1   2   2
# unet_final_renacimiento_validation_5.h5    1   1   1   1   1   1   1   1   1
# unet_new_segmentation_1.h5                 1   2   1   1   1   1   1   2   3
# uloss_new_segmentation_2.h5                1   1   1   1   1   1   1   1   3
# uloss_renacimiento_validation_2.h5         1   1   1   1   1   1   1   1   1
# unet_new_segmentation_3.h5                 1   1   1   1   1   1   1   1   4
# unet_renacimiento_validation_4.h5          2   1   1   1   1   1   1   4   2
# uloss_new_segmentation_3.h5                5   1   1   1   1   1   1   3   4
# unet_renacimiento_validation_3.h5          1   1   1   1   1   1   1   2   1
# uloss_new_segmentation_6.h5                1   1   1   1   1   1   1   4   2
# uloss_renacimiento_validation_4.h5         1   1   1   1   1   1   2   2   1
# uloss_renacimiento_validation_3.h5         1   1   1   1   1   1   1   1   2
# uloss_new_segmentation_7.h5               51  84  65  91  48  55  45  55  89
#
#                                            9  ...  193  194  195  196  197  \
# uloss_new_segmentation_5.h5                1  ...    1    1    1    1    1
# unet_final_renacimiento_validation_6.h5    1  ...    1    1    2    1    1
# unet_renacimiento_validation_2.h5          2  ...    1    1    1    1    1
# uloss_final_renacimiento_validation_8.h5   1  ...    1    1    1    1    1
# uloss_final_renacimiento_validation_6.h5   1  ...    1    1    1    2    1
# unet_new_segmentation_7.h5                 1  ...    1    1    5    1    1
# unet_new_segmentation_2.h5                 1  ...    1    1    1    1    1
# unet_renacimiento_validation_1.h5          1  ...    1    1    2    1    1
# unet_final_renacimiento_validation_8.h5    1  ...    1    1    1    1    1
# unet_new_segmentation_8.h5                 1  ...    1    1    1    1    1
# unet_final_renacimiento_validation_7.h5    1  ...    1    1    3    1    1
# uloss_new_segmentation_8.h5                1  ...    1    1    2    1    1
# unet_final_renacimiento_validation_5.h5    1  ...    1    1    1    4    1
# unet_new_segmentation_1.h5                 1  ...    1    1    1    1    1
# uloss_new_segmentation_2.h5                1  ...    1    1    5    1    1
# uloss_renacimiento_validation_2.h5         2  ...    2    1    1    2    1
# unet_new_segmentation_3.h5                 1  ...    4    1    1    1    1
# unet_renacimiento_validation_4.h5          3  ...    1    1    3    1    1
# uloss_new_segmentation_3.h5                2  ...    1    1    2    1    1
# unet_renacimiento_validation_3.h5          2  ...    1    1    3    1    1
# uloss_new_segmentation_6.h5                1  ...    2    1    1    1    1
# uloss_renacimiento_validation_4.h5         3  ...    1    1    1    6    1
# uloss_renacimiento_validation_3.h5         1  ...    2    1    2    1    1
# uloss_new_segmentation_7.h5               80  ...   64   70   60   91   98
#
#                                           198  199  incorrectas      media  \
# uloss_new_segmentation_5.h5                 1    1            0   0.995025
# unet_final_renacimiento_validation_6.h5     3    1           19   1.238806
# unet_renacimiento_validation_2.h5           1    1           20   1.203980
# uloss_final_renacimiento_validation_8.h5    1    2           21   1.228856
# uloss_final_renacimiento_validation_6.h5    1    2           23   1.288557
# unet_new_segmentation_7.h5                  1    1           25   1.398010
# unet_new_segmentation_2.h5                  1    3           26   1.323383
# unet_renacimiento_validation_1.h5           1    4           26   1.358209
# unet_final_renacimiento_validation_8.h5     2    1           26   1.323383
# unet_new_segmentation_8.h5                  1    4           27   1.353234
# unet_final_renacimiento_validation_7.h5     2    2           28   1.353234
# uloss_new_segmentation_8.h5                 1    2           32   1.407960
# unet_final_renacimiento_validation_5.h5     2    2           36   1.462687
# unet_new_segmentation_1.h5                  2    3           39   1.537313
# uloss_new_segmentation_2.h5                 1    4           40   1.552239
# uloss_renacimiento_validation_2.h5          1    4           42   1.582090
# unet_new_segmentation_3.h5                  8    4           42   1.631841
# unet_renacimiento_validation_4.h5           2    3           43   1.562189
# uloss_new_segmentation_3.h5                 1    4           44   1.527363
# unet_renacimiento_validation_3.h5           2    4           44   1.587065
# uloss_new_segmentation_6.h5                 1    4           45   1.567164
# uloss_renacimiento_validation_4.h5          1    6           47   1.751244
# uloss_renacimiento_validation_3.h5          1    5           59   1.910448
# uloss_new_segmentation_7.h5                88   69          200  72.159204
#
#                                            type
# uloss_new_segmentation_5.h5               uloss
# unet_final_renacimiento_validation_6.h5    unet
# unet_renacimiento_validation_2.h5          unet
# uloss_final_renacimiento_validation_8.h5  uloss
# uloss_final_renacimiento_validation_6.h5  uloss
# unet_new_segmentation_7.h5                 unet
# unet_new_segmentation_2.h5                 unet
# unet_renacimiento_validation_1.h5          unet
# unet_final_renacimiento_validation_8.h5    unet
# unet_new_segmentation_8.h5                 unet
# unet_final_renacimiento_validation_7.h5    unet
# uloss_new_segmentation_8.h5               uloss
# unet_final_renacimiento_validation_5.h5    unet
# unet_new_segmentation_1.h5                 unet
# uloss_new_segmentation_2.h5               uloss
# uloss_renacimiento_validation_2.h5        uloss
# unet_new_segmentation_3.h5                 unet
# unet_renacimiento_validation_4.h5          unet
# uloss_new_segmentation_3.h5               uloss
# unet_renacimiento_validation_3.h5          unet
# uloss_new_segmentation_6.h5               uloss
# uloss_renacimiento_validation_4.h5        uloss
# uloss_renacimiento_validation_3.h5        uloss
# uloss_new_segmentation_7.h5               uloss
#
# [24 rows x 203 columns]

# %%
np.mean(df[df.type == 'unet']['media'])
# Out:
# 1.4102564102564101

# %%
np.mean(df[df.type == 'uloss']['media'])
# Out:
# 7.906377204884668

# %%
lab = 'media'

# %%
plt.boxplot([df[df.type == 'uloss'][lab], df[df.type == 'unet'][lab]], labels = ['uloss', 'unet'])
q1, q3 = np.percentile(df[lab], [20, 80])
r = q1-q3
plt.ylim(q1-1.5*r, q3+1.5*r)
# Out:
# (1.7213930348258708, 1.1721393034825869)

# %%
df.to_csv('/home/mr1142/Documents/Data/models/validation_results/imagenes_incorrectas.csv')

# %% [markdown]
# # Aplicacion en serie

# %%
def des_normalize(img):
    return cv2.normalize(img, None, alpha = 0, beta = 255,
                         norm_type = cv2.NORM_MINMAX, dtype = cv2.CV_32F)

# %%
path = '/home/mr1142/Documents/Data/validacion_medica/NIH'

# %%
images = [f for f in os.listdir(path) if bool(re.search('png', f))]

# %%
len(images)
# Out:
# 200

# %%
model = uloss

# %%
for image in images:
    img = normalize(read_img(path,'', image))
    mask = model.predict(img[np.newaxis,...])[0,...]
    segmented = des_normalize(apply_mask(img, mask))    
    cv2.imwrite(os.path.join(path,'mascara', image), segmented)
# Out:
# {1: 26308}
# 1
# {1: 30745}
# 1
# {1: 30562}
# 1
# {1: 24165}
# 1
# {1: 30333}
# 1
# {1: 28419}
# 1
# {1: 30601}
# 1
# {1: 28980, 2: 45}
# 1
# {1: 25490}
# 1
# {1: 21443}
# 1
# {1: 21924, 2: 2}
# 1
# {1: 24617}
# 1
# {1: 26173}
# 1
# {1: 22881}
# 1
# {1: 30483}
# 1
# {1: 24476}
# 1
# {1: 30520}
# 1
# {1: 33366, 2: 11, 3: 4}
# 1
# {1: 20661}
# 1
# {1: 24239, 2: 9, 3: 8, 4: 1, 5: 3}
# 1
# {1: 25851}
# 1
# {1: 23900}
# 1
# {1: 24176}
# 1
# {1: 29285}
# 1
# {1: 26734}
# 1
# {1: 26298}
# 1
# {1: 19106}
# 1
# {1: 19347}
# 1
# {1: 32598}
# 1
# {1: 20569}
# 1
# {1: 30107}
# 1
# {1: 28340}
# 1
# {1: 30761}
# 1
# {1: 25185}
# 1
# {1: 23443}
# 1
# {1: 14704}
# 1
# {1: 21066}
# 1
# {1: 31318}
# 1
# {1: 27189}
# 1
# {1: 24210}
# 1
# {1: 31026, 2: 1}
# 1
# {1: 30421}
# 1
# {1: 24017}
# 1
# {1: 25028}
# 1
# {1: 29147}
# 1
# {1: 33204}
# 1
# {1: 37590}
# 1
# {1: 21726}
# 1
# {1: 38374}
# 1
# {1: 20814, 2: 2024, 3: 2118, 4: 14, 5: 1, 6: 1}
# 1
# {1: 23103}
# 1
# {1: 37600}
# 1
# {1: 24987}
# 1
# {1: 21552}
# 1
# {1: 23932}
# 1
# {1: 27589}
# 1
# {1: 22024}
# 1
# {1: 30426}
# 1
# {1: 21590}
# 1
# {1: 25418}
# 1
# {1: 33000, 2: 5, 3: 1}
# 1
# {1: 25026}
# 1
# {1: 31464}
# 1
# {1: 28223}
# 1
# {1: 22164}
# 1
# {1: 23650}
# 1
# {1: 23763}
# 1
# {1: 20562, 2: 2, 3: 8, 4: 1}
# 1
# {1: 28222}
# 1
# {1: 37641}
# 1
# {1: 25511}
# 1
# {1: 26549}
# 1
# {1: 245, 2: 258, 3: 7, 4: 3, 5: 2, 6: 12, 7: 12553}
# 7
# {1: 33172}
# 1
# {1: 25288, 2: 1, 3: 17}
# 1
# {1: 33561}
# 1
# {1: 33500}
# 1
# {1: 31894}
# 1
# {1: 27419}
# 1
# {1: 10, 2: 34167}
# 2
# {1: 28078}
# 1
# {1: 18872}
# 1
# {1: 19808}
# 1
# {1: 27161}
# 1
# {1: 19111}
# 1
# {1: 20864}
# 1
# {1: 22009, 2: 49}
# 1
# {1: 3, 2: 36824}
# 2
# {1: 29256, 2: 1}
# 1
# {1: 25449}
# 1
# {1: 25806}
# 1
# {1: 25607}
# 1
# {1: 24929}
# 1
# {1: 18758}
# 1
# {1: 18032}
# 1
# {1: 22844, 2: 33}
# 1
# {1: 21727}
# 1
# {1: 35012}
# 1
# {1: 25885}
# 1
# {1: 18837}
# 1
# {1: 38920, 2: 1}
# 1
# {1: 23897}
# 1
# {1: 29682}
# 1
# {1: 16538}
# 1
# {1: 29072}
# 1
# {1: 24056}
# 1
# {1: 18446}
# 1
# {1: 20341, 2: 1}
# 1
# {1: 20924}
# 1
# {1: 34203}
# 1
# {1: 30819}
# 1
# {1: 26327}
# 1
# {1: 21252}
# 1
# {1: 30080, 2: 1}
# 1
# {1: 26345}
# 1
# {1: 21904}
# 1
# {1: 25342}
# 1
# {1: 26756}
# 1
# {1: 18750, 2: 199}
# 1
# {1: 24007}
# 1
# {1: 14985}
# 1
# {1: 30413, 2: 5, 3: 88, 4: 13, 5: 3, 6: 1}
# 1
# {1: 25300}
# 1
# {1: 22089}
# 1
# {1: 14543}
# 1
# {1: 22186}
# 1
# {1: 34733}
# 1
# {1: 26594}
# 1
# {1: 21130}
# 1
# {1: 30504}
# 1
# {1: 36179}
# 1
# {1: 23077}
# 1
# {1: 24290}
# 1
# {1: 20871}
# 1
# {1: 26406}
# 1
# {1: 21612}
# 1
# {1: 31038}
# 1
# {1: 31600}
# 1
# {1: 22655}
# 1
# {1: 20703}
# 1
# {1: 23256}
# 1
# {1: 32150}
# 1
# {1: 32315}
# 1
# {1: 30181, 2: 100, 3: 1, 4: 1, 5: 1}
# 1
# {1: 28412}
# 1
# {1: 19422}
# 1
# {1: 30982, 2: 1}
# 1
# {1: 16971}
# 1
# {1: 20175}
# 1
# {1: 26813}
# 1
# {1: 38768}
# 1
# {1: 20471}
# 1
# {1: 31167}
# 1
# {1: 20172}
# 1
# {1: 21738, 2: 989}
# 1
# {1: 22950}
# 1
# {1: 18259}
# 1
# {1: 22771, 2: 80}
# 1
# {1: 28964}
# 1
# {1: 32130}
# 1
# {1: 27709}
# 1
# {1: 30219}
# 1
# {1: 30829}
# 1
# {1: 31053, 2: 1}
# 1
# {1: 31402, 2: 12}
# 1
# {1: 28150}
# 1
# {1: 30070}
# 1
# {1: 25237}
# 1
# {1: 20535}
# 1
# {1: 23811}
# 1
# {1: 26448}
# 1
# {1: 32772}
# 1
# {1: 31878}
# 1
# {1: 21379}
# 1
# {1: 15564}
# 1
# {1: 33792, 2: 6}
# 1
# {1: 35039}
# 1
# {1: 24581, 2: 275, 3: 6}
# 1
# {1: 22034}
# 1
# {1: 18821}
# 1
# {1: 24868}
# 1
# {1: 24144}
# 1
# {1: 22419}
# 1
# {1: 30048}
# 1
# {1: 19441, 2: 1}
# 1
# {1: 21238}
# 1
# {1: 35663}
# 1
# {1: 23515}
# 1
# {1: 25034}
# 1
# {1: 30443}
# 1
# {1: 21668, 2: 2, 3: 3, 4: 8, 5: 1, 6: 1, 7: 2, 8: 61, 9: 1, 10: 30, 11: 147, 12: 2, 13: 4, 14: 20, 15: 1, 16: 1968, 17: 2, 18: 5}
# 1
# {1: 41992}
# 1
# {1: 34207}
# 1
# {1: 25539}
# 1
# {1: 13742, 2: 5}
# 1
# {1: 27422}
# 1
# {1: 33372, 2: 1}
# 1
# {1: 29655}
# 1
# {1: 33756}
# 1
# {1: 24528}
# 1

# %%
names = os.listdir(os.path.join(path, 'mascara'))
len(names)
# Out:
# 200

# %%
p = '/home/mr1142/Documents/Data/NIH/Data_Entry_2017.csv'

# %%
df = pd.read_csv(p)

# %%
index = [i for i in df.index if df['Image Index'][i] in names]

# %%
df = df.iloc[index]

# %%
df.head()
# Out:
#            Image Index Finding Labels  Follow-up #  Patient ID  Patient Age  \
# 275   00000061_011.png       Effusion           11          61           77
# 1424  00000372_002.png   Pneumothorax            2         372           80
# 2967  00000792_001.png     No Finding            1         792           60
# 3001  00000798_013.png     No Finding           13         798           65
# 3172  00000831_005.png     No Finding            5         831           25
#
#      Patient Gender View Position  OriginalImage[Width  Height]  \
# 275               M            AP                 3056     2524
# 1424              M            AP                 2500     2048
# 2967              M            PA                 2992     2991
# 3001              F            AP                 2500     2048
# 3172              M            AP                 2500     2048
#
#       OriginalImagePixelSpacing[x     y]  Unnamed: 11
# 275                         0.139  0.139          NaN
# 1424                        0.168  0.168          NaN
# 2967                        0.143  0.143          NaN
# 3001                        0.168  0.168          NaN
# 3172                        0.168  0.168          NaN

# %%
len(df)
# Out:
# 200

# %%
df.to_csv(os.path.join(path,'validation_data.csv'))
