# %%
import numpy as np
import pandas as pd
import re

# %%
df = pd.read_csv('/home/mr1142/Documents/Data/segmentation/splited/validation/validation_data.csv')
labels = [re.split('[|]', df['Finding Labels'][i]) for i in df.index]
labels = [x for xs in labels for x in xs]
labels = list(np.unique(labels))
labels
# Out:
# ['Atelectasis',
#  'Cardiomegaly',
#  'Consolidation',
#  'Edema',
#  'Effusion',
#  'Emphysema',
#  'Infiltration',
#  'Mass',
#  'No Finding',
#  'Nodule',
#  'Pleural_Thickening',
#  'Pneumonia',
#  'Pneumothorax']

# %%
path = '/home/mr1142/Documents/Data/models/validation_results/validation_results' + '' + '.csv'
df = pd.read_csv(path)

# %%
df['doble_loss'] = df['dice_coef_loss'] + df['loss_mask']

# %%
df.sort_values('doble_loss').head(20)
# Out:
#      type                                       name      loss  \
# 42   unet  patologic_final_renacimiento_validation_6  0.010329
# 36  uloss                         new_segmentation_8  0.100327
# 22  uloss            final_renacimiento_validation_8  0.100469
# 25   unet                         new_segmentation_1  0.026739
# 19  uloss            final_renacimiento_validation_6  0.102747
# 27  uloss                         new_segmentation_2  0.102601
# 66  uloss               patologic_new_segmentation_6  0.103185
# 30   unet                         new_segmentation_8  0.028016
# 33  uloss                         new_segmentation_3  0.105276
# 57  uloss  patologic_final_renacimiento_validation_6  0.104725
# 21   unet            final_renacimiento_validation_7  0.028393
# 20   unet            final_renacimiento_validation_6  0.027842
# 61  uloss               patologic_new_segmentation_2  0.106732
# 62  uloss               patologic_new_segmentation_3  0.107975
# 24   unet                         new_segmentation_2  0.029598
# 55  uloss  patologic_final_renacimiento_validation_8  0.109311
# 69  uloss  patologic_final_renacimiento_validation_8  0.109311
# 34  uloss                         new_segmentation_6  0.111097
# 68  uloss               patologic_new_segmentation_8  0.110758
# 58  uloss        patologic_renacimiento_validation_3  0.111251
#
#     dice_coef_loss  loss_mask  accuracy       AUC  false_positives  \
# 42        0.010329   0.084500  0.991868  0.990991         728103.0
# 36        0.027026   0.072820  0.977854  0.979740          79161.0
# 22        0.026820   0.073125  0.978087  0.979268          68079.0
# 25        0.026341   0.075169  0.978365  0.979378          81964.0
# 19        0.028376   0.073854  0.976893  0.977792          70053.0
# 27        0.027155   0.075076  0.977825  0.979799          80248.0
# 66        0.027132   0.076053  0.978723  0.979761        3743327.0
# 30        0.027544   0.076408  0.977614  0.976839          57872.0
# 33        0.028231   0.076457  0.976861  0.978157          73210.0
# 57        0.027288   0.077437  0.978551  0.978354         342536.0
# 21        0.027809   0.077276  0.977255  0.977421          72967.0
# 20        0.027473   0.078634  0.977579  0.977706          72640.0
# 61        0.027362   0.079371  0.978450  0.979824        1066693.0
# 62        0.029015   0.078960  0.977211  0.977244        1165999.0
# 24        0.029114   0.080106  0.976126  0.977194          93158.0
# 55        0.028401   0.080910  0.977675  0.977669         101605.0
# 69        0.028401   0.080910  0.977675  0.977669        8309586.0
# 34        0.029996   0.080656  0.975554  0.977975          81662.0
# 68        0.029832   0.080926  0.976418  0.976644        8207981.0
# 58        0.029183   0.082068  0.977041  0.977651         444439.0
#
#     false_negatives  doble_loss
# 42        1223909.0    0.094829
# 36          65976.0    0.099846
# 22          75530.0    0.099945
# 25          59824.0    0.101509
# 19          81382.0    0.102230
# 27          65079.0    0.102231
# 66        3023843.0    0.103185
# 30          88834.0    0.103952
# 33          78431.0    0.104688
# 57         724644.0    0.104725
# 21          76094.0    0.105085
# 20          74298.0    0.106107
# 61        1886679.0    0.106732
# 62        2086071.0    0.107975
# 24          63302.0    0.109220
# 55         191015.0    0.109311
# 69        3744618.0    0.109311
# 34          78549.0    0.110652
# 68        3553603.0    0.110758
# 58         923666.0    0.111251

# %%
index = [i for i in df.index if bool(re.search('patologic', df['name'][i]))]

# %%
df.iloc[index].sort_values('dice_coef_loss').head(20)
# Out:
#      type                                       name      loss  \
# 42   unet  patologic_final_renacimiento_validation_6  0.010329
# 41   unet               patologic_new_segmentation_2  0.026118
# 47   unet  patologic_final_renacimiento_validation_5  0.026621
# 43   unet               patologic_new_segmentation_1  0.027093
# 66  uloss               patologic_new_segmentation_6  0.103185
# 57  uloss  patologic_final_renacimiento_validation_6  0.104725
# 61  uloss               patologic_new_segmentation_2  0.106732
# 51   unet               patologic_new_segmentation_3  0.027587
# 46   unet               patologic_new_segmentation_7  0.027836
# 37   unet  patologic_final_renacimiento_validation_7  0.028050
# 48   unet        patologic_renacimiento_validation_1  0.028204
# 38   unet  patologic_final_renacimiento_validation_8  0.028280
# 52   unet               patologic_new_segmentation_8  0.028385
# 55  uloss  patologic_final_renacimiento_validation_8  0.109311
# 69  uloss  patologic_final_renacimiento_validation_8  0.109311
# 62  uloss               patologic_new_segmentation_3  0.107975
# 58  uloss        patologic_renacimiento_validation_3  0.111251
# 39   unet        patologic_renacimiento_validation_2  0.029483
# 68  uloss               patologic_new_segmentation_8  0.110758
# 59  uloss        patologic_renacimiento_validation_4  0.115367
#
#     dice_coef_loss  loss_mask  accuracy       AUC  false_positives  \
# 42        0.010329   0.084500  0.991868  0.990991         728103.0
# 41        0.026118   0.191623  0.979343  0.979141         698484.0
# 47        0.026621   0.196282  0.979081  0.977774        1146235.0
# 43        0.027093   0.202216  0.978595  0.978217         849302.0
# 66        0.027132   0.076053  0.978723  0.979761        3743327.0
# 57        0.027288   0.077437  0.978551  0.978354         342536.0
# 61        0.027362   0.079371  0.978450  0.979824        1066693.0
# 51        0.027587   0.209517  0.978267  0.977902        1870899.0
# 46        0.027836   0.195432  0.978214  0.976372        1055048.0
# 37        0.028050   0.208446  0.977999  0.977043         109233.0
# 48        0.028204   0.209544  0.977812  0.977078        1499667.0
# 38        0.028280   0.201186  0.977707  0.977706         231254.0
# 52        0.028385   0.198268  0.977662  0.975669        1955631.0
# 55        0.028401   0.080910  0.977675  0.977669         101605.0
# 69        0.028401   0.080910  0.977675  0.977669        8309586.0
# 62        0.029015   0.078960  0.977211  0.977244        1165999.0
# 58        0.029183   0.082068  0.977041  0.977651         444439.0
# 39        0.029483   0.207453  0.976890  0.974784         409416.0
# 68        0.029832   0.080926  0.976418  0.976644        8207981.0
# 59        0.030165   0.085202  0.976367  0.976576         545836.0
#
#     false_negatives  doble_loss
# 42        1223909.0    0.094829
# 41        1146934.0    0.217741
# 47        1979773.0    0.222902
# 43        1383274.0    0.229309
# 66        3023843.0    0.103185
# 57         724644.0    0.104725
# 61        1886679.0    0.106732
# 51        3162686.0    0.237104
# 46        1796768.0    0.223268
# 37         179141.0    0.236496
# 48        2512436.0    0.237748
# 38         349315.0    0.229465
# 52        3370743.0    0.226653
# 55         191015.0    0.109311
# 69        3744618.0    0.109311
# 62        2086071.0    0.107975
# 58         923666.0    0.111251
# 39         705976.0    0.236936
# 68        3553603.0    0.110758
# 59        1132029.0    0.115367

# %%
m = {}
for tipo in np.unique(df['type']):
    u = df[df.type == tipo]
    models = [re.split('patologic_', name)[0] for name in u['name']]

    for model in models:
        models_model = [mod for mod in models if bool(re.search(model, mod))]
        lista = []
        for col in df.columns[2:10]:
            values = list(df[col][df.name == model])
            lista.append(np.mean(values))
        m[tipo + '_' + model] = lista
# Out:
# /home/mr1142/miniconda3/envs/init/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/mr1142/miniconda3/envs/init/lib/python3.6/site-packages/numpy/core/_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
n = pd.DataFrame(m).transpose()
n.columns = df.columns[2:10]
n.sort_values('dice_coef_loss')
# Out:
#                                                loss  dice_coef_loss  \
# unet_new_segmentation_1                    0.026739        0.026341
# unet_new_segmentation_8                    0.064171        0.027285
# uloss_new_segmentation_8                   0.064171        0.027285
# unet_final_renacimiento_validation_7       0.028393        0.027809
# unet_final_renacimiento_validation_6       0.065295        0.027925
# uloss_final_renacimiento_validation_6      0.065295        0.027925
# unet_new_segmentation_2                    0.066100        0.028134
# uloss_new_segmentation_2                   0.066100        0.028134
# uloss_new_segmentation_6                   0.111097        0.029996
# unet_final_renacimiento_validation_5       0.030735        0.030172
# uloss_final_renacimiento_validation_8      0.067628        0.030558
# unet_final_renacimiento_validation_8       0.067628        0.030558
# uloss_renacimiento_validation_3            0.076307        0.031819
# unet_renacimiento_validation_3             0.076307        0.031819
# unet_renacimiento_validation_1             0.032621        0.032179
# uloss_renacimiento_validation_4            0.077352        0.032584
# unet_renacimiento_validation_4             0.077352        0.032584
# uloss_renacimiento_validation_2            0.081739        0.033463
# unet_renacimiento_validation_2             0.081739        0.033463
# uloss_albumentation_rotate_3_validation_2  0.082922        0.035171
# unet_albumentation_rotate_3_validation_2   0.082922        0.035171
# unet__albumentation_validation_2.h5        0.091776        0.035416
# uloss__albumentation_validation_2.h5       0.091776        0.035416
# unet_albumentation_rotate_3_validation_1   0.082981        0.036136
# uloss_albumentation_rotate_3_validation_1  0.082981        0.036136
# unet_validation_rotate_normalization_1     0.086306        0.037424
# uloss_validation_rotate_normalization_1    0.086306        0.037424
# uloss__albumentation_validation_1.h5       0.089579        0.038122
# unet__albumentation_validation_1.h5        0.089579        0.038122
# unet_nuevos_validation_mejora_3            0.040236        0.039544
# unet_new_segmentation_3                    0.234259        0.089066
# uloss_new_segmentation_3                   0.234259        0.089066
# uloss_new_segmentation_7                   0.435991        0.176553
# unet_new_segmentation_7                    0.435991        0.176553
# uloss_new_segmentation_5                   0.624561        0.198346
# uloss_new_loss_1                           1.736912        0.350514
# uloss_                                          NaN             NaN
# unet_                                           NaN             NaN
#
#                                            loss_mask  accuracy       AUC  \
# unet_new_segmentation_1                     0.075169  0.978365  0.979378
# unet_new_segmentation_8                     0.074614  0.977734  0.978290
# uloss_new_segmentation_8                    0.074614  0.977734  0.978290
# unet_final_renacimiento_validation_7        0.077276  0.977255  0.977421
# unet_final_renacimiento_validation_6        0.076244  0.977236  0.977749
# uloss_final_renacimiento_validation_6       0.076244  0.977236  0.977749
# unet_new_segmentation_2                     0.077591  0.976975  0.978496
# uloss_new_segmentation_2                    0.077591  0.976975  0.978496
# uloss_new_segmentation_6                    0.080656  0.975554  0.977975
# unet_final_renacimiento_validation_5        0.084180  0.975373  0.975297
# uloss_final_renacimiento_validation_8       0.082765  0.975105  0.976077
# unet_final_renacimiento_validation_8        0.082765  0.975105  0.976077
# uloss_renacimiento_validation_3             0.093260  0.974355  0.975675
# unet_renacimiento_validation_3              0.093260  0.974355  0.975675
# unet_renacimiento_validation_1              0.092485  0.973949  0.974434
# uloss_renacimiento_validation_4             0.093521  0.973677  0.974354
# unet_renacimiento_validation_4              0.093521  0.973677  0.974354
# uloss_renacimiento_validation_2             0.092658  0.973155  0.973422
# unet_renacimiento_validation_2              0.092658  0.973155  0.973422
# uloss_albumentation_rotate_3_validation_2   0.095910  0.971772  0.972292
# unet_albumentation_rotate_3_validation_2    0.095910  0.971772  0.972292
# unet__albumentation_validation_2.h5         0.104266  0.973305  0.973715
# uloss__albumentation_validation_2.h5        0.104266  0.973305  0.973715
# unet_albumentation_rotate_3_validation_1    0.098623  0.970958  0.971008
# uloss_albumentation_rotate_3_validation_1   0.098623  0.970958  0.971008
# unet_validation_rotate_normalization_1      0.100656  0.969900  0.969945
# uloss_validation_rotate_normalization_1     0.100656  0.969900  0.969945
# uloss__albumentation_validation_1.h5        0.110078  0.971343  0.970623
# unet__albumentation_validation_1.h5         0.110078  0.971343  0.970623
# unet_nuevos_validation_mejora_3             0.106641  0.967752  0.968213
# unet_new_segmentation_3                     0.187446  0.909351  0.920868
# uloss_new_segmentation_3                    0.187446  0.909351  0.920868
# uloss_new_segmentation_7                    0.300273  0.808770  0.831566
# unet_new_segmentation_7                     0.300273  0.808770  0.831566
# uloss_new_segmentation_5                    0.424810  0.811638  0.831910
# uloss_new_loss_1                            1.384145  0.580410  0.641062
# uloss_                                           NaN       NaN       NaN
# unet_                                            NaN       NaN       NaN
#
#                                            false_positives  false_negatives  \
# unet_new_segmentation_1                           81964.00          59824.0
# unet_new_segmentation_8                           68516.50          77405.0
# uloss_new_segmentation_8                          68516.50          77405.0
# unet_final_renacimiento_validation_7              72967.00          76094.0
# unet_final_renacimiento_validation_6              71346.50          77840.0
# uloss_final_renacimiento_validation_6             71346.50          77840.0
# unet_new_segmentation_2                           86703.00          64190.5
# uloss_new_segmentation_2                          86703.00          64190.5
# uloss_new_segmentation_6                          81662.00          78549.0
# unet_final_renacimiento_validation_5              76188.00          85209.0
# uloss_final_renacimiento_validation_8             80545.00          82609.5
# unet_final_renacimiento_validation_8              80545.00          82609.5
# uloss_renacimiento_validation_3                   86272.50          80111.0
# unet_renacimiento_validation_3                    86272.50          80111.0
# unet_renacimiento_validation_1                    88665.00          80353.0
# uloss_renacimiento_validation_4                   84374.00          86413.5
# unet_renacimiento_validation_4                    84374.00          86413.5
# uloss_renacimiento_validation_2                   72587.00         101582.0
# unet_renacimiento_validation_2                    72587.00         101582.0
# uloss_albumentation_rotate_3_validation_2         84465.00          98678.0
# unet_albumentation_rotate_3_validation_2          84465.00          98678.0
# unet__albumentation_validation_2.h5                7449.50           6546.5
# uloss__albumentation_validation_2.h5               7449.50           6546.5
# unet_albumentation_rotate_3_validation_1          82793.50         105632.0
# uloss_albumentation_rotate_3_validation_1         82793.50         105632.0
# unet_validation_rotate_normalization_1            91350.00         103942.0
# uloss_validation_rotate_normalization_1           91350.00         103942.0
# uloss__albumentation_validation_1.h5               7445.00           7579.5
# unet__albumentation_validation_1.h5                7445.00           7579.5
# unet_nuevos_validation_mejora_3                  111092.00          98133.0
# unet_new_segmentation_3                          521340.75          72739.0
# uloss_new_segmentation_3                         521340.75          72739.0
# uloss_new_segmentation_7                        1109637.00         143607.5
# unet_new_segmentation_7                         1109637.00         143607.5
# uloss_new_segmentation_5                        1067720.00         166728.0
# uloss_new_loss_1                                2631613.00         118210.0
# uloss_                                                 NaN              NaN
# unet_                                                  NaN              NaN
#
#                                            doble_loss
# unet_new_segmentation_1                      0.101509
# unet_new_segmentation_8                      0.101899
# uloss_new_segmentation_8                     0.101899
# unet_final_renacimiento_validation_7         0.105085
# unet_final_renacimiento_validation_6         0.104169
# uloss_final_renacimiento_validation_6        0.104169
# unet_new_segmentation_2                      0.105725
# uloss_new_segmentation_2                     0.105725
# uloss_new_segmentation_6                     0.110652
# unet_final_renacimiento_validation_5         0.114352
# uloss_final_renacimiento_validation_8        0.113323
# unet_final_renacimiento_validation_8         0.113323
# uloss_renacimiento_validation_3              0.125080
# unet_renacimiento_validation_3               0.125080
# unet_renacimiento_validation_1               0.124665
# uloss_renacimiento_validation_4              0.126105
# unet_renacimiento_validation_4               0.126105
# uloss_renacimiento_validation_2              0.126121
# unet_renacimiento_validation_2               0.126121
# uloss_albumentation_rotate_3_validation_2    0.131082
# unet_albumentation_rotate_3_validation_2     0.131082
# unet__albumentation_validation_2.h5          0.139682
# uloss__albumentation_validation_2.h5         0.139682
# unet_albumentation_rotate_3_validation_1     0.134760
# uloss_albumentation_rotate_3_validation_1    0.134760
# unet_validation_rotate_normalization_1       0.138079
# uloss_validation_rotate_normalization_1      0.138079
# uloss__albumentation_validation_1.h5         0.148200
# unet__albumentation_validation_1.h5          0.148200
# unet_nuevos_validation_mejora_3              0.146185
# unet_new_segmentation_3                      0.276512
# uloss_new_segmentation_3                     0.276512
# uloss_new_segmentation_7                     0.476826
# unet_new_segmentation_7                      0.476826
# uloss_new_segmentation_5                     0.623156
# uloss_new_loss_1                             1.734659
# uloss_                                            NaN
# unet_                                             NaN

# %%
len(df[df.type == 'uloss'])
# Out:
# 19

# %%
len(df[df.type == 'uloss']) == len(df[df.type == 'unet'])
# Out:
# False

# %%
evaluations = list(df.columns[3:9])

for ev in evaluations:
    print(ev)
    print('unet: {}'.format(np.mean(df[ev][df.type == 'unet'])))
    print('uloss: {}'.format(np.mean(df[ev][df.type == 'uloss'])))
    print('-----')
# Out:
# dice_coef_loss
# unet: 0.03595833107829094
# uloss: 0.03554113581776619
# -----
# loss_mask
# unet: 0.10044687507408005
# uloss: 0.09659373015165329
# -----
# accuracy
# unet: 0.9711624979972839
# uloss: 0.9717517332597212
# -----
# AUC
# unet: 0.9709695449897221
# uloss: 0.9732427759604021
# -----
# false_positives
# unet: 81636.14285714286
# uloss: 72415.0
# -----
# false_negatives
# unet: 84696.21428571429
# uloss: 80722.81818181818
# -----

# %%
names = ['_albumentation', 'rotate', 'renacimiento']

# %%
tipos = {}
tipos['unet'] = {}
tipos['uloss'] = {}
for ev in evaluations:
    tipos['unet'][ev] = np.mean(df[ev][df.type == 'unet'])
    tipos['uloss'][ev] = np.mean(df[ev][df.type == 'uloss'])
    for name in names:
        index = [i for i in df.index if bool(re.search(name, df['name'][i]))]
        try:
            tipos[name][ev] = np.mean(df[ev].iloc[index])
        except:
            tipos[name] = {}
            tipos[name][ev] = np.mean(df[ev].iloc[index])

# %%
tipos
# Out:
# {'unet': {'dice_coef_loss': 0.03595833107829094,
#   'loss_mask': 0.10044687507408005,
#   'accuracy': 0.9711624979972839,
#   'AUC': 0.9709695449897221,
#   'false_positives': 81636.14285714286,
#   'false_negatives': 84696.21428571429},
#  'uloss': {'dice_coef_loss': 0.03554113581776619,
#   'loss_mask': 0.09659373015165329,
#   'accuracy': 0.9717517332597212,
#   'AUC': 0.9732427759604021,
#   'false_positives': 72415.0,
#   'false_negatives': 80722.81818181818},
#  '_albumentation': {'dice_coef_loss': 0.03676915168762207,
#   'loss_mask': 0.10717159509658813,
#   'accuracy': 0.9723238945007324,
#   'AUC': 0.9721685945987701,
#   'false_positives': 7447.25,
#   'false_negatives': 7063.0},
#  'rotate': {'dice_coef_loss': 0.03624377027153969,
#   'loss_mask': 0.09839637825886409,
#   'accuracy': 0.9708767533302307,
#   'AUC': 0.9710817734400431,
#   'false_positives': 86202.83333333333,
#   'false_negatives': 102750.66666666667},
#  'renacimiento': {'dice_coef_loss': 0.03502038999327591,
#   'loss_mask': 0.09593440539070539,
#   'accuracy': 0.9716596858842033,
#   'AUC': 0.9725618830748967,
#   'false_positives': 91526.64285714286,
#   'false_negatives': 95057.78571428571}}

# %%
comparation = {}
for k in tipos['unet'].keys():
    comparation[k] = []
    for j in tipos.keys():
        comparation[k].append(tipos[j][k])
comparation = pd.DataFrame(comparation)
comparation.index = tipos.keys()

# %%
comparation.sort_values('dice_coef_loss')
# Out:
#                 dice_coef_loss  loss_mask  accuracy       AUC  \
# renacimiento          0.035020   0.095934  0.971660  0.972562
# uloss                 0.035541   0.096594  0.971752  0.973243
# unet                  0.035958   0.100447  0.971162  0.970970
# rotate                0.036244   0.098396  0.970877  0.971082
# _albumentation        0.036769   0.107172  0.972324  0.972169
#
#                 false_positives  false_negatives
# renacimiento       91526.642857     95057.785714
# uloss              72415.000000     80722.818182
# unet               81636.142857     84696.214286
# rotate             86202.833333    102750.666667
# _albumentation      7447.250000      7063.000000

# %%
index = [i for i in df.index if any([bool(re.search(name, df['name'][i])) for name in ['old', 'clahe', 'gamma']])]

# %%
df = df.drop(index).reset_index()

# %%
tipos = {}
for tipo in ['unet', 'uloss']:
    for ev in evaluations:
        for name in names:
            index = [i for i in df.index if bool(re.search(name, df['name'][i]))]
            try:
                tipos[tipo + '_' + name][ev] = np.mean(df[ev].iloc[index][df['type']==tipo])
            except:
                tipos[tipo + '_' + name] = {}
                tipos[tipo + '_' + name][ev] = np.mean(df[ev].iloc[index][df['type']==tipo])

# %%
tipos
# Out:
# {'unet__albumentation': {'dice_coef_loss': 0.03589135408401489,
#   'loss_mask': 0.10652638971805573,
#   'accuracy': 0.9729394912719727,
#   'AUC': 0.972397118806839,
#   'false_positives': 7674.0,
#   'false_negatives': 6513.5},
#  'unet_rotate': {'dice_coef_loss': 0.03665660570065181,
#   'loss_mask': 0.10188330709934235,
#   'accuracy': 0.9703687032063802,
#   'AUC': 0.969934900601705,
#   'false_positives': 86533.0,
#   'false_negatives': 105716.66666666667},
#  'unet_renacimiento': {'dice_coef_loss': 0.03526495862752199,
#   'loss_mask': 0.09761407412588596,
#   'accuracy': 0.9714421927928925,
#   'AUC': 0.9713452383875847,
#   'false_positives': 94608.375,
#   'false_negatives': 94679.625},
#  'uloss__albumentation': {'dice_coef_loss': 0.03764694929122925,
#   'loss_mask': 0.10781680047512054,
#   'accuracy': 0.9717082977294922,
#   'AUC': 0.9719400703907014,
#   'false_positives': 7220.5,
#   'false_negatives': 7612.5},
#  'uloss_rotate': {'dice_coef_loss': 0.035830934842427574,
#   'loss_mask': 0.09490944941838582,
#   'accuracy': 0.9713848034540812,
#   'AUC': 0.9722286462783813,
#   'false_positives': 85872.66666666667,
#   'false_negatives': 99784.66666666667},
#  'uloss_renacimiento': {'dice_coef_loss': 0.034694298480947815,
#   'loss_mask': 0.09369484707713127,
#   'accuracy': 0.9719496766726176,
#   'AUC': 0.9741840759913126,
#   'false_positives': 87417.66666666667,
#   'false_negatives': 95562.0}}

# %%
comparation = {}
for k in tipos['uloss_renacimiento'].keys():
    comparation[k] = []
    for j in tipos.keys():
        comparation[k].append(tipos[j][k])
comparation = pd.DataFrame(comparation)
comparation.index = tipos.keys()

# %%
comparation.sort_values('dice_coef_loss')
# Out:
#                       dice_coef_loss  loss_mask  accuracy       AUC  \
# uloss_renacimiento          0.034694   0.093695  0.971950  0.974184
# unet_renacimiento           0.035265   0.097614  0.971442  0.971345
# uloss_rotate                0.035831   0.094909  0.971385  0.972229
# unet__albumentation         0.035891   0.106526  0.972939  0.972397
# unet_rotate                 0.036657   0.101883  0.970369  0.969935
# uloss__albumentation        0.037647   0.107817  0.971708  0.971940
#
#                       false_positives  false_negatives
# uloss_renacimiento       87417.666667     95562.000000
# unet_renacimiento        94608.375000     94679.625000
# uloss_rotate             85872.666667     99784.666667
# unet__albumentation       7674.000000      6513.500000
# unet_rotate              86533.000000    105716.666667
# uloss__albumentation      7220.500000      7612.500000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
unet = df[['name'] + evaluations][df.type == 'unet'].reset_index()
uloss = df[['name'] + evaluations][df.type == 'uloss'].reset_index()

fig, ax = plt.subplots(3, 2)
fig.set_size_inches(10,10)

for i, ev in enumerate(evaluations):
    if i%2 == 0:
        y = 0
    else:
        y = 1
    x = int(i/2)
    ax[x,y].boxplot([unet[ev], uloss[ev]], labels = ['unet', 'uloss'])
    q1, q3 = np.percentile(df[ev], [20, 80])
    r = q1-q3
    ax[x,y].set_ylim(q1-1.1*r, q3+1.1*r)
    ax[x,y].set_title(ev)

# %%
# data = {}
# for tipo in ['unet', 'uloss']:
#     data[tipo] = {}
#     for name in names:
#         d = df[df.type == 'unet'].reset_index()
#         index = [i for i in d.index if bool(re.search(name, d['name'][i]))]
#         data[tipo][name] = d.iloc[index]

# %%
data = {}
for name in names:
    index = [i for i in df.index if bool(re.search(name, df['name'][i]))]
    data[name] = df.iloc[index]

# %%
data
# Out:
# {'_albumentation':    index   type                            name      loss  dice_coef_loss  \
#  0      0   unet  _albumentation_validation_1.h5  0.037296        0.037296
#  1      1  uloss  _albumentation_validation_1.h5  0.141863        0.038948
#  2      2   unet  _albumentation_validation_2.h5  0.034487        0.034487
#  3      3  uloss  _albumentation_validation_2.h5  0.149065        0.036346
#
#     loss_mask  accuracy       AUC  false_positives  false_negatives
#  0   0.117240  0.971939  0.970628           7386.0           7326.0
#  1   0.102915  0.970747  0.970617           7504.0           7833.0
#  2   0.095812  0.973940  0.974166           7962.0           5701.0
#  3   0.112719  0.972670  0.973263           6937.0           7392.0  ,
#  'rotate':    index   type                                 name      loss  \
#  4      4   unet  albumentation_rotate_3_validation_1  0.037508
#  5      5   unet  albumentation_rotate_3_validation_2  0.035893
#  6      6  uloss  albumentation_rotate_3_validation_1  0.128454
#  7      7  uloss  albumentation_rotate_3_validation_2  0.129951
#  8      8   unet    validation_rotate_normalization_1  0.038100
#  9      9  uloss    validation_rotate_normalization_1  0.134512
#
#     dice_coef_loss  loss_mask  accuracy       AUC  false_positives  \
#  4        0.036994   0.104480  0.970098  0.969842          87088.0
#  5        0.035434   0.097252  0.971598  0.971085          81626.0
#  6        0.035279   0.092766  0.971818  0.972174          78499.0
#  7        0.034909   0.094568  0.971946  0.973499          87304.0
#  8        0.037542   0.103917  0.969410  0.968877          90885.0
#  9        0.037305   0.097394  0.970390  0.971013          91815.0
#
#     false_negatives
#  4         106918.0
#  5         102645.0
#  6         104346.0
#  7          94711.0
#  8         107587.0
#  9         100297.0  ,
#  'renacimiento':     index   type                                        name      loss  \
#  10     10   unet                   renacimiento_validation_1  0.032621
#  12     12   unet                   renacimiento_validation_2  0.032413
#  13     13  uloss                   renacimiento_validation_2  0.131064
#  14     14   unet                   renacimiento_validation_3  0.033088
#  15     15  uloss                   renacimiento_validation_3  0.119526
#  16     16   unet                   renacimiento_validation_4  0.034823
#  17     17  uloss                   renacimiento_validation_4  0.119882
#  18     18  uloss             final_renacimiento_validation_1  0.134435
#  19     19   unet             final_renacimiento_validation_1  0.037549
#  20     20  uloss             final_renacimiento_validation_3  0.133919
#  21     21   unet             final_renacimiento_validation_3  0.038956
#  22     22  uloss  patologic__final_renacimiento_validation_1  0.134435
#  23     23   unet   patologic_final_renacimiento_validation_3  0.038956
#  24     24   unet   patologic_final_renacimiento_validation_1  0.037549
#
#      dice_coef_loss  loss_mask  accuracy       AUC  false_positives  \
#  10        0.032179   0.092485  0.973949  0.974434          88665.0
#  12        0.031955   0.089793  0.974418  0.973736          70983.0
#  13        0.034971   0.095523  0.971893  0.973108          74191.0
#  14        0.032720   0.098321  0.973591  0.974356          92355.0
#  15        0.030919   0.088200  0.975120  0.976994          80190.0
#  16        0.034295   0.098386  0.972277  0.971930          88000.0
#  17        0.030873   0.088655  0.975076  0.976777          80748.0
#  18        0.037271   0.096563  0.969771  0.973185          92873.0
#  19        0.037049   0.099391  0.969916  0.969626          96596.0
#  20        0.036861   0.096666  0.970067  0.971855         103631.0
#  21        0.038436   0.101573  0.968735  0.968527         105116.0
#  22        0.037271   0.096563  0.969771  0.973185          92873.0
#  23        0.038436   0.101573  0.968735  0.968527         110526.0
#  24        0.037049   0.099391  0.969916  0.969626         104626.0
#
#      false_negatives
#  10          80353.0
#  12          94992.0
#  13         108172.0
#  14          78991.0
#  15          81231.0
#  16          91869.0
#  17          80958.0
#  18         105235.0
#  19         100561.0
#  20          92541.0
#  21          99783.0
#  22         105235.0
#  23         105196.0
#  24         105692.0  }

# %%
len(datos_unet)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-a254ba56c680> in <module>
# ----> 1 len(datos_unet)
#
# NameError: name 'datos_unet' is not defined

# %%
fig, ax = plt.subplots(3, 2)
fig.set_size_inches(20,30)

for i, ev in enumerate(evaluations):
    if i%2 == 0:
        y = 0
    else:
        y = 1
    x = int(i/2)
    datos_unet = [data[name][ev][data[name].type == 'unet'] for name in names]
    datos_uloss = [data[name][ev][data[name].type == 'uloss'] for name in names]
    labels = [name + '_unet' for name in names]
    ax[x,y].boxplot(datos_unet, positions = [1,3,5], patch_artist=True)
    labels = [name + '_uloss' for name in names]
    ax[x,y].boxplot(datos_uloss, positions = [2,4,6])
    q1, q3 = np.percentile(df[ev], [25, 75])
    r = q1-q3
    ax[x,y].set_xticklabels(names*2, rotation=90)
    ax[x,y].set_ylim(q1-3*r, q3+3*r)
    ax[x,y].set_title(ev)
